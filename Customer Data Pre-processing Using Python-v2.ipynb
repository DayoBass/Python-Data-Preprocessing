# %% [markdown]
# # <u>Data Preprocessing using Python
#
# ## Background
# You have been given a collection of data from a company wishing to process its customer
# records for business purposes (acw_user_data.csv). The existing systems in-place at the
# company only export to a CSV file, and this is not in an appropriate format for analysis.
# 1. __You
# have been given the task of preparing this data for further analyses by your colleagues
# within the company, including representation changes, filtering, and deriving some new
# attributes / metrics for them.
# These data include attributes such as first name, second name, credit card number, marital
# status, and even contains data on the customer’s car.__
# 2. __The number of records provided is significant, and therefore it is expected that solutions are
# robust to varying types of data, and varying values, offering a programmatic solution.__

# %% [markdown]
# ## Data Processing
# __In this section, seven tasks will be carried out relating to pre-processing data, and only standard python (No pandas / seaborn) with default libraries (os, sys, time, json, csv, etc.) will be used to carry out these tasks__

# %% [markdown]
# __Importing the relevant default libraries to be used for the tasks__

# %%
#Importing the relevant libraries for the tasks.
#only default Python libraries will be used

import os
import sys
import csv 
import json           
import datetime
from datetime import datetime
from datetime import timedelta
from datetime import date

# %% [markdown]
# __Creating Classes which will serve as a container to hold the customer data__
# - The classes have been created after having taken a look at the structure of the acw_user_data csv file

# %%
#creating a parent class of customers which will contain attributes for each customer
#The idea here is that each customer will have the different attributes contained in the inner classes

class Customer:
    
    #using the init special method and constructor which is to be called when when the class is being initiated
    #this will define the characteristics of each customer
    def __init__(self):
        self.personal = self.Personal()
        self.address = self.Address()
        self.work = self.Work()
        self.card = self.Card()
        self.vehicle = self.Vehicle()

    #define the repr method for the main class Customer    
    def __repr__(self):
        return f'[{self.Personal}, {self.Address},{self.Work},{self.Card},{self.Vehicle}]' 
    
    #define the inner class Personal for the Parent Class Customer and its attributes
    class Personal():
        def __init__(self, first_name, last_name, sex, age, marital_status, dependants):
        #a customer's Personal data must contain these six variables
            self.first_name = first_name
            self.last_name = last_name
            self.sex = sex
            self.age = age
            self.marital_status = marital_status
            self.dependants = dependants
            
        #define the repr method for the class Personal
        def __repr__(self):
            return f'[{self.first_name}, {self.last_name},{self.sex},{self.age},{self.marital_status},{self.dependants}]'
    
    #define the inner class Address for the Parent Class Customer and its attributes
    class Address:
        def __init__(self, street, city, postcode):
        #a customer's Address data must contain these three variables    
            self.street = street
            self.city = city
            self.postcode = postcode
            
        #define the repr method for the class Address
        def __repr__(self):
            return f'[{self.street}, {self.city},{self.postcode}]'
    
    #define the inner class Work for the Parent Class Customer and its attributes
    class Work:
        def __init__(self, employer, commute, salary_GBP, retired, pension_GBP):
        #a customer's Work data must contain these five variables 
            self.employer = employer
            self.commute = commute
            self.salary_GBP = salary_GBP
            self.retired = retired
            self.pension_GBP = pension_GBP

        #define the repr method for the class Work
        def __repr__(self):
            return f'[{self.employer}, {self.commute},{self.salary_GBP},{self.retired},{self.pension_GBP}]'            

    #define the inner class Card for the Parent Class Customer and its attributes        
    class Card:
        def __init__(self, card_num, card_cvv, card_iban, card_start, card_exp):
        #a customer's Card data must contain these five variables     
            self.card_num = card_num
            self.card_cvv = card_cvv
            self.card_iban = card_iban
            self.card_start = card_start
            self.card_exp = card_exp
            
        #define the repr method for the class Card
        def __repr__(self):
            return f'[{self.card_num}, {self.card_cvv},{self.card_iban},{self.card_start},{self.card_exp}]'

    #define the inner class Vehicle for the Parent Class Customer and its attributes       
    class Vehicle:
        def __init__(self, vehicle_make, vehicle_model, vehicle_year, vehicle_type):
        #a customer's Vehicle data must contain these four variables  
            self.vehicle_make = vehicle_make
            self.vehicle_model = vehicle_model
            self.vehicle_year = vehicle_year
            self.vehicle_type = vehicle_type

        #define the repr method for the class Vehicle
        def __repr__(self):
            return f'[{self.vehicle_make}, {self.vehicle_model},{self.vehicle_year},{self.vehicle_type}]'

# %% [markdown]
# __Tasks 1-3: In the next cell, the following will be carried out:__
# 1. Reading in the csv file
# 2. Converting values to their appropiate types
# 3. Converting the flat csv structure to a nested structure
#
# __A function will be defined to hold all of these points__
# <br>__Note regarding type conversion:__
# - Age is handled and converted to int
# - Dependants is handled - converted to int and then rows with issues handled using try/execpt conditions
# - Commute data is handled - converted to float
# - Salary is handled - converted to int
# - Pension is handled - converted to int
# - Card number is handled - using a combination of int and float due to the numbers ending with several zeros
# - Card start date and end date is handled - converted to datetime and back to string for ease of conversion to json later
# - Card cvv is handled - converted to int
# - Retired is handled to be a boolean - converted from string
# - Vehicle year is handled - converted to int

# %%
#creating a function which takes a filename as the input
#the function will do the required type conversions and create the nested structure

def customer(file_name):
    
    #the list comprehensions required for the tasks
    cust_data = []
    problematic_rows = []
      
    try:
        #reading in the csv file
        with open (file_name,'r') as cust_file:
            csv_reader = csv.reader(cust_file, delimiter=',')
            headers = next(csv_reader)
            for row_no , row in enumerate(csv_reader):
                
                #the type conversions are done first
                #in this case, the card start and end dates needed extensive conversion efforts
                #this is because the date styles when taken from csv to Python are not consistent
                #in most rows there were mainly 'Month-Year', while in some rows it was 'Year-Month'
                #these needed to be addressed
                
                try:
                    #direct datetime conversion and put the data in strings
                    row[6] = str(datetime.strptime(row[6], '%b-%y').date())
                    row[7] = str(datetime.strptime(row[7], '%b-%y').date())

                except Exception as e:
                    try:
                        #the idea here is to split the odd rows with 'Year-Month' instead of 'Month-Year' into two
                        #then after splitting, join them back in the row order and then do the datetime conversion
                        
                        cc_start_split = row[6].split('-')
                        cc_start_join = cc_start_split[1] + '-' + cc_start_split[0]
                        row[6] = str(datetime.strptime(cc_start_join, '%b-%y').date())

                        row[7] = str(datetime.strptime(row[7], '%b-%y').date())

                    except Exception as e:
                        try:
                            cc_exp_split = row[7].split('-')
                            cc_exp_join = cc_exp_split[1] + '-' + cc_exp_split[0]
                            row[7] = str(datetime.strptime(cc_exp_join, '%b-%y').date())

                        except Exception as e:
                            print ('datetime error')
                
                #another type conversion is done here to change TRUE and FALSE to boolean
                if row[16] == 'TRUE':
                    row[16] = True
                elif row[16] == 'FALSE':
                    row[16] = False
                else:
                    row[16] ='N/A'
                
                
                #finally, after the tricky date conversions, data storage is done with some other simple type conversions
                #the Parent class and inner classes have been assigned attributes as noted in the previous cells
                #each of the class takes the required attributes otherwise an error is raised
                
                try:
                    personal_data = Customer.Personal(row[11],row[13],row[18],int(row[3]), row[14], int(row[10])).__dict__
                    address_data = Customer.Address(row[0],row[1],row[2]).__dict__
                    work_data = Customer.Work(row[5],float(row[4]),int(row[17]),row[16],int(row[15])).__dict__
                    card_data = Customer.Card(int(float(row[8])),int(row[9]),row[12],row[6],row[7]).__dict__
                    vehicle_data = Customer.Vehicle(row[19],row[20],int(row[21]),row[22]).__dict__
                    
                    #the list comprehension defined earlier is apppended and now holds the data
                    cust_data.append({
                        'personal':personal_data,
                        'address': address_data,
                        'work': work_data,
                        'card': card_data,
                        'vehicle':vehicle_data,
                                         })
                except Exception as err:
                    
                    #converting dependants raises errors and is dealt with here
                    problematic_rows.append(row_no)
                    
                    #where there are blanck cells, change this to 0
                    if row[10] == "":
                        row[10] = 0
                        
                        personal_data = Customer.Personal(row[11],row[13],row[18],int(row[3]), row[14], int(row[10])).__dict__
                        address_data = Customer.Address(row[0],row[1],row[2]).__dict__
                        work_data = Customer.Work(row[5],float(row[4]),int(row[17]),row[16],int(row[15])).__dict__
                        card_data = Customer.Card(int(float(row[8])),int(row[9]),row[12],row[6],row[7]).__dict__
                        vehicle_data = Customer.Vehicle(row[19],row[20],row[21],row[22]).__dict__

                        cust_data.append({
                            'personal':personal_data,
                            'address': address_data,
                            'work': work_data,
                            'card': card_data,
                            'vehicle':vehicle_data,
                                             })

            print('There are', (len(problematic_rows)), 'rows with conversion issues and the problematic rows are:\n', problematic_rows)
            print ('The problematic rows had blank data and this has been changed to 0')
            print('\n The length of the list is:', len(cust_data),'rows')
                
        return (cust_data)
    
    except FileNotFoundError:
         print('CSV file name in the with open ()line is wrong\nPlease check the file name correctly or(and) check the directory')        

#creating an object
#calling the function and using the filename as the input to return our results
all_customers = customer('acw_user_data.csv')
all_customers
# Out:
# There are 19 rows with conversion issues and the problematic rows are:
#  [21, 109, 179, 205, 270, 272, 274, 358, 460, 468, 579, 636, 679, 725, 822, 865, 917, 931, 983]
# The problematic rows had blank data and this has been changed to 0
#
#  The length of the list is: 1000 rows
# [{'personal': {'first_name': 'Kieran',
#    'last_name': 'Wilson',
#    'sex': 'Male',
#    'age': 89,
#    'marital_status': 'married or civil partner',
#    'dependants': 3},
#   'address': {'street': '70 Lydia isle',
#    'city': 'Lake Conor',
#    'postcode': 'S71 7XZ'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 72838,
#    'retired': True,
#    'pension_GBP': 7257},
#   'card': {'card_num': 676000000000,
#    'card_cvv': 875,
#    'card_iban': 'GB62PQKB71416034141571',
#    'card_start': '2018-08-01',
#    'card_exp': '2027-11-01'},
#   'vehicle': {'vehicle_make': 'Hyundai',
#    'vehicle_model': 'Bonneville',
#    'vehicle_year': 2009,
#    'vehicle_type': 'Pickup'}},
#  {'personal': {'first_name': 'Jonathan',
#    'last_name': 'Thomas',
#    'sex': 'Male',
#    'age': 46,
#    'marital_status': 'married or civil partner',
#    'dependants': 1},
#   'address': {'street': '00 Wheeler wells',
#    'city': 'Chapmanton',
#    'postcode': 'L2 7BT'},
#   'work': {'employer': 'Begum-Williams',
#    'commute': 13.72,
#    'salary_GBP': 54016,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4530000000000000,
#    'card_cvv': 583,
#    'card_iban': 'GB37UMCO54540228728019',
#    'card_start': '2008-12-01',
#    'card_exp': '2026-11-01'},
#   'vehicle': {'vehicle_make': 'Nissan',
#    'vehicle_model': 'ATS',
#    'vehicle_year': 1996,
#    'vehicle_type': 'Coupe'}},
#  {'personal': {'first_name': 'Antony',
#    'last_name': 'Jones',
#    'sex': 'Male',
#    'age': 22,
#    'marital_status': 'married or civil partner',
#    'dependants': 1},
#   'address': {'street': 'Studio 33K Joel walk',
#    'city': 'Randallborough',
#    'postcode': 'ME3N 1GH'},
#   'work': {'employer': 'Hill-Wright',
#    'commute': 16.02,
#    'salary_GBP': 68049,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4090000000000000000,
#    'card_cvv': 422,
#    'card_iban': 'GB40CVUE84011545859591',
#    'card_start': '2019-11-01',
#    'card_exp': '2027-07-01'},
#   'vehicle': {'vehicle_make': 'GMC',
#    'vehicle_model': 'Achieva',
#    'vehicle_year': 2015,
#    'vehicle_type': 'Convertible, Coupe'}},
#  {'personal': {'first_name': 'Henry',
#    'last_name': 'Shaw',
#    'sex': 'Male',
#    'age': 56,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': 'Studio 46S Bethany lights',
#    'city': 'East Reece',
#    'postcode': 'E10 9RJ'},
#   'work': {'employer': 'Green LLC',
#    'commute': 19.35,
#    'salary_GBP': 91337,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4670000000000000000,
#    'card_cvv': 669,
#    'card_iban': 'GB40YPKK71613332239280',
#    'card_start': '2017-10-01',
#    'card_exp': '2018-04-01'},
#   'vehicle': {'vehicle_make': 'Scion',
#    'vehicle_model': 'F150 SuperCrew Cab',
#    'vehicle_year': 1994,
#    'vehicle_type': 'Pickup'}},
#  {'personal': {'first_name': 'Jodie',
#    'last_name': "O'Brien",
#    'sex': 'Female',
#    'age': 57,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': 'Flat 3 Christine views',
#    'city': 'Fletcherstad',
#    'postcode': 'WS2 9SN'},
#   'work': {'employer': 'Hill, Evans and Harrison',
#    'commute': 5.94,
#    'salary_GBP': 18446,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 2250000000000000,
#    'card_cvv': 659,
#    'card_iban': 'GB95WAYW31715898077181',
#    'card_start': '2019-04-01',
#    'card_exp': '2027-11-01'},
#   'vehicle': {'vehicle_make': 'Buick',
#    'vehicle_model': 'Outback',
#    'vehicle_year': 2020,
#    'vehicle_type': 'SUV'}},
#  {'personal': {'first_name': 'Ryan',
#    'last_name': 'Clarke',
#    'sex': 'Male',
#    'age': 23,
#    'marital_status': 'married or civil partner',
#    'dependants': 3},
#   'address': {'street': 'Studio 43M Emily rapid',
#    'city': 'West Derekborough',
#    'postcode': 'W1J 0DL'},
#   'work': {'employer': 'Gill and Sons',
#    'commute': 10.73,
#    'salary_GBP': 38100,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4490000000000000000,
#    'card_cvv': 123,
#    'card_iban': 'GB29SSDY05529526374313',
#    'card_start': '2015-03-01',
#    'card_exp': '2015-05-01'},
#   'vehicle': {'vehicle_make': 'Lexus',
#    'vehicle_model': 'Paceman',
#    'vehicle_year': 2004,
#    'vehicle_type': 'Van/Minivan'}},
#  {'personal': {'first_name': 'Julian',
#    'last_name': 'Potter',
#    'sex': 'Male',
#    'age': 43,
#    'marital_status': 'single',
#    'dependants': 3},
#   'address': {'street': '24 Heather locks',
#    'city': 'New Mathew',
#    'postcode': 'WD10 1LX'},
#   'work': {'employer': 'Clark Group',
#    'commute': 20.05,
#    'salary_GBP': 96645,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 37000000000000,
#    'card_cvv': 622,
#    'card_iban': 'GB92PWOB18937027850061',
#    'card_start': '2007-12-01',
#    'card_exp': '2029-03-01'},
#   'vehicle': {'vehicle_make': 'Lexus',
#    'vehicle_model': 'S-Series',
#    'vehicle_year': 1998,
#    'vehicle_type': 'Van/Minivan'}},
#  {'personal': {'first_name': 'Clive',
#    'last_name': 'Evans',
#    'sex': 'Male',
#    'age': 67,
#    'marital_status': 'single',
#    'dependants': 1},
#   'address': {'street': '81 Goodwin dam',
#    'city': 'Griffinstad',
#    'postcode': 'G3 7ZX'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 27964,
#    'retired': True,
#    'pension_GBP': 28075},
#   'card': {'card_num': 213000000000000,
#    'card_cvv': 389,
#    'card_iban': 'GB04VSAZ69128049616822',
#    'card_start': '2015-07-01',
#    'card_exp': '2027-04-01'},
#   'vehicle': {'vehicle_make': 'Volvo',
#    'vehicle_model': 'Express 3500 Passenger',
#    'vehicle_year': 2013,
#    'vehicle_type': 'SUV'}},
#  {'personal': {'first_name': 'Joan',
#    'last_name': 'Stanley',
#    'sex': 'Female',
#    'age': 33,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': '798 Yates crescent',
#    'city': 'Port Lisa',
#    'postcode': 'LS0M 7UU'},
#   'work': {'employer': 'Richardson and Sons',
#    'commute': 15.29,
#    'salary_GBP': 63433,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 30200000000000,
#    'card_cvv': 849,
#    'card_iban': 'GB80GFKU97154647098789',
#    'card_start': '2013-05-01',
#    'card_exp': '2020-08-01'},
#   'vehicle': {'vehicle_make': 'Volkswagen',
#    'vehicle_model': 'Town & Country',
#    'vehicle_year': 2010,
#    'vehicle_type': 'Sedan, Coupe, Hatchback'}},
#  {'personal': {'first_name': 'Malcolm',
#    'last_name': 'Hamilton',
#    'sex': 'Male',
#    'age': 87,
#    'marital_status': 'single',
#    'dependants': 2},
#   'address': {'street': 'Studio 77c Gail tunnel',
#    'city': 'Garyberg',
#    'postcode': 'S7W 4DW'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 66157,
#    'retired': True,
#    'pension_GBP': 29587},
#   'card': {'card_num': 213000000000000,
#    'card_cvv': 766,
#    'card_iban': 'GB74TXVQ82130006568515',
#    'card_start': '2013-10-01',
#    'card_exp': '2013-10-01'},
#   'vehicle': {'vehicle_make': 'Dodge',
#    'vehicle_model': 'Impreza',
#    'vehicle_year': 2015,
#    'vehicle_type': 'Sedan'}},
#  {'personal': {'first_name': 'Kimberley',
#    'last_name': 'Turner',
#    'sex': 'Female',
#    'age': 64,
#    'marital_status': 'married or civil partner',
#    'dependants': 3},
#   'address': {'street': '2 Robert squares',
#    'city': 'North Martyn',
#    'postcode': 'LN2 4JH'},
#   'work': {'employer': 'Gray-James',
#    'commute': 11.11,
#    'salary_GBP': 39983,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4710000000000000,
#    'card_cvv': 843,
#    'card_iban': 'GB95JQAU66555098753975',
#    'card_start': '2019-05-01',
#    'card_exp': '2029-03-01'},
#   'vehicle': {'vehicle_make': 'Volvo',
#    'vehicle_model': 'Tundra Double Cab',
#    'vehicle_year': 2011,
#    'vehicle_type': 'Sedan'}},
#  {'personal': {'first_name': 'Stuart',
#    'last_name': 'Page',
#    'sex': 'Male',
#    'age': 68,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': '6 Frances flats',
#    'city': 'Lake Amberchester',
#    'postcode': 'NE5E 5AD'},
#   'work': {'employer': 'Mitchell-Brown',
#    'commute': 7.5,
#    'salary_GBP': 24062,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4030000000000,
#    'card_cvv': 404,
#    'card_iban': 'GB52JKQX17539370637650',
#    'card_start': '2018-06-01',
#    'card_exp': '2022-12-01'},
#   'vehicle': {'vehicle_make': 'Volkswagen',
#    'vehicle_model': 'Stratus',
#    'vehicle_year': 2012,
#    'vehicle_type': 'SUV'}},
#  {'personal': {'first_name': 'Hollie',
#    'last_name': 'Gray',
#    'sex': 'Female',
#    'age': 45,
#    'marital_status': 'single',
#    'dependants': 3},
#   'address': {'street': 'Flat 29 Liam greens',
#    'city': 'West Liamview',
#    'postcode': 'S78 9WZ'},
#   'work': {'employer': 'Bailey, Gibson and Wallace',
#    'commute': 20.21,
#    'salary_GBP': 97948,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 375000000000000,
#    'card_cvv': 237,
#    'card_iban': 'GB32JFUZ85486983593277',
#    'card_start': '2019-03-01',
#    'card_exp': '2023-02-01'},
#   'vehicle': {'vehicle_make': 'Ford',
#    'vehicle_model': '1500 Regular Cab',
#    'vehicle_year': 2008,
#    'vehicle_type': 'Convertible'}},
#  {'personal': {'first_name': 'Lawrence',
#    'last_name': 'Smith',
#    'sex': 'Male',
#    'age': 56,
#    'marital_status': 'married or civil partner',
#    'dependants': 3},
#   'address': {'street': 'Studio 75 Matthew tunnel',
#    'city': 'Patelville',
#    'postcode': 'L85 4LT'},
#   'work': {'employer': 'Jones Inc',
#    'commute': 9.48,
#    'salary_GBP': 32281,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 3560000000000000,
#    'card_cvv': 69,
#    'card_iban': 'GB80OOIU80240902240471',
#    'card_start': '2017-04-01',
#    'card_exp': '2020-12-01'},
#   'vehicle': {'vehicle_make': 'Lincoln',
#    'vehicle_model': 'Sierra 2500 HD Crew Cab',
#    'vehicle_year': 2016,
#    'vehicle_type': 'Pickup'}},
#  {'personal': {'first_name': 'Jade',
#    'last_name': 'John',
#    'sex': 'Female',
#    'age': 78,
#    'marital_status': 'married or civil partner',
#    'dependants': 4},
#   'address': {'street': '8 Bray row',
#    'city': 'Daviestown',
#    'postcode': 'S2H 5RE'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 59891,
#    'retired': True,
#    'pension_GBP': 24712},
#   'card': {'card_num': 4550000000000000,
#    'card_cvv': 22,
#    'card_iban': 'GB76WOAN35375600936407',
#    'card_start': '2010-12-01',
#    'card_exp': '2019-12-01'},
#   'vehicle': {'vehicle_make': 'Nissan',
#    'vehicle_model': 'LC',
#    'vehicle_year': 2012,
#    'vehicle_type': 'SUV'}},
#  {'personal': {'first_name': 'Ronald',
#    'last_name': 'Pearce',
#    'sex': 'Male',
#    'age': 55,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': '8 Lesley estates',
#    'city': 'South Albertmouth',
#    'postcode': 'L1D 2GY'},
#   'work': {'employer': 'Butler PLC',
#    'commute': 17.53,
#    'salary_GBP': 78214,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4040000000000,
#    'card_cvv': 885,
#    'card_iban': 'GB63SWMR56023428926868',
#    'card_start': '2014-06-01',
#    'card_exp': '2029-04-01'},
#   'vehicle': {'vehicle_make': 'Acura',
#    'vehicle_model': 'S10 Regular Cab',
#    'vehicle_year': 1999,
#    'vehicle_type': 'Pickup'}},
#  {'personal': {'first_name': 'Josephine',
#    'last_name': 'Saunders',
#    'sex': 'Female',
#    'age': 40,
#    'marital_status': 'married or civil partner',
#    'dependants': 3},
#   'address': {'street': '6 Karl path',
#    'city': 'Lake Kateborough',
#    'postcode': 'L2 1YW'},
#   'work': {'employer': 'White PLC',
#    'commute': 18.76,
#    'salary_GBP': 86961,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 3580000000000000,
#    'card_cvv': 388,
#    'card_iban': 'GB95JPHC00666850049083',
#    'card_start': '2014-07-01',
#    'card_exp': '2017-02-01'},
#   'vehicle': {'vehicle_make': 'Hyundai',
#    'vehicle_model': 'Colorado Extended Cab',
#    'vehicle_year': 2017,
#    'vehicle_type': 'Sedan'}},
#  {'personal': {'first_name': 'Tina',
#    'last_name': 'Thornton',
#    'sex': 'Female',
#    'age': 28,
#    'marital_status': 'single',
#    'dependants': 2},
#   'address': {'street': 'Studio 9 Joan tunnel',
#    'city': 'Birdview',
#    'postcode': 'LS3 9ZL'},
#   'work': {'employer': 'McCarthy and Sons',
#    'commute': 6.65,
#    'salary_GBP': 20918,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 6010000000000000,
#    'card_cvv': 588,
#    'card_iban': 'GB02YMXX98886109551024',
#    'card_start': '2014-03-01',
#    'card_exp': '2023-06-01'},
#   'vehicle': {'vehicle_make': 'Mercedes-Benz',
#    'vehicle_model': 'RX',
#    'vehicle_year': 1992,
#    'vehicle_type': 'Hatchback, Convertible'}},
#  {'personal': {'first_name': 'Lauren',
#    'last_name': 'Smith',
#    'sex': 'Female',
#    'age': 64,
#    'marital_status': 'married or civil partner',
#    'dependants': 3},
#   'address': {'street': 'Studio 24F Cartwright mission',
#    'city': 'Lake Cheryl',
#    'postcode': 'EX5 7QJ'},
#   'work': {'employer': 'Dickinson LLC',
#    'commute': 11.2,
#    'salary_GBP': 40432,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4520000000000000,
#    'card_cvv': 592,
#    'card_iban': 'GB13NXGK90881253380683',
#    'card_start': '2013-09-01',
#    'card_exp': '2016-04-01'},
#   'vehicle': {'vehicle_make': 'Nissan',
#    'vehicle_model': 'Ram 3500 Quad Cab',
#    'vehicle_year': 2019,
#    'vehicle_type': 'Wagon, Sedan'}},
#  {'personal': {'first_name': 'Tracy',
#    'last_name': 'White',
#    'sex': 'Female',
#    'age': 61,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': '409 Julie cliff',
#    'city': 'North Benjamin',
#    'postcode': 'SK1 8EA'},
#   'work': {'employer': 'Pugh-Ahmed',
#    'commute': 15.12,
#    'salary_GBP': 62377,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4350000000000000000,
#    'card_cvv': 981,
#    'card_iban': 'GB46TBUI88094503861317',
#    'card_start': '2012-11-01',
#    'card_exp': '2019-08-01'},
#   'vehicle': {'vehicle_make': 'Chevrolet',
#    'vehicle_model': 'Navigator',
#    'vehicle_year': 2008,
#    'vehicle_type': 'Van/Minivan'}},
#  {'personal': {'first_name': 'Lynne',
#    'last_name': 'Smith',
#    'sex': 'Female',
#    'age': 61,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': 'Studio 98v Watson manors',
#    'city': 'Parkershire',
#    'postcode': 'E58 7QE'},
#   'work': {'employer': 'Wall Inc',
#    'commute': 18.23,
#    'salary_GBP': 83114,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4200000000000,
#    'card_cvv': 215,
#    'card_iban': 'GB95OJRW46308657171586',
#    'card_start': '2018-07-01',
#    'card_exp': '2020-06-01'},
#   'vehicle': {'vehicle_make': 'Ford',
#    'vehicle_model': 'Sierra 2500 HD Regular Cab',
#    'vehicle_year': 2009,
#    'vehicle_type': 'Wagon'}},
#  {'personal': {'first_name': 'Sian',
#    'last_name': 'Marshall',
#    'sex': 'Female',
#    'age': 40,
#    'marital_status': 'married or civil partner',
#    'dependants': 0},
#   'address': {'street': '9 Hargreaves loaf',
#    'city': 'New Keith',
#    'postcode': 'OX85 1NN'},
#   'work': {'employer': 'Frost-Howard',
#    'commute': 11.98,
#    'salary_GBP': 44434,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 3580000000000000,
#    'card_cvv': 426,
#    'card_iban': 'GB24RDII19341179851384',
#    'card_start': '2018-09-01',
#    'card_exp': '2023-02-01'},
#   'vehicle': {'vehicle_make': 'MAZDA',
#    'vehicle_model': 'Tundra Regular Cab',
#    'vehicle_year': '2001',
#    'vehicle_type': 'Sedan'}},
#  {'personal': {'first_name': 'Lindsey',
#    'last_name': 'Williams',
#    'sex': 'Female',
#    'age': 75,
#    'marital_status': 'single',
#    'dependants': 1},
#   'address': {'street': 'Studio 5 Morgan shore',
#    'city': 'Murrayshire',
#    'postcode': 'N2B 6BQ'},
#   'work': {'employer': 'Taylor-Price',
#    'commute': 17.76,
#    'salary_GBP': 79823,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 3600000000000000,
#    'card_cvv': 779,
#    'card_iban': 'GB13LRBV70338974739597',
#    'card_start': '2017-12-01',
#    'card_exp': '2025-07-01'},
#   'vehicle': {'vehicle_make': 'Toyota',
#    'vehicle_model': 'Silverado 3500 HD Crew Cab',
#    'vehicle_year': 2008,
#    'vehicle_type': 'SUV'}},
#  {'personal': {'first_name': 'Billy',
#    'last_name': 'Turner',
#    'sex': 'Male',
#    'age': 30,
#    'marital_status': 'single',
#    'dependants': 2},
#   'address': {'street': 'Flat 7 Nicholas extensions',
#    'city': 'Claireside',
#    'postcode': 'G1 8ND'},
#   'work': {'employer': 'Chapman-Roberts',
#    'commute': 17.22,
#    'salary_GBP': 76038,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4420000000000000,
#    'card_cvv': 844,
#    'card_iban': 'GB20SYOG64532798985587',
#    'card_start': '2007-12-01',
#    'card_exp': '2024-01-01'},
#   'vehicle': {'vehicle_make': 'Mitsubishi',
#    'vehicle_model': 'Optima Hybrid',
#    'vehicle_year': 2002,
#    'vehicle_type': 'Sedan'}},
#  {'personal': {'first_name': 'Elliot',
#    'last_name': 'Iqbal',
#    'sex': 'Male',
#    'age': 52,
#    'marital_status': 'widowed',
#    'dependants': 2},
#   'address': {'street': 'Studio 3 Duncan spurs',
#    'city': 'Briggsside',
#    'postcode': 'E0T 1XP'},
#   'work': {'employer': 'Hall, Chambers and Hussain',
#    'commute': 17.57,
#    'salary_GBP': 78499,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 341000000000000,
#    'card_cvv': 653,
#    'card_iban': 'GB33EXFR41119491231301',
#    'card_start': '2020-09-01',
#    'card_exp': '2021-05-01'},
#   'vehicle': {'vehicle_make': 'Chrysler',
#    'vehicle_model': 'Camry',
#    'vehicle_year': 2000,
#    'vehicle_type': 'Coupe'}},
#  {'personal': {'first_name': 'Jessica',
#    'last_name': 'Carr',
#    'sex': 'Female',
#    'age': 58,
#    'marital_status': 'married or civil partner',
#    'dependants': 1},
#   'address': {'street': '4 Mitchell ranch',
#    'city': 'Lake Josephinechester',
#    'postcode': 'N5S 7YJ'},
#   'work': {'employer': 'Hall-Bishop',
#    'commute': 10.68,
#    'salary_GBP': 37866,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 3540000000000000,
#    'card_cvv': 555,
#    'card_iban': 'GB34JTYZ40582231795531',
#    'card_start': '2020-09-01',
#    'card_exp': '2028-02-01'},
#   'vehicle': {'vehicle_make': 'Dodge',
#    'vehicle_model': 'Talon',
#    'vehicle_year': 2014,
#    'vehicle_type': 'Coupe, Convertible'}},
#  {'personal': {'first_name': 'Caroline',
#    'last_name': 'Clarke',
#    'sex': 'Female',
#    'age': 32,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': '235 Smith path',
#    'city': 'Singhmouth',
#    'postcode': 'WN71 7XD'},
#   'work': {'employer': 'Rogers, Richards and Thomas',
#    'commute': 16.42,
#    'salary_GBP': 70655,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 6010000000000000,
#    'card_cvv': 190,
#    'card_iban': 'GB02HCXE02205190652485',
#    'card_start': '2015-05-01',
#    'card_exp': '2024-04-01'},
#   'vehicle': {'vehicle_make': 'Hyundai',
#    'vehicle_model': 'Monte Carlo',
#    'vehicle_year': 2011,
#    'vehicle_type': 'Sedan, Wagon'}},
#  {'personal': {'first_name': 'Jack',
#    'last_name': 'Porter',
#    'sex': 'Male',
#    'age': 36,
#    'marital_status': 'single',
#    'dependants': 3},
#   'address': {'street': 'Studio 76l Carr mill',
#    'city': 'South Francesborough',
#    'postcode': 'W7 1DR'},
#   'work': {'employer': 'Henry, Gibson and French',
#    'commute': 17.64,
#    'salary_GBP': 78955,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 582000000000,
#    'card_cvv': 7258,
#    'card_iban': 'GB64SWHN93102765498771',
#    'card_start': '2009-12-01',
#    'card_exp': '2017-04-01'},
#   'vehicle': {'vehicle_make': 'Kia',
#    'vehicle_model': 'X3',
#    'vehicle_year': 2018,
#    'vehicle_type': 'Pickup'}},
#  {'personal': {'first_name': 'Gavin',
#    'last_name': 'Chapman',
#    'sex': 'Male',
#    'age': 18,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': '385 Ward rue',
#    'city': 'Abigailport',
#    'postcode': 'AL0 4BW'},
#   'work': {'employer': 'Barnett, Jones and Jones',
#    'commute': 19.49,
#    'salary_GBP': 92384,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 2720000000000000,
#    'card_cvv': 5547,
#    'card_iban': 'GB15JSIN49600511879663',
#    'card_start': '2013-02-01',
#    'card_exp': '2014-03-01'},
#   'vehicle': {'vehicle_make': 'Nissan',
#    'vehicle_model': 'Canyon Extended Cab',
#    'vehicle_year': 2014,
#    'vehicle_type': 'Coupe'}},
#  {'personal': {'first_name': 'Dennis',
#    'last_name': 'Johnson',
#    'sex': 'Male',
#    'age': 80,
#    'marital_status': 'married or civil partner',
#    'dependants': 1},
#   'address': {'street': 'Flat 59T Barry loop',
#    'city': 'Lindaton',
#    'postcode': 'B60 3LJ'},
#   'work': {'employer': 'Clark, Evans and Lloyd',
#    'commute': 19.67,
#    'salary_GBP': 93744,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4880000000000,
#    'card_cvv': 20,
#    'card_iban': 'GB67BTBB81025265475465',
#    'card_start': '2018-05-01',
#    'card_exp': '2027-01-01'},
#   'vehicle': {'vehicle_make': 'Nissan',
#    'vehicle_model': 'Spirit',
#    'vehicle_year': 2006,
#    'vehicle_type': 'Pickup'}},
#  {'personal': {'first_name': 'Rhys',
#    'last_name': 'George',
#    'sex': 'Male',
#    'age': 55,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': '4 Patel curve',
#    'city': 'Robertstad',
#    'postcode': 'DT33 1UL'},
#   'work': {'employer': 'May, Bennett and Wood',
#    'commute': 14.53,
#    'salary_GBP': 58770,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 3550000000000000,
#    'card_cvv': 106,
#    'card_iban': 'GB96MSSE31514251878599',
#    'card_start': '2007-12-01',
#    'card_exp': '2024-03-01'},
#   'vehicle': {'vehicle_make': 'Aston Martin',
#    'vehicle_model': 'Sierra 1500 Crew Cab',
#    'vehicle_year': 1993,
#    'vehicle_type': 'Hatchback'}},
#  {'personal': {'first_name': 'Denis',
#    'last_name': 'Brown',
#    'sex': 'Male',
#    'age': 65,
#    'marital_status': 'married or civil partner',
#    'dependants': 1},
#   'address': {'street': '949 Kirsty walk',
#    'city': 'Rickymouth',
#    'postcode': 'N77 4DX'},
#   'work': {'employer': 'Warren, Burton and Spencer',
#    'commute': 7.21,
#    'salary_GBP': 22959,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 3530000000000000,
#    'card_cvv': 570,
#    'card_iban': 'GB61PVEV06020291833305',
#    'card_start': '2008-12-01',
#    'card_exp': '2017-04-01'},
#   'vehicle': {'vehicle_make': 'Ford',
#    'vehicle_model': 'Yukon XL 1500',
#    'vehicle_year': 2007,
#    'vehicle_type': 'Wagon, Sedan, Coupe'}},
#  {'personal': {'first_name': 'Helen',
#    'last_name': 'Kaur',
#    'sex': 'Female',
#    'age': 82,
#    'marital_status': 'single',
#    'dependants': 5},
#   'address': {'street': 'Flat 47 Godfrey road',
#    'city': 'West Brianfurt',
#    'postcode': 'S6G 3HB'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 80297,
#    'retired': True,
#    'pension_GBP': 28731},
#   'card': {'card_num': 5540000000000000,
#    'card_cvv': 465,
#    'card_iban': 'GB42TNFG09550061109890',
#    'card_start': '2018-01-01',
#    'card_exp': '2028-07-01'},
#   'vehicle': {'vehicle_make': 'Acura',
#    'vehicle_model': 'G',
#    'vehicle_year': 1998,
#    'vehicle_type': 'SUV'}},
#  {'personal': {'first_name': 'Jeffrey',
#    'last_name': 'Humphreys',
#    'sex': 'Male',
#    'age': 39,
#    'marital_status': 'divorced',
#    'dependants': 2},
#   'address': {'street': '004 Julian estates',
#    'city': 'Colinhaven',
#    'postcode': 'KT54 9TR'},
#   'work': {'employer': 'Kay, Chapman and Wilson',
#    'commute': 18.81,
#    'salary_GBP': 87308,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4100000000000000,
#    'card_cvv': 615,
#    'card_iban': 'GB34LHKJ06609001114424',
#    'card_start': '2016-01-01',
#    'card_exp': '2025-08-01'},
#   'vehicle': {'vehicle_make': 'Saab',
#    'vehicle_model': 'Transit Connect Cargo',
#    'vehicle_year': 2005,
#    'vehicle_type': 'SUV'}},
#  {'personal': {'first_name': 'Adam',
#    'last_name': 'Wright',
#    'sex': 'Male',
#    'age': 83,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': 'Flat 32 Sharp prairie',
#    'city': 'Marcusstad',
#    'postcode': 'AB57 0ZN'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 70109,
#    'retired': True,
#    'pension_GBP': 30115},
#   'card': {'card_num': 2430000000000000,
#    'card_cvv': 453,
#    'card_iban': 'GB76KUNW91632428208056',
#    'card_start': '2002-12-01',
#    'card_exp': '2024-03-01'},
#   'vehicle': {'vehicle_make': 'GMC',
#    'vehicle_model': 'Frontier Crew Cab',
#    'vehicle_year': 1998,
#    'vehicle_type': 'Van/Minivan'}},
#  {'personal': {'first_name': 'Danielle',
#    'last_name': 'Robertson',
#    'sex': 'Female',
#    'age': 65,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': '8 Michael cliff',
#    'city': 'Joanchester',
#    'postcode': 'B8E 0XR'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 57953,
#    'retired': True,
#    'pension_GBP': 8022},
#   'card': {'card_num': 30300000000000,
#    'card_cvv': 479,
#    'card_iban': 'GB77BKAA88748168755170',
#    'card_start': '2014-05-01',
#    'card_exp': '2027-12-01'},
#   'vehicle': {'vehicle_make': 'Jaguar',
#    'vehicle_model': 'Odyssey',
#    'vehicle_year': 1997,
#    'vehicle_type': 'Hatchback'}},
#  {'personal': {'first_name': 'Joyce',
#    'last_name': 'Brown',
#    'sex': 'Female',
#    'age': 42,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': 'Studio 63 Rachel underpass',
#    'city': 'Gallaghermouth',
#    'postcode': 'G99 3GH'},
#   'work': {'employer': 'Stevenson Group',
#    'commute': 12.44,
#    'salary_GBP': 46864,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4610000000000,
#    'card_cvv': 926,
#    'card_iban': 'GB09RXOP90874575465239',
#    'card_start': '2013-07-01',
#    'card_exp': '2013-08-01'},
#   'vehicle': {'vehicle_make': 'Mercedes-Benz',
#    'vehicle_model': 'Veloster',
#    'vehicle_year': 2011,
#    'vehicle_type': 'Convertible'}},
#  {'personal': {'first_name': 'Vanessa',
#    'last_name': 'Kay',
#    'sex': 'Female',
#    'age': 91,
#    'marital_status': 'single',
#    'dependants': 2},
#   'address': {'street': '7 Williams forks',
#    'city': 'Cookside',
#    'postcode': 'N6 2YZ'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 81220,
#    'retired': True,
#    'pension_GBP': 30866},
#   'card': {'card_num': 4230000000000,
#    'card_cvv': 752,
#    'card_iban': 'GB75HZCQ22453289425740',
#    'card_start': '2019-06-01',
#    'card_exp': '2021-11-01'},
#   'vehicle': {'vehicle_make': 'Chevrolet',
#    'vehicle_model': 'Viper',
#    'vehicle_year': 2015,
#    'vehicle_type': 'Pickup'}},
#  {'personal': {'first_name': 'Dawn',
#    'last_name': 'Young',
#    'sex': 'Female',
#    'age': 35,
#    'marital_status': 'married or civil partner',
#    'dependants': 4},
#   'address': {'street': '75 Gordon courts',
#    'city': 'Lorraineberg',
#    'postcode': 'L56 2JA'},
#   'work': {'employer': 'Wright and Sons',
#    'commute': 15.36,
#    'salary_GBP': 63857,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 6010000000000000,
#    'card_cvv': 660,
#    'card_iban': 'GB86CXKN23940068226539',
#    'card_start': '2019-10-01',
#    'card_exp': '2021-07-01'},
#   'vehicle': {'vehicle_make': 'Chevrolet',
#    'vehicle_model': 'S2000',
#    'vehicle_year': 2002,
#    'vehicle_type': 'SUV'}},
#  {'personal': {'first_name': 'Darren',
#    'last_name': 'Nicholls',
#    'sex': 'Male',
#    'age': 54,
#    'marital_status': 'married or civil partner',
#    'dependants': 1},
#   'address': {'street': 'Studio 09F Allen road',
#    'city': 'Port Rachel',
#    'postcode': 'TS9 1TL'},
#   'work': {'employer': 'Thomson, Kirby and Barker',
#    'commute': 9.85,
#    'salary_GBP': 33987,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 3580000000000000,
#    'card_cvv': 113,
#    'card_iban': 'GB12URYF32648832649281',
#    'card_start': '2019-05-01',
#    'card_exp': '2023-08-01'},
#   'vehicle': {'vehicle_make': 'Volkswagen',
#    'vehicle_model': '300',
#    'vehicle_year': 2015,
#    'vehicle_type': 'Sedan'}},
#  {'personal': {'first_name': 'Lauren',
#    'last_name': 'Martin',
#    'sex': 'Female',
#    'age': 20,
#    'marital_status': 'widowed',
#    'dependants': 2},
#   'address': {'street': 'Studio 7 Jemma cliff',
#    'city': 'Turnerbury',
#    'postcode': 'B98 1HT'},
#   'work': {'employer': 'Smith-Smith',
#    'commute': 7.65,
#    'salary_GBP': 24652,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4930000000000000,
#    'card_cvv': 373,
#    'card_iban': 'GB41AMAJ35865980015154',
#    'card_start': '2004-12-01',
#    'card_exp': '2024-01-01'},
#   'vehicle': {'vehicle_make': 'GMC',
#    'vehicle_model': 'Phaeton',
#    'vehicle_year': 2008,
#    'vehicle_type': 'SUV'}},
#  {'personal': {'first_name': 'Melanie',
#    'last_name': "O'Brien",
#    'sex': 'Female',
#    'age': 51,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': 'Flat 08d Ward squares',
#    'city': 'Phillipside',
#    'postcode': 'BB3A 9PE'},
#   'work': {'employer': 'Clarke Inc',
#    'commute': 6.45,
#    'salary_GBP': 20206,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 213000000000000,
#    'card_cvv': 542,
#    'card_iban': 'GB14FFMB81152248185033',
#    'card_start': '2001-12-01',
#    'card_exp': '2023-09-01'},
#   'vehicle': {'vehicle_make': 'Pontiac',
#    'vehicle_model': '2500 Regular Cab',
#    'vehicle_year': 1997,
#    'vehicle_type': 'Sedan'}},
#  {'personal': {'first_name': 'Vanessa',
#    'last_name': 'Hussain',
#    'sex': 'Female',
#    'age': 42,
#    'marital_status': 'single',
#    'dependants': 2},
#   'address': {'street': '28 Oliver fort',
#    'city': 'Melissaport',
#    'postcode': 'DY95 0UG'},
#   'work': {'employer': 'Smith PLC',
#    'commute': 20.08,
#    'salary_GBP': 96882,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4030000000000000,
#    'card_cvv': 326,
#    'card_iban': 'GB50MQKE98379126728837',
#    'card_start': '2013-12-01',
#    'card_exp': '2014-11-01'},
#   'vehicle': {'vehicle_make': 'Lexus',
#    'vehicle_model': 'TrailBlazer',
#    'vehicle_year': 2001,
#    'vehicle_type': 'Van/Minivan'}},
#  {'personal': {'first_name': 'Chelsea',
#    'last_name': 'Thorpe',
#    'sex': 'Female',
#    'age': 43,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': 'Flat 39 Shaun dam',
#    'city': 'Martinbury',
#    'postcode': 'N9W 3EN'},
#   'work': {'employer': 'Sutton LLC',
#    'commute': 17.96,
#    'salary_GBP': 81215,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 2240000000000000,
#    'card_cvv': 751,
#    'card_iban': 'GB23IKFU36409120028603',
#    'card_start': '2016-06-01',
#    'card_exp': '2017-01-01'},
#   'vehicle': {'vehicle_make': 'Nissan',
#    'vehicle_model': 'Tundra Regular Cab',
#    'vehicle_year': 2013,
#    'vehicle_type': 'Van/Minivan'}},
#  {'personal': {'first_name': 'Sarah',
#    'last_name': 'Robinson',
#    'sex': 'Female',
#    'age': 38,
#    'marital_status': 'single',
#    'dependants': 2},
#   'address': {'street': 'Studio 77T Emily path',
#    'city': 'West Connor',
#    'postcode': 'NW7B 5ZR'},
#   'work': {'employer': 'Dickinson, Nolan and Smith',
#    'commute': 6.35,
#    'salary_GBP': 19863,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4420000000000000000,
#    'card_cvv': 800,
#    'card_iban': 'GB72SOVW84817129799960',
#    'card_start': '2018-09-01',
#    'card_exp': '2026-02-01'},
#   'vehicle': {'vehicle_make': 'INFINITI',
#    'vehicle_model': 'Sportvan G20',
#    'vehicle_year': 2020,
#    'vehicle_type': 'SUV'}},
#  {'personal': {'first_name': 'Zoe',
#    'last_name': 'Williams',
#    'sex': 'Female',
#    'age': 59,
#    'marital_status': 'widowed',
#    'dependants': 1},
#   'address': {'street': 'Flat 66f Anderson fords',
#    'city': 'Aaronburgh',
#    'postcode': 'E33 3NW'},
#   'work': {'employer': 'Blake-Johnson',
#    'commute': 15.52,
#    'salary_GBP': 64885,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4860000000000000000,
#    'card_cvv': 854,
#    'card_iban': 'GB73OAWO74482506912387',
#    'card_start': '2020-04-01',
#    'card_exp': '2026-02-01'},
#   'vehicle': {'vehicle_make': 'Cadillac',
#    'vehicle_model': 'Tacoma Double Cab',
#    'vehicle_year': 2016,
#    'vehicle_type': 'Coupe, Sedan'}},
#  {'personal': {'first_name': 'Sheila',
#    'last_name': 'Woodward',
#    'sex': 'Female',
#    'age': 84,
#    'marital_status': 'single',
#    'dependants': 1},
#   'address': {'street': '1 Holt knoll',
#    'city': 'Ianview',
#    'postcode': 'L93 2QY'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 59223,
#    'retired': True,
#    'pension_GBP': 24080},
#   'card': {'card_num': 2280000000000000,
#    'card_cvv': 243,
#    'card_iban': 'GB28KWDH09406690563679',
#    'card_start': '2006-12-01',
#    'card_exp': '2017-09-01'},
#   'vehicle': {'vehicle_make': 'Audi',
#    'vehicle_model': 'Celica',
#    'vehicle_year': 2016,
#    'vehicle_type': 'Van/Minivan'}},
#  {'personal': {'first_name': 'Dorothy',
#    'last_name': 'Leonard',
#    'sex': 'Female',
#    'age': 72,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': 'Studio 30X Clive hills',
#    'city': 'East Katemouth',
#    'postcode': 'SN5V 1JD'},
#   'work': {'employer': 'Archer-Dean',
#    'commute': 9.28,
#    'salary_GBP': 31412,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 38700000000000,
#    'card_cvv': 510,
#    'card_iban': 'GB53SWXB45203854278672',
#    'card_start': '2015-05-01',
#    'card_exp': '2018-10-01'},
#   'vehicle': {'vehicle_make': 'Dodge',
#    'vehicle_model': 'B-Series Regular Cab',
#    'vehicle_year': 2017,
#    'vehicle_type': 'Sedan'}},
#  {'personal': {'first_name': 'Ashley',
#    'last_name': 'Sullivan',
#    'sex': 'Male',
#    'age': 50,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': '34 Amanda trace',
#    'city': 'North Juliamouth',
#    'postcode': 'HU28 3AR'},
#   'work': {'employer': 'Williams-Jones',
#    'commute': 5.81,
#    'salary_GBP': 18005,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 379000000000000,
#    'card_cvv': 586,
#    'card_iban': 'GB22OTJE53991614349608',
#    'card_start': '2006-12-01',
#    'card_exp': '2017-07-01'},
#   'vehicle': {'vehicle_make': 'Mercedes-Benz',
#    'vehicle_model': 'Sprinter 2500 Crew',
#    'vehicle_year': 2014,
#    'vehicle_type': 'Pickup'}},
#  {'personal': {'first_name': 'Lindsey',
#    'last_name': 'Perry',
#    'sex': 'Female',
#    'age': 22,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': 'Studio 39L Fisher junction',
#    'city': 'Lukeport',
#    'postcode': 'B5 6HB'},
#   'work': {'employer': 'Phillips-Nixon',
#    'commute': 19.12,
#    'salary_GBP': 89661,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4660000000000,
#    'card_cvv': 643,
#    'card_iban': 'GB04OJXZ36629513168495',
#    'card_start': '2018-01-01',
#    'card_exp': '2027-06-01'},
#   'vehicle': {'vehicle_make': 'Toyota',
#    'vehicle_model': 'Civic',
#    'vehicle_year': 2018,
#    'vehicle_type': 'Coupe, Convertible'}},
#  {'personal': {'first_name': 'Grace',
#    'last_name': 'Davies',
#    'sex': 'Female',
#    'age': 57,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': 'Studio 88 Collins fords',
#    'city': 'Lake Howard',
#    'postcode': 'W4 0AA'},
#   'work': {'employer': 'Collins Group',
#    'commute': 18.78,
#    'salary_GBP': 87098,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4570000000000000000,
#    'card_cvv': 132,
#    'card_iban': 'GB51LSRK16179476021409',
#    'card_start': '2019-04-01',
#    'card_exp': '2025-10-01'},
#   'vehicle': {'vehicle_make': 'Chrysler',
#    'vehicle_model': 'Sierra 3500 HD Crew Cab',
#    'vehicle_year': 2006,
#    'vehicle_type': 'Sedan'}},
#  {'personal': {'first_name': 'Albert',
#    'last_name': 'Steele',
#    'sex': 'Male',
#    'age': 60,
#    'marital_status': 'married or civil partner',
#    'dependants': 3},
#   'address': {'street': '82 Paige bridge',
#    'city': 'Port Elaine',
#    'postcode': 'B5 3BF'},
#   'work': {'employer': 'Webb Group',
#    'commute': 7.57,
#    'salary_GBP': 24329,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 2720000000000000,
#    'card_cvv': 899,
#    'card_iban': 'GB61YUTS59935062271665',
#    'card_start': '2014-02-01',
#    'card_exp': '2026-07-01'},
#   'vehicle': {'vehicle_make': 'Ford',
#    'vehicle_model': 'Prelude',
#    'vehicle_year': 2012,
#    'vehicle_type': 'SUV'}},
#  {'personal': {'first_name': 'Geoffrey',
#    'last_name': 'Ward',
#    'sex': 'Male',
#    'age': 72,
#    'marital_status': 'single',
#    'dependants': 1},
#   'address': {'street': '9 Randall center',
#    'city': 'Donaldmouth',
#    'postcode': 'S5 3GT'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 97406,
#    'retired': True,
#    'pension_GBP': 21838},
#   'card': {'card_num': 377000000000000,
#    'card_cvv': 434,
#    'card_iban': 'GB54ZXCM95740026097623',
#    'card_start': '2014-03-01',
#    'card_exp': '2024-08-01'},
#   'vehicle': {'vehicle_make': 'Lincoln',
#    'vehicle_model': 'Silverado 3500 HD Regular Cab',
#    'vehicle_year': 2015,
#    'vehicle_type': 'Van/Minivan'}},
#  {'personal': {'first_name': 'Adam',
#    'last_name': 'Walsh',
#    'sex': 'Male',
#    'age': 86,
#    'marital_status': 'married or civil partner',
#    'dependants': 3},
#   'address': {'street': '57 Edward burg',
#    'city': 'Shanefurt',
#    'postcode': 'FK4B 4HU'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 26452,
#    'retired': True,
#    'pension_GBP': 10651},
#   'card': {'card_num': 379000000000000,
#    'card_cvv': 150,
#    'card_iban': 'GB45RNEO63895090850522',
#    'card_start': '2015-01-01',
#    'card_exp': '2025-12-01'},
#   'vehicle': {'vehicle_make': 'Subaru',
#    'vehicle_model': 'Commander',
#    'vehicle_year': 1995,
#    'vehicle_type': 'Sedan, Hatchback'}},
#  {'personal': {'first_name': 'Peter',
#    'last_name': 'Burton',
#    'sex': 'Male',
#    'age': 63,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': 'Studio 38 James throughway',
#    'city': 'Leighton',
#    'postcode': 'M8E 7HJ'},
#   'work': {'employer': 'Graham, Watts and Hall',
#    'commute': 5.58,
#    'salary_GBP': 17245,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4060000000000,
#    'card_cvv': 458,
#    'card_iban': 'GB30EGRJ34862965423758',
#    'card_start': '2011-12-01',
#    'card_exp': '2022-07-01'},
#   'vehicle': {'vehicle_make': 'Dodge',
#    'vehicle_model': 'Sorento',
#    'vehicle_year': 2016,
#    'vehicle_type': 'Sedan, Coupe, Hatchback'}},
#  {'personal': {'first_name': 'Christopher',
#    'last_name': 'Jackson',
#    'sex': 'Male',
#    'age': 33,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': 'Flat 05 Hope prairie',
#    'city': 'Lake Grace',
#    'postcode': 'NG0R 7SG'},
#   'work': {'employer': 'Jones Ltd',
#    'commute': 11.51,
#    'salary_GBP': 41981,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 3600000000000000,
#    'card_cvv': 927,
#    'card_iban': 'GB30EKXF93283283335493',
#    'card_start': '2013-09-01',
#    'card_exp': '2026-05-01'},
#   'vehicle': {'vehicle_make': 'Cadillac',
#    'vehicle_model': 'V90',
#    'vehicle_year': 1996,
#    'vehicle_type': 'Van/Minivan'}},
#  {'personal': {'first_name': 'Gavin',
#    'last_name': 'Holland',
#    'sex': 'Male',
#    'age': 46,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': '83 Jemma estates',
#    'city': 'Patelchester',
#    'postcode': 'KA1N 5UP'},
#   'work': {'employer': 'Bailey-George',
#    'commute': 17.08,
#    'salary_GBP': 75117,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 60416002073,
#    'card_cvv': 61,
#    'card_iban': 'GB05MUJX37298335273577',
#    'card_start': '2018-03-01',
#    'card_exp': '2029-05-01'},
#   'vehicle': {'vehicle_make': 'Ford',
#    'vehicle_model': '3000GT',
#    'vehicle_year': 2003,
#    'vehicle_type': 'Van/Minivan'}},
#  {'personal': {'first_name': 'Jeremy',
#    'last_name': 'Richardson',
#    'sex': 'Male',
#    'age': 88,
#    'marital_status': 'single',
#    'dependants': 2},
#   'address': {'street': 'Studio 7 Hill inlet',
#    'city': 'Barnesfurt',
#    'postcode': 'M5 6LA'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 92899,
#    'retired': True,
#    'pension_GBP': 36202},
#   'card': {'card_num': 3570000000000000,
#    'card_cvv': 734,
#    'card_iban': 'GB68DNZL38729225311976',
#    'card_start': '2018-11-01',
#    'card_exp': '2019-06-01'},
#   'vehicle': {'vehicle_make': 'Ford',
#    'vehicle_model': 'ES',
#    'vehicle_year': 1998,
#    'vehicle_type': 'Pickup'}},
#  {'personal': {'first_name': 'Declan',
#    'last_name': 'Smith',
#    'sex': 'Male',
#    'age': 75,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': 'Studio 05p Gardner fords',
#    'city': 'North Bradley',
#    'postcode': 'BB25 7EP'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 59872,
#    'retired': True,
#    'pension_GBP': 19073},
#   'card': {'card_num': 348000000000000,
#    'card_cvv': 915,
#    'card_iban': 'GB35RZFZ68276656752362',
#    'card_start': '2019-09-01',
#    'card_exp': '2022-02-01'},
#   'vehicle': {'vehicle_make': 'Cadillac',
#    'vehicle_model': 'Rodeo',
#    'vehicle_year': 2013,
#    'vehicle_type': 'Pickup'}},
#  {'personal': {'first_name': 'Christian',
#    'last_name': 'Rogers',
#    'sex': 'Male',
#    'age': 66,
#    'marital_status': 'single',
#    'dependants': 4},
#   'address': {'street': 'Studio 15 Cooper forges',
#    'city': 'Port Joel',
#    'postcode': 'B2 9AL'},
#   'work': {'employer': 'Patel-Singh',
#    'commute': 14.39,
#    'salary_GBP': 57934,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 60467338848,
#    'card_cvv': 552,
#    'card_iban': 'GB97UEAX89313220430163',
#    'card_start': '2020-08-01',
#    'card_exp': '2024-10-01'},
#   'vehicle': {'vehicle_make': 'Toyota',
#    'vehicle_model': 'Tiburon',
#    'vehicle_year': 1998,
#    'vehicle_type': 'Sedan'}},
#  {'personal': {'first_name': 'Kenneth',
#    'last_name': 'Lewis',
#    'sex': 'Male',
#    'age': 42,
#    'marital_status': 'divorced',
#    'dependants': 4},
#   'address': {'street': 'Flat 76j Carter junctions',
#    'city': 'Stanleyton',
#    'postcode': 'L9B 0AL'},
#   'work': {'employer': 'Pritchard PLC',
#    'commute': 14.02,
#    'salary_GBP': 55758,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 3520000000000000,
#    'card_cvv': 168,
#    'card_iban': 'GB98HIIZ00956490663842',
#    'card_start': '2019-09-01',
#    'card_exp': '2024-04-01'},
#   'vehicle': {'vehicle_make': 'Isuzu',
#    'vehicle_model': '929',
#    'vehicle_year': 2003,
#    'vehicle_type': 'SUV'}},
#  {'personal': {'first_name': 'Abbie',
#    'last_name': 'Gill',
#    'sex': 'Female',
#    'age': 72,
#    'marital_status': 'single',
#    'dependants': 2},
#   'address': {'street': 'Studio 2 Carpenter prairie',
#    'city': 'West Joyce',
#    'postcode': 'N9 4NW'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 62907,
#    'retired': True,
#    'pension_GBP': 8418},
#   'card': {'card_num': 4700000000000000,
#    'card_cvv': 673,
#    'card_iban': 'GB40VSFG91266868613507',
#    'card_start': '2019-03-01',
#    'card_exp': '2022-04-01'},
#   'vehicle': {'vehicle_make': 'Cadillac',
#    'vehicle_model': 'Escape',
#    'vehicle_year': 1996,
#    'vehicle_type': 'Sedan, Hatchback'}},
#  {'personal': {'first_name': 'Steven',
#    'last_name': 'Stanley',
#    'sex': 'Male',
#    'age': 42,
#    'marital_status': 'widowed',
#    'dependants': 1},
#   'address': {'street': 'Flat 59 Joel pass',
#    'city': 'Murphystad',
#    'postcode': 'B4 6PT'},
#   'work': {'employer': 'Fletcher LLC',
#    'commute': 17.34,
#    'salary_GBP': 76921,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4250000000000000000,
#    'card_cvv': 177,
#    'card_iban': 'GB60ABVW08545614890191',
#    'card_start': '2017-09-01',
#    'card_exp': '2018-03-01'},
#   'vehicle': {'vehicle_make': 'Chrysler',
#    'vehicle_model': 'Savana 2500 Cargo',
#    'vehicle_year': 2000,
#    'vehicle_type': 'Coupe'}},
#  {'personal': {'first_name': 'Carly',
#    'last_name': 'Wright',
#    'sex': 'Female',
#    'age': 32,
#    'marital_status': 'married or civil partner',
#    'dependants': 5},
#   'address': {'street': 'Studio 20 Lisa shores',
#    'city': 'Malcolmstad',
#    'postcode': 'SE7B 0WY'},
#   'work': {'employer': 'Edwards, Clarke and Palmer',
#    'commute': 15.91,
#    'salary_GBP': 67367,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 2700000000000000,
#    'card_cvv': 864,
#    'card_iban': 'GB36ZZMR85340990776081',
#    'card_start': '2013-06-01',
#    'card_exp': '2027-05-01'},
#   'vehicle': {'vehicle_make': 'Nissan',
#    'vehicle_model': 'Excel',
#    'vehicle_year': 2000,
#    'vehicle_type': 'SUV'}},
#  {'personal': {'first_name': 'Lorraine',
#    'last_name': 'Duncan',
#    'sex': 'Female',
#    'age': 33,
#    'marital_status': 'single',
#    'dependants': 4},
#   'address': {'street': '487 Gordon village',
#    'city': 'Hicksstad',
#    'postcode': 'E8E 8BN'},
#   'work': {'employer': 'Williams PLC',
#    'commute': 11.95,
#    'salary_GBP': 44279,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 36100000000000,
#    'card_cvv': 308,
#    'card_iban': 'GB49DVCP36360318826870',
#    'card_start': '2016-05-01',
#    'card_exp': '2024-12-01'},
#   'vehicle': {'vehicle_make': 'Plymouth',
#    'vehicle_model': 'F150 SuperCrew Cab',
#    'vehicle_year': 2001,
#    'vehicle_type': 'Van/Minivan'}},
#  {'personal': {'first_name': 'Jasmine',
#    'last_name': 'Khan',
#    'sex': 'Female',
#    'age': 54,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': 'Studio 24X Saunders plain',
#    'city': 'Cartwrightton',
#    'postcode': 'HX36 6ZR'},
#   'work': {'employer': 'Carter, Ward and Smith',
#    'commute': 11.01,
#    'salary_GBP': 39466,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 213000000000000,
#    'card_cvv': 386,
#    'card_iban': 'GB54URZU46329075531104',
#    'card_start': '2013-05-01',
#    'card_exp': '2020-06-01'},
#   'vehicle': {'vehicle_make': 'Toyota',
#    'vehicle_model': 'NV3500 HD Passenger',
#    'vehicle_year': 1994,
#    'vehicle_type': 'Convertible'}},
#  {'personal': {'first_name': 'Darren',
#    'last_name': 'Davies',
#    'sex': 'Male',
#    'age': 48,
#    'marital_status': 'single',
#    'dependants': 2},
#   'address': {'street': '010 Eric street',
#    'city': 'New Reecefurt',
#    'postcode': 'SS7A 4EP'},
#   'work': {'employer': 'Day-Thomas',
#    'commute': 19.13,
#    'salary_GBP': 89697,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4130000000000,
#    'card_cvv': 911,
#    'card_iban': 'GB94ENEM74278534672022',
#    'card_start': '2017-01-01',
#    'card_exp': '2019-01-01'},
#   'vehicle': {'vehicle_make': 'Mercedes-Benz',
#    'vehicle_model': 'DTS',
#    'vehicle_year': 1992,
#    'vehicle_type': 'Sedan'}},
#  {'personal': {'first_name': 'Paula',
#    'last_name': 'Roberts',
#    'sex': 'Female',
#    'age': 37,
#    'marital_status': 'single',
#    'dependants': 2},
#   'address': {'street': 'Flat 23D Nicola isle',
#    'city': 'South Garethmouth',
#    'postcode': 'RG3 2AG'},
#   'work': {'employer': 'Lambert, Parker and Brown',
#    'commute': 11.99,
#    'salary_GBP': 44472,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 6540000000000000,
#    'card_cvv': 77,
#    'card_iban': 'GB87FHXK16979131324991',
#    'card_start': '2019-05-01',
#    'card_exp': '2022-09-01'},
#   'vehicle': {'vehicle_make': 'Jeep',
#    'vehicle_model': 'SX4',
#    'vehicle_year': 2013,
#    'vehicle_type': 'SUV'}},
#  {'personal': {'first_name': 'Tracey',
#    'last_name': 'Knight',
#    'sex': 'Female',
#    'age': 87,
#    'marital_status': 'single',
#    'dependants': 1},
#   'address': {'street': '8 King roads',
#    'city': 'Helenmouth',
#    'postcode': 'M3 5FE'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 90989,
#    'retired': True,
#    'pension_GBP': 19833},
#   'card': {'card_num': 3530000000000000,
#    'card_cvv': 889,
#    'card_iban': 'GB32HKXY65019270186072',
#    'card_start': '2014-07-01',
#    'card_exp': '2025-08-01'},
#   'vehicle': {'vehicle_make': 'Mitsubishi',
#    'vehicle_model': 'Wrangler',
#    'vehicle_year': 2005,
#    'vehicle_type': 'Van/Minivan'}},
#  {'personal': {'first_name': 'Carolyn',
#    'last_name': 'Roberts',
#    'sex': 'Female',
#    'age': 67,
#    'marital_status': 'married or civil partner',
#    'dependants': 3},
#   'address': {'street': 'Flat 53 Hollie motorway',
#    'city': 'East Raymond',
#    'postcode': 'JE18 7AJ'},
#   'work': {'employer': 'Richardson-Watts',
# ...
#    'card_iban': 'GB22LYFJ95732218003692',
#    'card_start': '2020-05-01',
#    'card_exp': '2026-01-01'},
#   'vehicle': {'vehicle_make': 'BMW',
#    'vehicle_model': 'LR3',
#    'vehicle_year': 2010,
#    'vehicle_type': 'Coupe'}},
#  {'personal': {'first_name': 'Vincent',
#    'last_name': 'Swift',
#    'sex': 'Male',
#    'age': 50,
#    'marital_status': 'divorced',
#    'dependants': 1},
#   'address': {'street': 'Flat 22 Mandy squares',
#    'city': 'Shanehaven',
#    'postcode': 'SR18 1EZ'},
#   'work': {'employer': 'Davies, Pearce and Williams',
#    'commute': 16.12,
#    'salary_GBP': 68728,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 30500000000000,
#    'card_cvv': 799,
#    'card_iban': 'GB30EGOC73092573029419',
#    'card_start': '2020-09-01',
#    'card_exp': '2022-04-01'},
#   'vehicle': {'vehicle_make': 'GMC',
#    'vehicle_model': 'Mercedes-AMG GLC Coupe',
#    'vehicle_year': 2012,
#    'vehicle_type': 'Sedan'}},
#  {'personal': {'first_name': 'Lydia',
#    'last_name': 'Reed',
#    'sex': 'Female',
#    'age': 26,
#    'marital_status': 'single',
#    'dependants': 2},
#   'address': {'street': 'Flat 08d Taylor path',
#    'city': 'Smartside',
#    'postcode': 'HU4N 6YX'},
#   'work': {'employer': 'Fisher-Hill',
#    'commute': 8.8,
#    'salary_GBP': 29320,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4640000000000,
#    'card_cvv': 691,
#    'card_iban': 'GB52OFTT26226743199049',
#    'card_start': '2016-09-01',
#    'card_exp': '2027-01-01'},
#   'vehicle': {'vehicle_make': 'FIAT',
#    'vehicle_model': 'Odyssey',
#    'vehicle_year': 2010,
#    'vehicle_type': 'Sedan'}},
#  {'personal': {'first_name': 'Marc',
#    'last_name': 'Payne',
#    'sex': 'Male',
#    'age': 43,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': 'Studio 99 Curtis rest',
#    'city': 'Port Laurenmouth',
#    'postcode': 'BH8P 0UX'},
#   'work': {'employer': 'Morton-Collins',
#    'commute': 16.19,
#    'salary_GBP': 69182,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 3510000000000000,
#    'card_cvv': 349,
#    'card_iban': 'GB55TNII01672776605843',
#    'card_start': '2014-12-01',
#    'card_exp': '2026-06-01'},
#   'vehicle': {'vehicle_make': 'Land Rover',
#    'vehicle_model': 'Avalon',
#    'vehicle_year': 2005,
#    'vehicle_type': 'Hatchback'}},
#  {'personal': {'first_name': 'Ellie',
#    'last_name': 'Wright',
#    'sex': 'Female',
#    'age': 30,
#    'marital_status': 'single',
#    'dependants': 2},
#   'address': {'street': '20 Dean lakes',
#    'city': 'Meganland',
#    'postcode': 'N4E 6XQ'},
#   'work': {'employer': 'Rahman-Parker',
#    'commute': 17.11,
#    'salary_GBP': 75305,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4830000000000,
#    'card_cvv': 349,
#    'card_iban': 'GB97KQVY80253351403949',
#    'card_start': '2018-12-01',
#    'card_exp': '2020-01-01'},
#   'vehicle': {'vehicle_make': 'Chevrolet',
#    'vehicle_model': 'Tracer',
#    'vehicle_year': 2002,
#    'vehicle_type': 'Coupe'}},
#  {'personal': {'first_name': 'Simon',
#    'last_name': 'Murphy',
#    'sex': 'Male',
#    'age': 53,
#    'marital_status': 'single',
#    'dependants': 2},
#   'address': {'street': '12 Potter squares',
#    'city': 'Dominicside',
#    'postcode': 'WC5R 4ES'},
#   'work': {'employer': 'Jennings LLC',
#    'commute': 12.44,
#    'salary_GBP': 46840,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 213000000000000,
#    'card_cvv': 677,
#    'card_iban': 'GB14PIHK07386954050456',
#    'card_start': '2015-06-01',
#    'card_exp': '2018-05-01'},
#   'vehicle': {'vehicle_make': 'Honda',
#    'vehicle_model': 'Silverado 2500 Regular Cab',
#    'vehicle_year': 2017,
#    'vehicle_type': 'Sedan, Hatchback'}},
#  {'personal': {'first_name': 'Catherine',
#    'last_name': 'Lowe',
#    'sex': 'Female',
#    'age': 38,
#    'marital_status': 'married or civil partner',
#    'dependants': 3},
#   'address': {'street': 'Studio 6 McCarthy forest',
#    'city': 'New Damian',
#    'postcode': 'IV7X 8SY'},
#   'work': {'employer': 'Ball, Hughes and Robinson',
#    'commute': 12.18,
#    'salary_GBP': 45491,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 3580000000000000,
#    'card_cvv': 451,
#    'card_iban': 'GB48DASS31162887870344',
#    'card_start': '2018-02-01',
#    'card_exp': '2028-01-01'},
#   'vehicle': {'vehicle_make': 'Dodge',
#    'vehicle_model': 'Thunderbird',
#    'vehicle_year': 1996,
#    'vehicle_type': 'Sedan'}},
#  {'personal': {'first_name': 'Hazel',
#    'last_name': 'Hayward',
#    'sex': 'Female',
#    'age': 84,
#    'marital_status': 'married or civil partner',
#    'dependants': 0},
#   'address': {'street': 'Flat 75 Russell orchard',
#    'city': 'Katiemouth',
#    'postcode': 'SL5 9RD'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 22020,
#    'retired': True,
#    'pension_GBP': 25214},
#   'card': {'card_num': 4080000000000000,
#    'card_cvv': 314,
#    'card_iban': 'GB43GWMR08993795489139',
#    'card_start': '2014-07-01',
#    'card_exp': '2014-08-01'},
#   'vehicle': {'vehicle_make': 'Mercedes-Benz',
#    'vehicle_model': 'Durango',
#    'vehicle_year': '1998',
#    'vehicle_type': 'SUV'}},
#  {'personal': {'first_name': 'Lorraine',
#    'last_name': 'Mistry',
#    'sex': 'Female',
#    'age': 54,
#    'marital_status': 'divorced',
#    'dependants': 4},
#   'address': {'street': '34 Mary locks',
#    'city': 'Tonymouth',
#    'postcode': 'L2 1RH'},
#   'work': {'employer': 'Marshall LLC',
#    'commute': 12.1,
#    'salary_GBP': 45051,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4720000000000000000,
#    'card_cvv': 314,
#    'card_iban': 'GB19NWSV06173347245700',
#    'card_start': '2014-08-01',
#    'card_exp': '2028-07-01'},
#   'vehicle': {'vehicle_make': 'Nissan',
#    'vehicle_model': 'RS 7',
#    'vehicle_year': 1997,
#    'vehicle_type': 'Wagon'}},
#  {'personal': {'first_name': 'Aaron',
#    'last_name': 'Mistry',
#    'sex': 'Male',
#    'age': 83,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': '71 Smith stravenue',
#    'city': 'Lesleytown',
#    'postcode': 'MK0 1HD'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 66220,
#    'retired': True,
#    'pension_GBP': 16436},
#   'card': {'card_num': 38200000000000,
#    'card_cvv': 684,
#    'card_iban': 'GB04ZDRK14974964545353',
#    'card_start': '2020-08-01',
#    'card_exp': '2021-11-01'},
#   'vehicle': {'vehicle_make': 'GMC',
#    'vehicle_model': 'Venture Cargo',
#    'vehicle_year': 2018,
#    'vehicle_type': 'SUV'}},
#  {'personal': {'first_name': 'Kieran',
#    'last_name': 'Thomas',
#    'sex': 'Male',
#    'age': 90,
#    'marital_status': 'married or civil partner',
#    'dependants': 1},
#   'address': {'street': 'Studio 51 Scott summit',
#    'city': 'East Shane',
#    'postcode': 'N2 8WH'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 26654,
#    'retired': True,
#    'pension_GBP': 25776},
#   'card': {'card_num': 2710000000000000,
#    'card_cvv': 863,
#    'card_iban': 'GB32QNPA26143392126454',
#    'card_start': '2010-12-01',
#    'card_exp': '2018-01-01'},
#   'vehicle': {'vehicle_make': 'Kia',
#    'vehicle_model': '3 Series',
#    'vehicle_year': 2003,
#    'vehicle_type': 'Coupe, Convertible'}},
#  {'personal': {'first_name': 'Rachel',
#    'last_name': 'Smart',
#    'sex': 'Female',
#    'age': 29,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': '64 Patterson centers',
#    'city': 'Cliffordburgh',
#    'postcode': 'B24 8EJ'},
#   'work': {'employer': "O'Sullivan, Taylor and Cox",
#    'commute': 18.81,
#    'salary_GBP': 87344,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4840000000000,
#    'card_cvv': 133,
#    'card_iban': 'GB62ONWU62915681538019',
#    'card_start': '2018-10-01',
#    'card_exp': '2029-07-01'},
#   'vehicle': {'vehicle_make': 'Volkswagen',
#    'vehicle_model': 'Sprinter 3500 Cargo',
#    'vehicle_year': 1994,
#    'vehicle_type': 'Pickup'}},
#  {'personal': {'first_name': 'Trevor',
#    'last_name': 'Goddard',
#    'sex': 'Male',
#    'age': 76,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': 'Studio 6 Leslie keys',
#    'city': 'Andreastad',
#    'postcode': 'KA4X 1QR'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 48597,
#    'retired': True,
#    'pension_GBP': 28990},
#   'card': {'card_num': 676000000000,
#    'card_cvv': 909,
#    'card_iban': 'GB27KLPB12136922168928',
#    'card_start': '2017-10-01',
#    'card_exp': '2028-12-01'},
#   'vehicle': {'vehicle_make': 'Scion',
#    'vehicle_model': 'Vibe',
#    'vehicle_year': 2005,
#    'vehicle_type': 'Wagon'}},
#  {'personal': {'first_name': 'Katy',
#    'last_name': 'Knight',
#    'sex': 'Female',
#    'age': 33,
#    'marital_status': 'married or civil partner',
#    'dependants': 1},
#   'address': {'street': '133 Jacob spur',
#    'city': 'East Mathew',
#    'postcode': 'M0S 0GJ'},
#   'work': {'employer': 'Archer Ltd',
#    'commute': 7.77,
#    'salary_GBP': 25115,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 180000000000000,
#    'card_cvv': 292,
#    'card_iban': 'GB78HGUW98653392316629',
#    'card_start': '2015-12-01',
#    'card_exp': '2020-07-01'},
#   'vehicle': {'vehicle_make': 'Suzuki',
#    'vehicle_model': 'Silverado 2500 HD Extended Cab',
#    'vehicle_year': 2012,
#    'vehicle_type': 'Pickup'}},
#  {'personal': {'first_name': 'Bradley',
#    'last_name': 'Thompson',
#    'sex': 'Male',
#    'age': 30,
#    'marital_status': 'married or civil partner',
#    'dependants': 1},
#   'address': {'street': 'Studio 58D Hill dam',
#    'city': 'West Owenview',
#    'postcode': 'B48 1FB'},
#   'work': {'employer': 'Ashton, Tucker and Davies',
#    'commute': 11.68,
#    'salary_GBP': 42838,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4550000000000000,
#    'card_cvv': 401,
#    'card_iban': 'GB44HFCB98336374626479',
#    'card_start': '2014-08-01',
#    'card_exp': '2032-04-01'},
#   'vehicle': {'vehicle_make': 'Freightliner',
#    'vehicle_model': 'Nautilus',
#    'vehicle_year': 2011,
#    'vehicle_type': 'Wagon, Convertible'}},
#  {'personal': {'first_name': 'Antony',
#    'last_name': 'Edwards',
#    'sex': 'Male',
#    'age': 39,
#    'marital_status': 'married or civil partner',
#    'dependants': 1},
#   'address': {'street': '54 Josephine point',
#    'city': 'South William',
#    'postcode': 'WN6B 7PF'},
#   'work': {'employer': 'Roberts, Thompson and Thomas',
#    'commute': 8.85,
#    'salary_GBP': 29557,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4620000000000000,
#    'card_cvv': 295,
#    'card_iban': 'GB43NXOW18067474519071',
#    'card_start': '2019-12-01',
#    'card_exp': '2023-11-01'},
#   'vehicle': {'vehicle_make': 'Volkswagen',
#    'vehicle_model': 'Eclipse',
#    'vehicle_year': 1997,
#    'vehicle_type': 'SUV'}},
#  {'personal': {'first_name': 'Simon',
#    'last_name': 'Pollard',
#    'sex': 'Male',
#    'age': 39,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': 'Studio 19 Booth freeway',
#    'city': 'West Louisehaven',
#    'postcode': 'GU8 4EX'},
#   'work': {'employer': 'Kennedy LLC',
#    'commute': 19.84,
#    'salary_GBP': 95080,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4890000000000000,
#    'card_cvv': 578,
#    'card_iban': 'GB02UMII22298941128830',
#    'card_start': '2014-08-01',
#    'card_exp': '2019-12-01'},
#   'vehicle': {'vehicle_make': 'Jaguar',
#    'vehicle_model': 'Mystique',
#    'vehicle_year': 2017,
#    'vehicle_type': 'Coupe'}},
#  {'personal': {'first_name': 'Amelia',
#    'last_name': 'Cooper',
#    'sex': 'Female',
#    'age': 69,
#    'marital_status': 'single',
#    'dependants': 2},
#   'address': {'street': '66 Hutchinson run',
#    'city': 'New Joanneton',
#    'postcode': 'B3G 0RL'},
#   'work': {'employer': 'Jones, Simmons and Wyatt',
#    'commute': 15.49,
#    'salary_GBP': 64712,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4150000000000000,
#    'card_cvv': 18,
#    'card_iban': 'GB09KABU79666494796792',
#    'card_start': '2015-10-01',
#    'card_exp': '2024-12-01'},
#   'vehicle': {'vehicle_make': 'Mercedes-Benz',
#    'vehicle_model': 'M6',
#    'vehicle_year': 2014,
#    'vehicle_type': 'Sedan'}},
#  {'personal': {'first_name': 'Joel',
#    'last_name': 'Sykes',
#    'sex': 'Male',
#    'age': 90,
#    'marital_status': 'single',
#    'dependants': 3},
#   'address': {'street': 'Flat 35h Kathleen extensions',
#    'city': 'Lake Owenmouth',
#    'postcode': 'G3 8PL'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 49928,
#    'retired': True,
#    'pension_GBP': 15650},
#   'card': {'card_num': 213000000000000,
#    'card_cvv': 911,
#    'card_iban': 'GB60TSJL96687346319661',
#    'card_start': '2015-06-01',
#    'card_exp': '2026-07-01'},
#   'vehicle': {'vehicle_make': 'Nissan',
#    'vehicle_model': 'Prizm',
#    'vehicle_year': 1994,
#    'vehicle_type': 'Van/Minivan'}},
#  {'personal': {'first_name': 'Leonard',
#    'last_name': 'Clark',
#    'sex': 'Male',
#    'age': 48,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': 'Studio 6 Heather prairie',
#    'city': 'North Amelia',
#    'postcode': 'E9 0HB'},
#   'work': {'employer': 'Phillips-Pope',
#    'commute': 18.44,
#    'salary_GBP': 84645,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 3560000000000000,
#    'card_cvv': 908,
#    'card_iban': 'GB45UVZH05043505193524',
#    'card_start': '2019-04-01',
#    'card_exp': '2026-08-01'},
#   'vehicle': {'vehicle_make': 'Saturn',
#    'vehicle_model': 'Convertible',
#    'vehicle_year': 2015,
#    'vehicle_type': 'Van/Minivan'}},
#  {'personal': {'first_name': 'Jemma',
#    'last_name': 'Jones',
#    'sex': 'Female',
#    'age': 22,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': 'Flat 3 Davies run',
#    'city': 'Greenshire',
#    'postcode': 'E7 4UJ'},
#   'work': {'employer': 'Hughes LLC',
#    'commute': 19.61,
#    'salary_GBP': 93314,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 3590000000000000,
#    'card_cvv': 675,
#    'card_iban': 'GB88EGZV32518465934497',
#    'card_start': '2005-12-01',
#    'card_exp': '2028-07-01'},
#   'vehicle': {'vehicle_make': 'Toyota',
#    'vehicle_model': 'Yukon',
#    'vehicle_year': 2015,
#    'vehicle_type': 'Van/Minivan'}},
#  {'personal': {'first_name': 'Nicola',
#    'last_name': 'Walker',
#    'sex': 'Female',
#    'age': 38,
#    'marital_status': 'single',
#    'dependants': 1},
#   'address': {'street': 'Flat 7 Barber motorway',
#    'city': 'Burrowsshire',
#    'postcode': 'L62 8TA'},
#   'work': {'employer': 'Bailey Group',
#    'commute': 6.66,
#    'salary_GBP': 20940,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 3580000000000000,
#    'card_cvv': 679,
#    'card_iban': 'GB81SVHK17718594367943',
#    'card_start': '2013-01-01',
#    'card_exp': '2029-05-01'},
#   'vehicle': {'vehicle_make': 'Ford',
#    'vehicle_model': 'S6',
#    'vehicle_year': 2020,
#    'vehicle_type': 'Sedan'}},
#  {'personal': {'first_name': 'Paul',
#    'last_name': 'Thomson',
#    'sex': 'Male',
#    'age': 45,
#    'marital_status': 'married or civil partner',
#    'dependants': 3},
#   'address': {'street': '00 Tony forks',
#    'city': 'Abbiebury',
#    'postcode': 'NP4 1JL'},
#   'work': {'employer': 'Foster-Price',
#    'commute': 18.13,
#    'salary_GBP': 82412,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4090000000000000,
#    'card_cvv': 775,
#    'card_iban': 'GB14LLBD59118062249339',
#    'card_start': '2019-04-01',
#    'card_exp': '2023-05-01'},
#   'vehicle': {'vehicle_make': 'Scion',
#    'vehicle_model': 'Ram 1500 Quad Cab',
#    'vehicle_year': 2015,
#    'vehicle_type': 'Pickup'}},
#  {'personal': {'first_name': 'Sheila',
#    'last_name': 'Russell',
#    'sex': 'Female',
#    'age': 80,
#    'marital_status': 'single',
#    'dependants': 1},
#   'address': {'street': 'Flat 9 Mohamed route',
#    'city': 'West Glen',
#    'postcode': 'LL3M 4WS'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 25788,
#    'retired': True,
#    'pension_GBP': 22869},
#   'card': {'card_num': 180000000000000,
#    'card_cvv': 903,
#    'card_iban': 'GB45ORXV49380519147072',
#    'card_start': '2014-12-01',
#    'card_exp': '2016-01-01'},
#   'vehicle': {'vehicle_make': 'Geo',
#    'vehicle_model': 'S7',
#    'vehicle_year': 1993,
#    'vehicle_type': 'Van/Minivan'}}]

# %% [markdown]
# ### Task 4: Converting our new list of dict to json format - a list of dictionaries, where each index of the list is a dictionary representing a singular person.
#
# __A function that will be used to write json files will be created.__
# - This function will take two arguments: the name of the list to be written and the name of the new file to be created

# %%
#creating the function
#the function takes 2 arguments
def create_json(list_name,file_name):
    with open(file_name, mode='w') as processed_json:
        json.dump(list_name, processed_json)

#creating the object for the new filename to be created
#calling the function, which then creates the new file.
#in this case, the new file is called processed.
processed_json = 'processed.json'
create_json(all_customers,processed_json)

# %% [markdown]
# ### Task 5: You should create two additional file outputs, retired.json and employed.json, these should contain all retired customers (as indicated by the retired field in the CSV), and all employed customers respectively (as indicated by the employer field in the CSV) and be in the JSON data format.

# %%
#creating the list comprehensions for the new lists
retired_customers = []
employed_customers = []
not_retired_employed = [] #created to handle exceptions

#iterating through the all_customers list to separate the new lists we want
#This iteration is done based on set conditions
#if row is retired = TRUE then the customer is retired
#if row employed is not equal to N/A, then the customer is employed

for row_no, row in enumerate (all_customers):
    if row['work'] ['retired'] == True:
        retired_customers.append(row)
    elif row['work'] ['employer'] != 'N/A':
        employed_customers.append(row)
    else:
        not_retired_employed.append(row) #created to handle exceptions

#creating the objects for the filename to be used for creating the json files
retired_json = 'retired.json'
employed_json = 'employed.json'

#calling the previously created function for creating json files
#the inputs are the list (in this case retired and employed) and the objects for the file names
create_json(retired_customers,retired_json)
create_json(employed_customers,employed_json)

print('The number of retired customers are:',len(retired_customers))
print('The number of employed customers are:',len(employed_customers))
# Out:
# The number of retired customers are: 246
# The number of employed customers are: 754

# %%
retired_customers
# Out:
# [{'personal': {'first_name': 'Kieran',
#    'last_name': 'Wilson',
#    'sex': 'Male',
#    'age': 89,
#    'marital_status': 'married or civil partner',
#    'dependants': 3},
#   'address': {'street': '70 Lydia isle',
#    'city': 'Lake Conor',
#    'postcode': 'S71 7XZ'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 72838,
#    'retired': True,
#    'pension_GBP': 7257},
#   'card': {'card_num': 676000000000,
#    'card_cvv': 875,
#    'card_iban': 'GB62PQKB71416034141571',
#    'card_start': '2018-08-01',
#    'card_exp': '2027-11-01'},
#   'vehicle': {'vehicle_make': 'Hyundai',
#    'vehicle_model': 'Bonneville',
#    'vehicle_year': 2009,
#    'vehicle_type': 'Pickup'}},
#  {'personal': {'first_name': 'Clive',
#    'last_name': 'Evans',
#    'sex': 'Male',
#    'age': 67,
#    'marital_status': 'single',
#    'dependants': 1},
#   'address': {'street': '81 Goodwin dam',
#    'city': 'Griffinstad',
#    'postcode': 'G3 7ZX'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 27964,
#    'retired': True,
#    'pension_GBP': 28075},
#   'card': {'card_num': 213000000000000,
#    'card_cvv': 389,
#    'card_iban': 'GB04VSAZ69128049616822',
#    'card_start': '2015-07-01',
#    'card_exp': '2027-04-01'},
#   'vehicle': {'vehicle_make': 'Volvo',
#    'vehicle_model': 'Express 3500 Passenger',
#    'vehicle_year': 2013,
#    'vehicle_type': 'SUV'}},
#  {'personal': {'first_name': 'Malcolm',
#    'last_name': 'Hamilton',
#    'sex': 'Male',
#    'age': 87,
#    'marital_status': 'single',
#    'dependants': 2},
#   'address': {'street': 'Studio 77c Gail tunnel',
#    'city': 'Garyberg',
#    'postcode': 'S7W 4DW'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 66157,
#    'retired': True,
#    'pension_GBP': 29587},
#   'card': {'card_num': 213000000000000,
#    'card_cvv': 766,
#    'card_iban': 'GB74TXVQ82130006568515',
#    'card_start': '2013-10-01',
#    'card_exp': '2013-10-01'},
#   'vehicle': {'vehicle_make': 'Dodge',
#    'vehicle_model': 'Impreza',
#    'vehicle_year': 2015,
#    'vehicle_type': 'Sedan'}},
#  {'personal': {'first_name': 'Jade',
#    'last_name': 'John',
#    'sex': 'Female',
#    'age': 78,
#    'marital_status': 'married or civil partner',
#    'dependants': 4},
#   'address': {'street': '8 Bray row',
#    'city': 'Daviestown',
#    'postcode': 'S2H 5RE'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 59891,
#    'retired': True,
#    'pension_GBP': 24712},
#   'card': {'card_num': 4550000000000000,
#    'card_cvv': 22,
#    'card_iban': 'GB76WOAN35375600936407',
#    'card_start': '2010-12-01',
#    'card_exp': '2019-12-01'},
#   'vehicle': {'vehicle_make': 'Nissan',
#    'vehicle_model': 'LC',
#    'vehicle_year': 2012,
#    'vehicle_type': 'SUV'}},
#  {'personal': {'first_name': 'Helen',
#    'last_name': 'Kaur',
#    'sex': 'Female',
#    'age': 82,
#    'marital_status': 'single',
#    'dependants': 5},
#   'address': {'street': 'Flat 47 Godfrey road',
#    'city': 'West Brianfurt',
#    'postcode': 'S6G 3HB'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 80297,
#    'retired': True,
#    'pension_GBP': 28731},
#   'card': {'card_num': 5540000000000000,
#    'card_cvv': 465,
#    'card_iban': 'GB42TNFG09550061109890',
#    'card_start': '2018-01-01',
#    'card_exp': '2028-07-01'},
#   'vehicle': {'vehicle_make': 'Acura',
#    'vehicle_model': 'G',
#    'vehicle_year': 1998,
#    'vehicle_type': 'SUV'}},
#  {'personal': {'first_name': 'Adam',
#    'last_name': 'Wright',
#    'sex': 'Male',
#    'age': 83,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': 'Flat 32 Sharp prairie',
#    'city': 'Marcusstad',
#    'postcode': 'AB57 0ZN'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 70109,
#    'retired': True,
#    'pension_GBP': 30115},
#   'card': {'card_num': 2430000000000000,
#    'card_cvv': 453,
#    'card_iban': 'GB76KUNW91632428208056',
#    'card_start': '2002-12-01',
#    'card_exp': '2024-03-01'},
#   'vehicle': {'vehicle_make': 'GMC',
#    'vehicle_model': 'Frontier Crew Cab',
#    'vehicle_year': 1998,
#    'vehicle_type': 'Van/Minivan'}},
#  {'personal': {'first_name': 'Danielle',
#    'last_name': 'Robertson',
#    'sex': 'Female',
#    'age': 65,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': '8 Michael cliff',
#    'city': 'Joanchester',
#    'postcode': 'B8E 0XR'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 57953,
#    'retired': True,
#    'pension_GBP': 8022},
#   'card': {'card_num': 30300000000000,
#    'card_cvv': 479,
#    'card_iban': 'GB77BKAA88748168755170',
#    'card_start': '2014-05-01',
#    'card_exp': '2027-12-01'},
#   'vehicle': {'vehicle_make': 'Jaguar',
#    'vehicle_model': 'Odyssey',
#    'vehicle_year': 1997,
#    'vehicle_type': 'Hatchback'}},
#  {'personal': {'first_name': 'Vanessa',
#    'last_name': 'Kay',
#    'sex': 'Female',
#    'age': 91,
#    'marital_status': 'single',
#    'dependants': 2},
#   'address': {'street': '7 Williams forks',
#    'city': 'Cookside',
#    'postcode': 'N6 2YZ'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 81220,
#    'retired': True,
#    'pension_GBP': 30866},
#   'card': {'card_num': 4230000000000,
#    'card_cvv': 752,
#    'card_iban': 'GB75HZCQ22453289425740',
#    'card_start': '2019-06-01',
#    'card_exp': '2021-11-01'},
#   'vehicle': {'vehicle_make': 'Chevrolet',
#    'vehicle_model': 'Viper',
#    'vehicle_year': 2015,
#    'vehicle_type': 'Pickup'}},
#  {'personal': {'first_name': 'Sheila',
#    'last_name': 'Woodward',
#    'sex': 'Female',
#    'age': 84,
#    'marital_status': 'single',
#    'dependants': 1},
#   'address': {'street': '1 Holt knoll',
#    'city': 'Ianview',
#    'postcode': 'L93 2QY'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 59223,
#    'retired': True,
#    'pension_GBP': 24080},
#   'card': {'card_num': 2280000000000000,
#    'card_cvv': 243,
#    'card_iban': 'GB28KWDH09406690563679',
#    'card_start': '2006-12-01',
#    'card_exp': '2017-09-01'},
#   'vehicle': {'vehicle_make': 'Audi',
#    'vehicle_model': 'Celica',
#    'vehicle_year': 2016,
#    'vehicle_type': 'Van/Minivan'}},
#  {'personal': {'first_name': 'Geoffrey',
#    'last_name': 'Ward',
#    'sex': 'Male',
#    'age': 72,
#    'marital_status': 'single',
#    'dependants': 1},
#   'address': {'street': '9 Randall center',
#    'city': 'Donaldmouth',
#    'postcode': 'S5 3GT'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 97406,
#    'retired': True,
#    'pension_GBP': 21838},
#   'card': {'card_num': 377000000000000,
#    'card_cvv': 434,
#    'card_iban': 'GB54ZXCM95740026097623',
#    'card_start': '2014-03-01',
#    'card_exp': '2024-08-01'},
#   'vehicle': {'vehicle_make': 'Lincoln',
#    'vehicle_model': 'Silverado 3500 HD Regular Cab',
#    'vehicle_year': 2015,
#    'vehicle_type': 'Van/Minivan'}},
#  {'personal': {'first_name': 'Adam',
#    'last_name': 'Walsh',
#    'sex': 'Male',
#    'age': 86,
#    'marital_status': 'married or civil partner',
#    'dependants': 3},
#   'address': {'street': '57 Edward burg',
#    'city': 'Shanefurt',
#    'postcode': 'FK4B 4HU'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 26452,
#    'retired': True,
#    'pension_GBP': 10651},
#   'card': {'card_num': 379000000000000,
#    'card_cvv': 150,
#    'card_iban': 'GB45RNEO63895090850522',
#    'card_start': '2015-01-01',
#    'card_exp': '2025-12-01'},
#   'vehicle': {'vehicle_make': 'Subaru',
#    'vehicle_model': 'Commander',
#    'vehicle_year': 1995,
#    'vehicle_type': 'Sedan, Hatchback'}},
#  {'personal': {'first_name': 'Jeremy',
#    'last_name': 'Richardson',
#    'sex': 'Male',
#    'age': 88,
#    'marital_status': 'single',
#    'dependants': 2},
#   'address': {'street': 'Studio 7 Hill inlet',
#    'city': 'Barnesfurt',
#    'postcode': 'M5 6LA'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 92899,
#    'retired': True,
#    'pension_GBP': 36202},
#   'card': {'card_num': 3570000000000000,
#    'card_cvv': 734,
#    'card_iban': 'GB68DNZL38729225311976',
#    'card_start': '2018-11-01',
#    'card_exp': '2019-06-01'},
#   'vehicle': {'vehicle_make': 'Ford',
#    'vehicle_model': 'ES',
#    'vehicle_year': 1998,
#    'vehicle_type': 'Pickup'}},
#  {'personal': {'first_name': 'Declan',
#    'last_name': 'Smith',
#    'sex': 'Male',
#    'age': 75,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': 'Studio 05p Gardner fords',
#    'city': 'North Bradley',
#    'postcode': 'BB25 7EP'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 59872,
#    'retired': True,
#    'pension_GBP': 19073},
#   'card': {'card_num': 348000000000000,
#    'card_cvv': 915,
#    'card_iban': 'GB35RZFZ68276656752362',
#    'card_start': '2019-09-01',
#    'card_exp': '2022-02-01'},
#   'vehicle': {'vehicle_make': 'Cadillac',
#    'vehicle_model': 'Rodeo',
#    'vehicle_year': 2013,
#    'vehicle_type': 'Pickup'}},
#  {'personal': {'first_name': 'Abbie',
#    'last_name': 'Gill',
#    'sex': 'Female',
#    'age': 72,
#    'marital_status': 'single',
#    'dependants': 2},
#   'address': {'street': 'Studio 2 Carpenter prairie',
#    'city': 'West Joyce',
#    'postcode': 'N9 4NW'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 62907,
#    'retired': True,
#    'pension_GBP': 8418},
#   'card': {'card_num': 4700000000000000,
#    'card_cvv': 673,
#    'card_iban': 'GB40VSFG91266868613507',
#    'card_start': '2019-03-01',
#    'card_exp': '2022-04-01'},
#   'vehicle': {'vehicle_make': 'Cadillac',
#    'vehicle_model': 'Escape',
#    'vehicle_year': 1996,
#    'vehicle_type': 'Sedan, Hatchback'}},
#  {'personal': {'first_name': 'Tracey',
#    'last_name': 'Knight',
#    'sex': 'Female',
#    'age': 87,
#    'marital_status': 'single',
#    'dependants': 1},
#   'address': {'street': '8 King roads',
#    'city': 'Helenmouth',
#    'postcode': 'M3 5FE'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 90989,
#    'retired': True,
#    'pension_GBP': 19833},
#   'card': {'card_num': 3530000000000000,
#    'card_cvv': 889,
#    'card_iban': 'GB32HKXY65019270186072',
#    'card_start': '2014-07-01',
#    'card_exp': '2025-08-01'},
#   'vehicle': {'vehicle_make': 'Mitsubishi',
#    'vehicle_model': 'Wrangler',
#    'vehicle_year': 2005,
#    'vehicle_type': 'Van/Minivan'}},
#  {'personal': {'first_name': 'Peter',
#    'last_name': 'Fox',
#    'sex': 'Male',
#    'age': 90,
#    'marital_status': 'single',
#    'dependants': 2},
#   'address': {'street': 'Flat 05 Sally lock',
#    'city': 'Port Paul',
#    'postcode': 'DA92 4YE'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 66210,
#    'retired': True,
#    'pension_GBP': 22344},
#   'card': {'card_num': 3540000000000000,
#    'card_cvv': 991,
#    'card_iban': 'GB74IEMW86147848359945',
#    'card_start': '2020-05-01',
#    'card_exp': '2028-02-01'},
#   'vehicle': {'vehicle_make': 'Mercedes-Benz',
#    'vehicle_model': 'HHR',
#    'vehicle_year': 2009,
#    'vehicle_type': 'SUV'}},
#  {'personal': {'first_name': 'Shane',
#    'last_name': 'Martin',
#    'sex': 'Male',
#    'age': 84,
#    'marital_status': 'married or civil partner',
#    'dependants': 3},
#   'address': {'street': '197 Hughes light',
#    'city': 'Simpsonview',
#    'postcode': 'E5 1EY'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 77566,
#    'retired': True,
#    'pension_GBP': 16699},
#   'card': {'card_num': 30200000000000,
#    'card_cvv': 64,
#    'card_iban': 'GB77WZQH05366315429846',
#    'card_start': '2016-06-01',
#    'card_exp': '2021-06-01'},
#   'vehicle': {'vehicle_make': 'Ford',
#    'vehicle_model': 'Grand Prix',
#    'vehicle_year': 2017,
#    'vehicle_type': 'SUV'}},
#  {'personal': {'first_name': 'Ashley',
#    'last_name': 'Atkins',
#    'sex': 'Male',
#    'age': 78,
#    'marital_status': 'single',
#    'dependants': 2},
#   'address': {'street': 'Studio 35 Davison bridge',
#    'city': 'Morganhaven',
#    'postcode': 'N06 0GR'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 33081,
#    'retired': True,
#    'pension_GBP': 29483},
#   'card': {'card_num': 4510000000000,
#    'card_cvv': 9263,
#    'card_iban': 'GB50DJLM41916388959252',
#    'card_start': '2017-10-01',
#    'card_exp': '2020-07-01'},
#   'vehicle': {'vehicle_make': 'GMC',
#    'vehicle_model': 'Metris WORKER Passenger',
#    'vehicle_year': 1996,
#    'vehicle_type': 'Sedan'}},
#  {'personal': {'first_name': 'Owen',
#    'last_name': 'Clarke',
#    'sex': 'Male',
#    'age': 77,
#    'marital_status': 'single',
#    'dependants': 2},
#   'address': {'street': '451 Fry forges',
#    'city': 'New Yvonnefurt',
#    'postcode': 'B56 9JR'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 93472,
#    'retired': True,
#    'pension_GBP': 25180},
#   'card': {'card_num': 4210000000000000000,
#    'card_cvv': 665,
#    'card_iban': 'GB52NDLB99095695780485',
#    'card_start': '2014-07-01',
#    'card_exp': '2016-10-01'},
#   'vehicle': {'vehicle_make': 'Ford',
#    'vehicle_model': 'Escalade',
#    'vehicle_year': 2017,
#    'vehicle_type': 'Sedan'}},
#  {'personal': {'first_name': 'Lucy',
#    'last_name': 'Bradley',
#    'sex': 'Female',
#    'age': 90,
#    'marital_status': 'married or civil partner',
#    'dependants': 1},
#   'address': {'street': 'Studio 9 Morgan wells',
#    'city': 'Lake Hazel',
#    'postcode': 'W1W 4PF'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 34869,
#    'retired': True,
#    'pension_GBP': 6992},
#   'card': {'card_num': 502000000000,
#    'card_cvv': 592,
#    'card_iban': 'GB05YRVL77089575786362',
#    'card_start': '2002-12-01',
#    'card_exp': '2028-09-01'},
#   'vehicle': {'vehicle_make': 'Saturn',
#    'vehicle_model': 'Discovery',
#    'vehicle_year': 1998,
#    'vehicle_type': 'SUV'}},
#  {'personal': {'first_name': 'Georgia',
#    'last_name': 'McKenzie',
#    'sex': 'Female',
#    'age': 74,
#    'marital_status': 'divorced',
#    'dependants': 2},
#   'address': {'street': '20 Martyn ferry',
#    'city': 'Jonestown',
#    'postcode': 'CT40 0HS'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 19405,
#    'retired': True,
#    'pension_GBP': 16945},
#   'card': {'card_num': 3560000000000000,
#    'card_cvv': 107,
#    'card_iban': 'GB15NUJZ64936781419815',
#    'card_start': '2019-09-01',
#    'card_exp': '2020-06-01'},
#   'vehicle': {'vehicle_make': 'Lexus',
#    'vehicle_model': 'Beetle',
#    'vehicle_year': 2011,
#    'vehicle_type': 'SUV'}},
#  {'personal': {'first_name': 'Joel',
#    'last_name': 'Williams',
#    'sex': 'Male',
#    'age': 79,
#    'marital_status': 'divorced',
#    'dependants': 2},
#   'address': {'street': 'Flat 72Z Clark estates',
#    'city': 'West Garry',
#    'postcode': 'KW9 6QU'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 27904,
#    'retired': True,
#    'pension_GBP': 18184},
#   'card': {'card_num': 3520000000000000,
#    'card_cvv': 333,
#    'card_iban': 'GB04OPMS12664739515711',
#    'card_start': '2016-11-01',
#    'card_exp': '2019-08-01'},
#   'vehicle': {'vehicle_make': 'Chevrolet',
#    'vehicle_model': 'F350 Super Duty Regular Cab',
#    'vehicle_year': 2005,
#    'vehicle_type': 'Coupe, Sedan, Convertible'}},
#  {'personal': {'first_name': 'Ashleigh',
#    'last_name': 'Ryan',
#    'sex': 'Female',
#    'age': 75,
#    'marital_status': 'married or civil partner',
#    'dependants': 1},
#   'address': {'street': 'Studio 45c Burton way',
#    'city': 'North Ronaldland',
#    'postcode': 'BS0R 3AL'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 54451,
#    'retired': True,
#    'pension_GBP': 38315},
#   'card': {'card_num': 5590000000000000,
#    'card_cvv': 231,
#    'card_iban': 'GB76ZNJT93939806204998',
#    'card_start': '2013-08-01',
#    'card_exp': '2015-03-01'},
#   'vehicle': {'vehicle_make': 'BMW',
#    'vehicle_model': 'GLS',
#    'vehicle_year': 2015,
#    'vehicle_type': 'Van/Minivan'}},
#  {'personal': {'first_name': 'Michael',
#    'last_name': 'Akhtar',
#    'sex': 'Male',
#    'age': 90,
#    'marital_status': 'married or civil partner',
#    'dependants': 1},
#   'address': {'street': '2 Lewis estates',
#    'city': 'Lake Iain',
#    'postcode': 'M4T 7PB'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 40184,
#    'retired': True,
#    'pension_GBP': 24818},
#   'card': {'card_num': 348000000000000,
#    'card_cvv': 282,
#    'card_iban': 'GB33NHPT55918111814942',
#    'card_start': '2016-06-01',
#    'card_exp': '2028-06-01'},
#   'vehicle': {'vehicle_make': 'Ford',
#    'vehicle_model': 'SVX',
#    'vehicle_year': 2011,
#    'vehicle_type': 'Pickup'}},
#  {'personal': {'first_name': 'Francesca',
#    'last_name': 'Barnes',
#    'sex': 'Female',
#    'age': 80,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': 'Studio 07 Harvey branch',
#    'city': 'North Lauraside',
#    'postcode': 'M4 9JG'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 77914,
#    'retired': True,
#    'pension_GBP': 20080},
#   'card': {'card_num': 4440000000000000,
#    'card_cvv': 873,
#    'card_iban': 'GB68OGXV47976181686007',
#    'card_start': '2019-04-01',
#    'card_exp': '2024-03-01'},
#   'vehicle': {'vehicle_make': 'Toyota',
#    'vehicle_model': 'Grand Cherokee',
#    'vehicle_year': 2017,
#    'vehicle_type': 'Hatchback, Sedan'}},
#  {'personal': {'first_name': 'Kathryn',
#    'last_name': 'Ashton',
#    'sex': 'Female',
#    'age': 68,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': 'Flat 82 Ruth haven',
#    'city': 'West Hughville',
#    'postcode': 'W6 1AJ'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 25565,
#    'retired': True,
#    'pension_GBP': 18806},
#   'card': {'card_num': 4760000000000000,
#    'card_cvv': 2415,
#    'card_iban': 'GB39TASS76050202879400',
#    'card_start': '2018-03-01',
#    'card_exp': '2028-12-01'},
#   'vehicle': {'vehicle_make': 'Ford',
#    'vehicle_model': '911',
#    'vehicle_year': 2003,
#    'vehicle_type': 'Wagon'}},
#  {'personal': {'first_name': 'Keith',
#    'last_name': 'Williamson',
#    'sex': 'Male',
#    'age': 86,
#    'marital_status': 'married or civil partner',
#    'dependants': 1},
#   'address': {'street': '18 King isle',
#    'city': 'East Caroline',
#    'postcode': 'SE25 0EH'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 97308,
#    'retired': True,
#    'pension_GBP': 17419},
#   'card': {'card_num': 4210000000000000,
#    'card_cvv': 533,
#    'card_iban': 'GB04PRCL86743699392708',
#    'card_start': '2018-09-01',
#    'card_exp': '2027-05-01'},
#   'vehicle': {'vehicle_make': 'Nissan',
#    'vehicle_model': 'X-Type',
#    'vehicle_year': 2013,
#    'vehicle_type': 'Pickup'}},
#  {'personal': {'first_name': 'Julie',
#    'last_name': 'Gray',
#    'sex': 'Female',
#    'age': 89,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': '3 Gilbert freeway',
#    'city': 'South Victoria',
#    'postcode': 'CV1 3SB'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 87281,
#    'retired': True,
#    'pension_GBP': 5258},
#   'card': {'card_num': 4050000000000000,
#    'card_cvv': 669,
#    'card_iban': 'GB75ZJUX75000413809933',
#    'card_start': '2015-12-01',
#    'card_exp': '2017-07-01'},
#   'vehicle': {'vehicle_make': 'Volkswagen',
#    'vehicle_model': 'Sierra (Classic) 1500 Crew Cab',
#    'vehicle_year': 2001,
#    'vehicle_type': 'Hatchback, Convertible'}},
#  {'personal': {'first_name': 'Abdul',
#    'last_name': 'Smith',
#    'sex': 'Male',
#    'age': 77,
#    'marital_status': 'single',
#    'dependants': 2},
#   'address': {'street': 'Flat 28 Johnson square',
#    'city': 'Waltersstad',
#    'postcode': 'GU06 9NJ'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 25474,
#    'retired': True,
#    'pension_GBP': 26096},
#   'card': {'card_num': 30600000000000,
#    'card_cvv': 972,
#    'card_iban': 'GB65WQAM06002206517572',
#    'card_start': '2020-09-01',
#    'card_exp': '2021-04-01'},
#   'vehicle': {'vehicle_make': 'Dodge',
#    'vehicle_model': 'Camaro',
#    'vehicle_year': 2001,
#    'vehicle_type': 'SUV'}},
#  {'personal': {'first_name': 'Jamie',
#    'last_name': 'Williams',
#    'sex': 'Male',
#    'age': 77,
#    'marital_status': 'married or civil partner',
#    'dependants': 3},
#   'address': {'street': 'Flat 2 Cheryl tunnel',
#    'city': 'North Cherylstad',
#    'postcode': 'SO2R 7JD'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 18127,
#    'retired': True,
#    'pension_GBP': 34750},
#   'card': {'card_num': 3600000000000000,
#    'card_cvv': 383,
#    'card_iban': 'GB44RYBA89420601702356',
#    'card_start': '2013-03-01',
#    'card_exp': '2027-01-01'},
#   'vehicle': {'vehicle_make': 'Pontiac',
#    'vehicle_model': 'Avalon',
#    'vehicle_year': 2016,
#    'vehicle_type': 'Convertible'}},
#  {'personal': {'first_name': 'Emma',
#    'last_name': 'Newton',
#    'sex': 'Female',
#    'age': 89,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': 'Studio 0 Dale shoal',
#    'city': 'Anthonytown',
#    'postcode': 'E4T 5WT'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 26495,
#    'retired': True,
#    'pension_GBP': 28188},
#   'card': {'card_num': 4360000000000000,
#    'card_cvv': 553,
#    'card_iban': 'GB44ZNBI02161896110580',
#    'card_start': '2011-11-01',
#    'card_exp': '2024-09-01'},
#   'vehicle': {'vehicle_make': 'Mercedes-Benz',
#    'vehicle_model': 'Montero Sport',
#    'vehicle_year': 1994,
#    'vehicle_type': 'Coupe, Convertible'}},
#  {'personal': {'first_name': 'Fiona',
#    'last_name': 'Slater',
#    'sex': 'Female',
#    'age': 89,
#    'marital_status': 'married or civil partner',
#    'dependants': 3},
#   'address': {'street': '232 Nathan cape',
#    'city': 'Jenniferborough',
#    'postcode': 'N0 7PJ'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 75219,
#    'retired': True,
#    'pension_GBP': 16798},
#   'card': {'card_num': 4750000000000000000,
#    'card_cvv': 272,
#    'card_iban': 'GB63ZBVH58450370260784',
#    'card_start': '2020-02-01',
#    'card_exp': '2023-06-01'},
#   'vehicle': {'vehicle_make': 'MINI',
#    'vehicle_model': 'Ram Wagon 3500',
#    'vehicle_year': 2009,
#    'vehicle_type': 'Pickup'}},
#  {'personal': {'first_name': 'Beverley',
#    'last_name': 'Clements',
#    'sex': 'Female',
#    'age': 81,
#    'marital_status': 'single',
#    'dependants': 3},
#   'address': {'street': '4 Griffiths lane',
#    'city': 'Robinhaven',
#    'postcode': 'W2K 7FU'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 93179,
#    'retired': True,
#    'pension_GBP': 33323},
#   'card': {'card_num': 4400000000000,
#    'card_cvv': 127,
#    'card_iban': 'GB23KSDI18325875892927',
#    'card_start': '2017-07-01',
#    'card_exp': '2024-10-01'},
#   'vehicle': {'vehicle_make': 'Lexus',
#    'vehicle_model': 'Sportage',
#    'vehicle_year': 1996,
#    'vehicle_type': 'Convertible'}},
#  {'personal': {'first_name': 'Abigail',
#    'last_name': 'Bates',
#    'sex': 'Female',
#    'age': 87,
#    'marital_status': 'single',
#    'dependants': 2},
#   'address': {'street': 'Flat 72E Luke loaf',
#    'city': 'Hurstburgh',
#    'postcode': 'SE8E 2UT'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 47282,
#    'retired': True,
#    'pension_GBP': 28661},
#   'card': {'card_num': 213000000000000,
#    'card_cvv': 410,
#    'card_iban': 'GB92GXRT03970627714771',
#    'card_start': '2019-12-01',
#    'card_exp': '2025-10-01'},
#   'vehicle': {'vehicle_make': 'Dodge',
#    'vehicle_model': 'Escape',
#    'vehicle_year': 1993,
#    'vehicle_type': 'SUV'}},
#  {'personal': {'first_name': 'Heather',
#    'last_name': 'Dunn',
#    'sex': 'Female',
#    'age': 79,
#    'marital_status': 'widowed',
#    'dependants': 3},
#   'address': {'street': '5 Brown valleys',
#    'city': 'South Francesca',
#    'postcode': 'G2S 2EL'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 54470,
#    'retired': True,
#    'pension_GBP': 10528},
#   'card': {'card_num': 5380000000000000,
#    'card_cvv': 596,
#    'card_iban': 'GB43OTOQ21719538186487',
#    'card_start': '2011-11-01',
#    'card_exp': '2013-03-01'},
#   'vehicle': {'vehicle_make': 'Mercedes-Benz',
#    'vehicle_model': 'Grand Marquis',
#    'vehicle_year': 2009,
#    'vehicle_type': 'Hatchback'}},
#  {'personal': {'first_name': 'Phillip',
#    'last_name': 'Brown',
#    'sex': 'Male',
#    'age': 84,
#    'marital_status': 'married or civil partner',
#    'dependants': 4},
#   'address': {'street': '7 Lauren path',
#    'city': 'Port Paulineside',
#    'postcode': 'WA4 3PW'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 36454,
#    'retired': True,
#    'pension_GBP': 29575},
#   'card': {'card_num': 2230000000000000,
#    'card_cvv': 806,
#    'card_iban': 'GB44YORQ20944907977609',
#    'card_start': '2015-05-01',
#    'card_exp': '2024-01-01'},
#   'vehicle': {'vehicle_make': 'Mitsubishi',
#    'vehicle_model': 'NX',
#    'vehicle_year': 2000,
#    'vehicle_type': 'Sedan'}},
#  {'personal': {'first_name': 'Lynne',
#    'last_name': 'Griffiths',
#    'sex': 'Female',
#    'age': 73,
#    'marital_status': 'married or civil partner',
#    'dependants': 1},
#   'address': {'street': 'Studio 01s Brandon light',
#    'city': 'West Deborahtown',
#    'postcode': 'CF0X 3YB'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 67885,
#    'retired': True,
#    'pension_GBP': 24491},
#   'card': {'card_num': 6010000000000000,
#    'card_cvv': 479,
#    'card_iban': 'GB98TUTV80361796405362',
#    'card_start': '2014-11-01',
#    'card_exp': '2019-01-01'},
#   'vehicle': {'vehicle_make': 'Oldsmobile',
#    'vehicle_model': 'Suburban 1500',
#    'vehicle_year': 2018,
#    'vehicle_type': 'Sedan, Hatchback'}},
#  {'personal': {'first_name': 'Billy',
#    'last_name': 'Clayton',
#    'sex': 'Male',
#    'age': 68,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': '9 Gregory canyon',
#    'city': 'Higginsshire',
#    'postcode': 'EC51 2XJ'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 58750,
#    'retired': True,
#    'pension_GBP': 4468},
#   'card': {'card_num': 3540000000000000,
#    'card_cvv': 831,
#    'card_iban': 'GB29CCYX11405637056572',
#    'card_start': '2017-05-01',
#    'card_exp': '2020-01-01'},
#   'vehicle': {'vehicle_make': 'Ford',
#    'vehicle_model': 'Silverado 2500 HD Extended Cab',
#    'vehicle_year': 2014,
#    'vehicle_type': 'Wagon'}},
#  {'personal': {'first_name': 'Max',
#    'last_name': 'Brown',
#    'sex': 'Male',
#    'age': 88,
#    'marital_status': 'single',
#    'dependants': 2},
#   'address': {'street': 'Flat 2 Byrne overpass',
#    'city': 'Kirstyhaven',
#    'postcode': 'DA69 2WR'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 71618,
#    'retired': True,
#    'pension_GBP': 13405},
#   'card': {'card_num': 639000000000,
#    'card_cvv': 431,
#    'card_iban': 'GB07NTIA61920390807785',
#    'card_start': '2017-06-01',
#    'card_exp': '2026-01-01'},
#   'vehicle': {'vehicle_make': 'Cadillac',
#    'vehicle_model': 'Ram 2500 Quad Cab',
#    'vehicle_year': 2012,
#    'vehicle_type': 'Sedan, Hatchback'}},
#  {'personal': {'first_name': 'Carly',
#    'last_name': 'Lloyd',
#    'sex': 'Female',
#    'age': 89,
#    'marital_status': 'single',
#    'dependants': 2},
#   'address': {'street': 'Flat 86 Abigail mount',
#    'city': 'North Emilystad',
#    'postcode': 'G0F 8GG'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 17080,
#    'retired': True,
#    'pension_GBP': 14877},
#   'card': {'card_num': 4450000000000000,
#    'card_cvv': 32,
#    'card_iban': 'GB20YNUQ40766287388345',
#    'card_start': '2020-04-01',
#    'card_exp': '2022-08-01'},
#   'vehicle': {'vehicle_make': 'Audi',
#    'vehicle_model': 'MR2',
#    'vehicle_year': 1993,
#    'vehicle_type': 'SUV'}},
#  {'personal': {'first_name': 'Paula',
#    'last_name': 'Evans',
#    'sex': 'Female',
#    'age': 91,
#    'marital_status': 'married or civil partner',
#    'dependants': 1},
#   'address': {'street': '77 Payne road',
#    'city': 'Harryfurt',
#    'postcode': 'ML55 7UB'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 42266,
#    'retired': True,
#    'pension_GBP': 30379},
#   'card': {'card_num': 346000000000000,
#    'card_cvv': 745,
#    'card_iban': 'GB29GLGB55781721266519',
#    'card_start': '2014-02-01',
#    'card_exp': '2018-08-01'},
#   'vehicle': {'vehicle_make': 'Honda',
#    'vehicle_model': 'Escalade',
#    'vehicle_year': 1995,
#    'vehicle_type': 'Pickup'}},
#  {'personal': {'first_name': 'Stacey',
#    'last_name': 'Lewis',
#    'sex': 'Female',
#    'age': 86,
#    'marital_status': 'divorced',
#    'dependants': 3},
#   'address': {'street': 'Studio 62I Wilkinson shoal',
#    'city': 'Lake Gerald',
#    'postcode': 'HP0X 1DT'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 34547,
#    'retired': True,
#    'pension_GBP': 22322},
#   'card': {'card_num': 4670000000000000,
#    'card_cvv': 391,
#    'card_iban': 'GB32PXFH99899625532561',
#    'card_start': '2020-07-01',
#    'card_exp': '2028-07-01'},
#   'vehicle': {'vehicle_make': 'Ford',
#    'vehicle_model': 'Element',
#    'vehicle_year': 2019,
#    'vehicle_type': 'Convertible'}},
#  {'personal': {'first_name': 'Marian',
#    'last_name': 'Morris',
#    'sex': 'Female',
#    'age': 85,
#    'marital_status': 'single',
#    'dependants': 2},
#   'address': {'street': '6 Elliot expressway',
#    'city': 'East Martyn',
#    'postcode': 'KA4Y 9HH'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 27788,
#    'retired': True,
#    'pension_GBP': 18188},
#   'card': {'card_num': 4280000000000000000,
#    'card_cvv': 920,
#    'card_iban': 'GB61MRAY67432105740453',
#    'card_start': '2017-05-01',
#    'card_exp': '2022-08-01'},
#   'vehicle': {'vehicle_make': 'Buick',
#    'vehicle_model': '488 Spider',
#    'vehicle_year': 1993,
#    'vehicle_type': 'SUV'}},
#  {'personal': {'first_name': 'Jeffrey',
#    'last_name': 'Bradley',
#    'sex': 'Male',
#    'age': 91,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': 'Studio 17 Brennan circles',
#    'city': 'East Stephenmouth',
#    'postcode': 'L4 8LE'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 66830,
#    'retired': True,
#    'pension_GBP': 21461},
#   'card': {'card_num': 30100000000000,
#    'card_cvv': 428,
#    'card_iban': 'GB10EVWV67455810554513',
#    'card_start': '2016-10-01',
#    'card_exp': '2018-02-01'},
#   'vehicle': {'vehicle_make': 'Cadillac',
#    'vehicle_model': '2500 Crew Cab',
#    'vehicle_year': 1999,
#    'vehicle_type': 'SUV'}},
#  {'personal': {'first_name': 'Judith',
#    'last_name': 'Lane',
#    'sex': 'Female',
#    'age': 91,
#    'marital_status': 'single',
#    'dependants': 2},
#   'address': {'street': '42 Alex burgs',
#    'city': 'West Nicole',
#    'postcode': 'G8S 4JD'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 93485,
#    'retired': True,
#    'pension_GBP': 39930},
#   'card': {'card_num': 3550000000000000,
#    'card_cvv': 228,
#    'card_iban': 'GB32BLVW12286806144217',
#    'card_start': '2015-06-01',
#    'card_exp': '2020-05-01'},
#   'vehicle': {'vehicle_make': 'Lexus',
#    'vehicle_model': 'Samurai',
#    'vehicle_year': 2011,
#    'vehicle_type': 'Pickup'}},
#  {'personal': {'first_name': 'Jacqueline',
#    'last_name': 'Cooke',
#    'sex': 'Female',
#    'age': 80,
#    'marital_status': 'married or civil partner',
#    'dependants': 3},
#   'address': {'street': 'Studio 11 Thompson road',
#    'city': 'Robinville',
#    'postcode': 'M0 7ZG'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 40374,
#    'retired': True,
#    'pension_GBP': 27017},
#   'card': {'card_num': 3550000000000000,
#    'card_cvv': 5225,
#    'card_iban': 'GB81HAHA38940755671413',
#    'card_start': '2018-11-01',
#    'card_exp': '2028-08-01'},
#   'vehicle': {'vehicle_make': 'Dodge',
#    'vehicle_model': 'RX',
#    'vehicle_year': 2006,
#    'vehicle_type': 'Sedan'}},
#  {'personal': {'first_name': 'Rita',
#    'last_name': 'Simpson',
#    'sex': 'Female',
#    'age': 71,
#    'marital_status': 'single',
#    'dependants': 2},
#   'address': {'street': '501 Webster trafficway',
#    'city': 'West Kathleen',
#    'postcode': 'L5J 6QE'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 51556,
#    'retired': True,
#    'pension_GBP': 29058},
#   'card': {'card_num': 3580000000000000,
#    'card_cvv': 985,
#    'card_iban': 'GB79ANTC49044393718953',
#    'card_start': '2018-10-01',
#    'card_exp': '2028-03-01'},
#   'vehicle': {'vehicle_make': 'Ford',
#    'vehicle_model': 'Jetta SportWagen',
#    'vehicle_year': 2016,
#    'vehicle_type': 'SUV'}},
#  {'personal': {'first_name': 'Amelia',
#    'last_name': 'Sanders',
#    'sex': 'Female',
#    'age': 74,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': 'Flat 4 Eric falls',
#    'city': 'South Jillfort',
#    'postcode': 'S1C 1EF'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 26271,
#    'retired': True,
#    'pension_GBP': 19223},
#   'card': {'card_num': 30200000000000,
#    'card_cvv': 973,
#    'card_iban': 'GB04PTEU93211358082866',
#    'card_start': '2015-10-01',
#    'card_exp': '2021-02-01'},
#   'vehicle': {'vehicle_make': 'Jaguar',
#    'vehicle_model': 'Spectra',
#    'vehicle_year': 2001,
#    'vehicle_type': 'Sedan'}},
#  {'personal': {'first_name': 'Stephanie',
#    'last_name': 'Graham',
#    'sex': 'Female',
#    'age': 85,
#    'marital_status': 'widowed',
#    'dependants': 4},
#   'address': {'street': '9 Lewis land',
#    'city': 'South Brenda',
#    'postcode': 'B5 9DN'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 44159,
#    'retired': True,
#    'pension_GBP': 22410},
#   'card': {'card_num': 639000000000,
#    'card_cvv': 283,
#    'card_iban': 'GB04KSXJ43697886371150',
#    'card_start': '2013-04-01',
#    'card_exp': '2025-03-01'},
#   'vehicle': {'vehicle_make': 'BMW',
#    'vehicle_model': 'Montero Sport',
#    'vehicle_year': 2004,
#    'vehicle_type': 'Hatchback'}},
#  {'personal': {'first_name': 'Chloe',
#    'last_name': 'Wyatt',
#    'sex': 'Female',
#    'age': 89,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': '2 Nash meadow',
#    'city': 'South Caroline',
#    'postcode': 'B45 5XX'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 57387,
#    'retired': True,
#    'pension_GBP': 35545},
#   'card': {'card_num': 4370000000000,
#    'card_cvv': 725,
#    'card_iban': 'GB60ZTJZ49049576519263',
#    'card_start': '2019-03-01',
#    'card_exp': '2022-09-01'},
#   'vehicle': {'vehicle_make': 'Nissan',
#    'vehicle_model': 'tC',
#    'vehicle_year': 2018,
#    'vehicle_type': 'Van/Minivan'}},
#  {'personal': {'first_name': 'Charlotte',
#    'last_name': 'Quinn',
#    'sex': 'Female',
#    'age': 83,
#    'marital_status': 'married or civil partner',
#    'dependants': 3},
#   'address': {'street': '20 Tina camp',
#    'city': 'Bethberg',
#    'postcode': 'W9F 8GG'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 72864,
#    'retired': True,
#    'pension_GBP': 15710},
#   'card': {'card_num': 4350000000000,
#    'card_cvv': 559,
#    'card_iban': 'GB80ZMIA07638663039306',
#    'card_start': '2019-06-01',
#    'card_exp': '2023-06-01'},
#   'vehicle': {'vehicle_make': 'Mercury',
#    'vehicle_model': 'Explorer',
#    'vehicle_year': 2009,
#    'vehicle_type': 'Sedan'}},
#  {'personal': {'first_name': 'Alice',
#    'last_name': 'Rogers',
#    'sex': 'Female',
#    'age': 68,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': '441 Miller junctions',
#    'city': 'Archermouth',
#    'postcode': 'HU8M 7WD'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 70317,
#    'retired': True,
#    'pension_GBP': 33852},
#   'card': {'card_num': 344000000000000,
#    'card_cvv': 275,
#    'card_iban': 'GB96XTGK11614823667356',
#    'card_start': '2017-07-01',
#    'card_exp': '2017-07-01'},
#   'vehicle': {'vehicle_make': 'Lotus',
#    'vehicle_model': 'Pilot',
#    'vehicle_year': 2010,
#    'vehicle_type': 'Coupe'}},
#  {'personal': {'first_name': 'Donna',
#    'last_name': 'Stanley',
#    'sex': 'Female',
#    'age': 81,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': '6 Gavin canyon',
#    'city': 'Campbelltown',
#    'postcode': 'M1 4FU'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 54509,
#    'retired': True,
#    'pension_GBP': 29116},
#   'card': {'card_num': 3550000000000000,
#    'card_cvv': 203,
#    'card_iban': 'GB63UWOQ65829953219202',
#    'card_start': '2015-04-01',
#    'card_exp': '2025-10-01'},
#   'vehicle': {'vehicle_make': 'Mercedes-Benz',
#    'vehicle_model': 'Veloster',
#    'vehicle_year': 2011,
#    'vehicle_type': 'SUV'}},
#  {'personal': {'first_name': 'Vincent',
#    'last_name': 'Hutchinson',
#    'sex': 'Male',
#    'age': 74,
#    'marital_status': 'single',
#    'dependants': 1},
#   'address': {'street': '4 Edwards spurs',
#    'city': 'North Victor',
#    'postcode': 'HG07 6JE'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 75172,
#    'retired': True,
#    'pension_GBP': 31192},
#   'card': {'card_num': 4110000000000,
#    'card_cvv': 739,
#    'card_iban': 'GB80BJAF26294016568157',
#    'card_start': '2011-11-01',
#    'card_exp': '2017-09-01'},
#   'vehicle': {'vehicle_make': 'Buick',
#    'vehicle_model': 'E-Class',
#    'vehicle_year': 1992,
#    'vehicle_type': 'Hatchback'}},
#  {'personal': {'first_name': 'Janice',
#    'last_name': 'Barnes',
#    'sex': 'Female',
#    'age': 66,
#    'marital_status': 'divorced',
#    'dependants': 2},
#   'address': {'street': '088 Olivia row',
#    'city': 'Jeremybury',
#    'postcode': 'W67 2DQ'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 74186,
#    'retired': True,
#    'pension_GBP': 31440},
#   'card': {'card_num': 4730000000000,
#    'card_cvv': 5,
#    'card_iban': 'GB59CGWC09501003795263',
#    'card_start': '2006-12-01',
#    'card_exp': '2025-01-01'},
#   'vehicle': {'vehicle_make': 'INFINITI',
#    'vehicle_model': 'XC40',
#    'vehicle_year': 1998,
#    'vehicle_type': 'SUV'}},
#  {'personal': {'first_name': 'Joyce',
#    'last_name': 'White',
#    'sex': 'Female',
#    'age': 88,
#    'marital_status': 'single',
#    'dependants': 2},
#   'address': {'street': '89 Quinn ports',
#    'city': 'Priceton',
#    'postcode': 'B48 4SY'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 81911,
#    'retired': True,
#    'pension_GBP': 20967},
#   'card': {'card_num': 3540000000000000,
#    'card_cvv': 741,
#    'card_iban': 'GB53SWJF73957031961758',
#    'card_start': '2018-07-01',
#    'card_exp': '2027-04-01'},
#   'vehicle': {'vehicle_make': 'Chevrolet',
#    'vehicle_model': '300 CE',
#    'vehicle_year': 2002,
#    'vehicle_type': 'SUV'}},
#  {'personal': {'first_name': 'James',
#    'last_name': 'Sanderson',
#    'sex': 'Male',
#    'age': 72,
#    'marital_status': 'divorced',
#    'dependants': 2},
#   'address': {'street': '64 Howard alley',
#    'city': 'Staceyside',
#    'postcode': 'E1B 8AE'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 62026,
#    'retired': True,
#    'pension_GBP': 37608},
#   'card': {'card_num': 4440000000000000000,
#    'card_cvv': 284,
#    'card_iban': 'GB41CACL40516590405913',
#    'card_start': '2014-04-01',
#    'card_exp': '2021-08-01'},
#   'vehicle': {'vehicle_make': 'Kia',
#    'vehicle_model': 'Titan King Cab',
#    'vehicle_year': 1998,
#    'vehicle_type': 'Van/Minivan'}},
#  {'personal': {'first_name': 'Alexander',
#    'last_name': 'Gardner',
#    'sex': 'Male',
#    'age': 78,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': 'Studio 49c Sean oval',
#    'city': 'Rickyberg',
#    'postcode': 'HS5 2DF'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 50950,
#    'retired': True,
#    'pension_GBP': 14692},
#   'card': {'card_num': 4390000000000000000,
#    'card_cvv': 4192,
#    'card_iban': 'GB53GKFC76949582334762',
#    'card_start': '2016-12-01',
#    'card_exp': '2028-03-01'},
#   'vehicle': {'vehicle_make': 'Honda',
#    'vehicle_model': 'Touareg 2',
#    'vehicle_year': 2007,
#    'vehicle_type': 'Hatchback'}},
#  {'personal': {'first_name': 'Rosie',
#    'last_name': 'Jones',
#    'sex': 'Female',
#    'age': 78,
#    'marital_status': 'married or civil partner',
#    'dependants': 1},
#   'address': {'street': 'Flat 8 Geoffrey knolls',
#    'city': 'Parkerton',
#    'postcode': 'W09 7UZ'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 63989,
#    'retired': True,
#    'pension_GBP': 21272},
#   'card': {'card_num': 2280000000000000,
#    'card_cvv': 260,
#    'card_iban': 'GB06EUQK67067081044334',
#    'card_start': '2018-11-01',
#    'card_exp': '2020-12-01'},
#   'vehicle': {'vehicle_make': 'Ford',
#    'vehicle_model': 'Sentra',
#    'vehicle_year': 2015,
#    'vehicle_type': 'Van/Minivan'}},
#  {'personal': {'first_name': 'Reece',
#    'last_name': 'Sullivan',
#    'sex': 'Male',
#    'age': 89,
#    'marital_status': 'married or civil partner',
#    'dependants': 1},
#   'address': {'street': 'Studio 79V Rebecca mission',
#    'city': 'Yvonneville',
#    'postcode': 'TF11 7US'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 91070,
#    'retired': True,
#    'pension_GBP': 21395},
#   'card': {'card_num': 4510000000000,
#    'card_cvv': 216,
#    'card_iban': 'GB03LCIM12350559650965',
#    'card_start': '2013-07-01',
#    'card_exp': '2023-12-01'},
#   'vehicle': {'vehicle_make': 'Nissan',
#    'vehicle_model': 'CL-Class',
#    'vehicle_year': 2001,
#    'vehicle_type': 'Van/Minivan'}},
#  {'personal': {'first_name': 'Frances',
#    'last_name': 'Francis',
#    'sex': 'Female',
#    'age': 72,
#    'marital_status': 'single',
#    'dependants': 1},
#   'address': {'street': 'Studio 32R Lynn parkway',
#    'city': 'Nicholsonport',
#    'postcode': 'M2 7HR'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 59168,
#    'retired': True,
#    'pension_GBP': 35827},
#   'card': {'card_num': 4140000000000000,
#    'card_cvv': 837,
#    'card_iban': 'GB40WRBD50872027110094',
#    'card_start': '2013-12-01',
#    'card_exp': '2021-04-01'},
#   'vehicle': {'vehicle_make': 'Mercury',
#    'vehicle_model': 'Gallardo',
#    'vehicle_year': 2009,
#    'vehicle_type': 'Sedan'}},
#  {'personal': {'first_name': 'Barry',
#    'last_name': 'Charlton',
#    'sex': 'Male',
#    'age': 89,
#    'marital_status': 'single',
#    'dependants': 2},
#   'address': {'street': '2 Bates camp',
#    'city': 'North Kimberleymouth',
#    'postcode': 'CR5H 6LY'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 58729,
#    'retired': True,
#    'pension_GBP': 36985},
#   'card': {'card_num': 4780000000000000000,
#    'card_cvv': 427,
#    'card_iban': 'GB22LCWN45914936638582',
#    'card_start': '2020-09-01',
#    'card_exp': '2024-12-01'},
#   'vehicle': {'vehicle_make': 'Honda',
#    'vehicle_model': 'Highlander',
#    'vehicle_year': 2019,
#    'vehicle_type': 'SUV'}},
#  {'personal': {'first_name': 'Judith',
#    'last_name': 'Hussain',
#    'sex': 'Female',
#    'age': 90,
#    'marital_status': 'single',
#    'dependants': 3},
#   'address': {'street': '488 Hutchinson trail',
#    'city': 'Francescaside',
#    'postcode': 'SO4M 6RY'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 39725,
#    'retired': True,
#    'pension_GBP': 18704},
#   'card': {'card_num': 586000000000,
#    'card_cvv': 78,
#    'card_iban': 'GB87PPRL93552500559119',
#    'card_start': '2013-03-01',
#    'card_exp': '2020-02-01'},
#   'vehicle': {'vehicle_make': 'Dodge',
#    'vehicle_model': 'LaCrosse',
#    'vehicle_year': 2011,
#    'vehicle_type': 'Sedan'}},
#  {'personal': {'first_name': 'Jemma',
#    'last_name': 'Cooper',
#    'sex': 'Female',
#    'age': 85,
#    'marital_status': 'single',
#    'dependants': 3},
#   'address': {'street': 'Studio 67 Robert lights',
#    'city': 'Williamsport',
#    'postcode': 'CA09 0NR'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 72391,
#    'retired': True,
#    'pension_GBP': 32065},
#   'card': {'card_num': 2590000000000000,
#    'card_cvv': 776,
#    'card_iban': 'GB86HEAP71785638463694',
#    'card_start': '2016-08-01',
#    'card_exp': '2027-11-01'},
#   'vehicle': {'vehicle_make': 'Suzuki',
#    'vehicle_model': 'Sierra 2500 HD Regular Cab',
#    'vehicle_year': 2010,
#    'vehicle_type': 'SUV'}},
#  {'personal': {'first_name': 'Emma',
#    'last_name': 'Stone',
#    'sex': 'Female',
#    'age': 84,
#    'marital_status': 'married or civil partner',
#    'dependants': 3},
#   'address': {'street': '9 Charlene place',
#    'city': 'Marshallbury',
#    'postcode': 'KT2H 4ZD'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 73010,
#    'retired': True,
#    'pension_GBP': 22838},
#   'card': {'card_num': 3510000000000000,
#    'card_cvv': 909,
#    'card_iban': 'GB94TBGV01861271051029',
#    'card_start': '2016-01-01',
#    'card_exp': '2020-08-01'},
#   'vehicle': {'vehicle_make': 'Ford',
#    'vehicle_model': 'Veloster',
#    'vehicle_year': 2011,
#    'vehicle_type': 'Pickup'}},
#  {'personal': {'first_name': 'Brett',
#    'last_name': 'Lee',
#    'sex': 'Male',
#    'age': 72,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': 'Studio 29 Patel bridge',
#    'city': 'South Karenview',
#    'postcode': 'M98 2TF'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 55199,
#    'retired': True,
#    'pension_GBP': 26044},
#   'card': {'card_num': 6590000000000000,
#    'card_cvv': 561,
#    'card_iban': 'GB20KSPI69319283249670',
#    'card_start': '2017-07-01',
#    'card_exp': '2022-10-01'},
#   'vehicle': {'vehicle_make': 'BMW',
#    'vehicle_model': 'Sportage',
#    'vehicle_year': 2014,
#    'vehicle_type': 'Hatchback'}},
#  {'personal': {'first_name': 'Bethany',
#    'last_name': 'Lamb',
#    'sex': 'Female',
#    'age': 72,
#    'marital_status': 'married or civil partner',
#    'dependants': 1},
#   'address': {'street': 'Flat 39W Terry village',
#    'city': 'Hardingfurt',
#    'postcode': 'LU7 2HX'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 28120,
#    'retired': True,
#    'pension_GBP': 27093},
#   'card': {'card_num': 4190000000000000,
#    'card_cvv': 994,
#    'card_iban': 'GB23IGFD65192602596335',
#    'card_start': '2020-05-01',
#    'card_exp': '2025-11-01'},
#   'vehicle': {'vehicle_make': 'Toyota',
#    'vehicle_model': 'S90',
#    'vehicle_year': 2016,
#    'vehicle_type': 'Sedan'}},
#  {'personal': {'first_name': 'Melanie',
#    'last_name': 'Woods',
#    'sex': 'Female',
#    'age': 83,
#    'marital_status': 'married or civil partner',
#    'dependants': 3},
#   'address': {'street': '4 Chapman run',
#    'city': 'Georgeview',
#    'postcode': 'YO8P 2FY'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 48001,
#    'retired': True,
#    'pension_GBP': 23119},
#   'card': {'card_num': 4290000000000000,
#    'card_cvv': 836,
#    'card_iban': 'GB04NNQH82360641876337',
#    'card_start': '2017-06-01',
#    'card_exp': '2028-06-01'},
#   'vehicle': {'vehicle_make': 'Ford',
#    'vehicle_model': 'Coupe',
#    'vehicle_year': 2003,
#    'vehicle_type': 'Sedan'}},
#  {'personal': {'first_name': 'Connor',
#    'last_name': 'Law',
#    'sex': 'Male',
#    'age': 74,
#    'marital_status': 'widowed',
#    'dependants': 3},
#   'address': {'street': '977 Fletcher islands',
#    'city': 'Lake Charlene',
#    'postcode': 'W1 6SE'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 59985,
#    'retired': True,
#    'pension_GBP': 19081},
#   'card': {'card_num': 4510000000000000000,
#    'card_cvv': 944,
#    'card_iban': 'GB35RJXL55868227746584',
#    'card_start': '2019-03-01',
#    'card_exp': '2022-10-01'},
#   'vehicle': {'vehicle_make': 'Audi',
#    'vehicle_model': 'F150 Super Cab',
#    'vehicle_year': 1992,
#    'vehicle_type': 'SUV'}},
#  {'personal': {'first_name': 'Denise',
#    'last_name': 'Johnson',
#    'sex': 'Female',
#    'age': 91,
#    'marital_status': 'single',
#    'dependants': 2},
#   'address': {'street': '11 Susan corners',
#    'city': 'New Gemmaside',
#    'postcode': 'E47 1FD'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 40940,
#    'retired': True,
#    'pension_GBP': 30771},
#   'card': {'card_num': 4090000000000000,
#    'card_cvv': 395,
#    'card_iban': 'GB70BYVY35000815633952',
#    'card_start': '2014-12-01',
#    'card_exp': '2016-02-01'},
#   'vehicle': {'vehicle_make': 'INFINITI',
#    'vehicle_model': 'CTS-V',
#    'vehicle_year': 2008,
#    'vehicle_type': 'Sedan, Coupe, Convertible'}},
#  {'personal': {'first_name': 'Olivia',
#    'last_name': 'Morley',
#    'sex': 'Female',
#    'age': 85,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': 'Studio 7 Mitchell drives',
#    'city': 'Richardsonmouth',
#    'postcode': 'L6S 1YX'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 45273,
#    'retired': True,
#    'pension_GBP': 27196},
#   'card': {'card_num': 6010000000000000,
#    'card_cvv': 781,
#    'card_iban': 'GB46JUEF63044498095285',
#    'card_start': '2020-07-01',
#    'card_exp': '2024-05-01'},
#   'vehicle': {'vehicle_make': 'Toyota',
#    'vehicle_model': 'GLC Coupe',
#    'vehicle_year': 2011,
#    'vehicle_type': 'Coupe, Convertible'}},
#  {'personal': {'first_name': 'Ryan',
#    'last_name': 'Tucker',
#    'sex': 'Male',
#    'age': 70,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': 'Studio 9 Kerry via',
# ...
#    'dependants': 3},
#   'address': {'street': '6 Frost meadow',
#    'city': 'Bishopchester',
#    'postcode': 'B6 1LS'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 90389,
#    'retired': True,
#    'pension_GBP': 21526},
#   'card': {'card_num': 2360000000000000,
#    'card_cvv': 971,
#    'card_iban': 'GB17WCLQ98830247618110',
#    'card_start': '2018-12-01',
#    'card_exp': '2025-08-01'},
#   'vehicle': {'vehicle_make': 'Toyota',
#    'vehicle_model': 'MX-5 Miata RF',
#    'vehicle_year': 2018,
#    'vehicle_type': 'Coupe, Sedan, Convertible'}},
#  {'personal': {'first_name': 'Irene',
#    'last_name': 'Stevens',
#    'sex': 'Female',
#    'age': 82,
#    'marital_status': 'single',
#    'dependants': 2},
#   'address': {'street': 'Flat 89q Morris ports',
#    'city': 'South Amelia',
#    'postcode': 'TF4M 2WF'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 81685,
#    'retired': True,
#    'pension_GBP': 24962},
#   'card': {'card_num': 38600000000000,
#    'card_cvv': 354,
#    'card_iban': 'GB77FKQW93276336096137',
#    'card_start': '2013-07-01',
#    'card_exp': '2024-05-01'},
#   'vehicle': {'vehicle_make': 'Eagle',
#    'vehicle_model': 'Mystique',
#    'vehicle_year': 2013,
#    'vehicle_type': 'Van/Minivan'}},
#  {'personal': {'first_name': 'Steven',
#    'last_name': 'Begum',
#    'sex': 'Male',
#    'age': 76,
#    'marital_status': 'widowed',
#    'dependants': 1},
#   'address': {'street': '3 Irene coves',
#    'city': 'Shawstad',
#    'postcode': 'FK2 3EJ'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 52702,
#    'retired': True,
#    'pension_GBP': 38420},
#   'card': {'card_num': 3560000000000000,
#    'card_cvv': 659,
#    'card_iban': 'GB25TZDP01367557620470',
#    'card_start': '2018-10-01',
#    'card_exp': '2029-10-01'},
#   'vehicle': {'vehicle_make': 'Buick',
#    'vehicle_model': 'Boxster',
#    'vehicle_year': 2015,
#    'vehicle_type': 'Pickup'}},
#  {'personal': {'first_name': 'Trevor',
#    'last_name': 'Wright',
#    'sex': 'Male',
#    'age': 91,
#    'marital_status': 'married or civil partner',
#    'dependants': 4},
#   'address': {'street': 'Studio 37 Dunn lane',
#    'city': 'Jacquelineland',
#    'postcode': 'E8E 3QG'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 23473,
#    'retired': True,
#    'pension_GBP': 16759},
#   'card': {'card_num': 3550000000000000,
#    'card_cvv': 412,
#    'card_iban': 'GB66DNJX81713774875902',
#    'card_start': '2014-03-01',
#    'card_exp': '2016-12-01'},
#   'vehicle': {'vehicle_make': 'Toyota',
#    'vehicle_model': 'Canyon Crew Cab',
#    'vehicle_year': 2013,
#    'vehicle_type': 'Pickup'}},
#  {'personal': {'first_name': 'Robert',
#    'last_name': 'Thorpe',
#    'sex': 'Male',
#    'age': 79,
#    'marital_status': 'married or civil partner',
#    'dependants': 1},
#   'address': {'street': '741 Carly ways',
#    'city': 'Mitchellstad',
#    'postcode': 'NN6H 3UN'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 17965,
#    'retired': True,
#    'pension_GBP': 19321},
#   'card': {'card_num': 213000000000000,
#    'card_cvv': 619,
#    'card_iban': 'GB19NUAM55033686418817',
#    'card_start': '2017-06-01',
#    'card_exp': '2019-01-01'},
#   'vehicle': {'vehicle_make': 'Dodge',
#    'vehicle_model': 'Solara',
#    'vehicle_year': 1995,
#    'vehicle_type': 'SUV'}},
#  {'personal': {'first_name': 'Teresa',
#    'last_name': 'Thomas',
#    'sex': 'Female',
#    'age': 84,
#    'marital_status': 'single',
#    'dependants': 2},
#   'address': {'street': '29 Hartley lakes',
#    'city': 'Charlotteshire',
#    'postcode': 'W8J 5UJ'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 39585,
#    'retired': True,
#    'pension_GBP': 20435},
#   'card': {'card_num': 3560000000000000,
#    'card_cvv': 996,
#    'card_iban': 'GB90JJIZ64969906858591',
#    'card_start': '2017-04-01',
#    'card_exp': '2029-05-01'},
#   'vehicle': {'vehicle_make': 'Chevrolet',
#    'vehicle_model': 'Sunfire',
#    'vehicle_year': 2003,
#    'vehicle_type': 'SUV'}},
#  {'personal': {'first_name': 'Justin',
#    'last_name': 'Gordon',
#    'sex': 'Male',
#    'age': 88,
#    'marital_status': 'single',
#    'dependants': 0},
#   'address': {'street': 'Flat 83T Mohammed mill',
#    'city': 'Newtonland',
#    'postcode': 'TF46 1AY'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 44939,
#    'retired': True,
#    'pension_GBP': 29117},
#   'card': {'card_num': 3560000000000000,
#    'card_cvv': 42,
#    'card_iban': 'GB85IDBL18743572719319',
#    'card_start': '2014-12-01',
#    'card_exp': '2021-12-01'},
#   'vehicle': {'vehicle_make': 'Chevrolet',
#    'vehicle_model': 'Spark',
#    'vehicle_year': '2019',
#    'vehicle_type': 'Van/Minivan'}},
#  {'personal': {'first_name': 'Shirley',
#    'last_name': 'Garner',
#    'sex': 'Female',
#    'age': 72,
#    'marital_status': 'divorced',
#    'dependants': 1},
#   'address': {'street': 'Studio 3 Victoria parkways',
#    'city': 'Reynoldsmouth',
#    'postcode': 'SE1E 4EU'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 76218,
#    'retired': True,
#    'pension_GBP': 17862},
#   'card': {'card_num': 3580000000000000,
#    'card_cvv': 680,
#    'card_iban': 'GB03PBVL26878491093000',
#    'card_start': '2018-04-01',
#    'card_exp': '2022-12-01'},
#   'vehicle': {'vehicle_make': 'Toyota',
#    'vehicle_model': '3 Series',
#    'vehicle_year': 2019,
#    'vehicle_type': 'Pickup'}},
#  {'personal': {'first_name': 'Francesca',
#    'last_name': 'Martin',
#    'sex': 'Female',
#    'age': 88,
#    'marital_status': 'divorced',
#    'dependants': 2},
#   'address': {'street': '092 Baldwin branch',
#    'city': 'Lorraineshire',
#    'postcode': 'W0 4QT'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 83879,
#    'retired': True,
#    'pension_GBP': 32232},
#   'card': {'card_num': 370000000000000,
#    'card_cvv': 897,
#    'card_iban': 'GB09HXWS10236769668322',
#    'card_start': '2014-02-01',
#    'card_exp': '2027-02-01'},
#   'vehicle': {'vehicle_make': 'Chevrolet',
#    'vehicle_model': 'tC',
#    'vehicle_year': 1995,
#    'vehicle_type': 'Pickup'}},
#  {'personal': {'first_name': 'Rachael',
#    'last_name': 'Perkins',
#    'sex': 'Female',
#    'age': 90,
#    'marital_status': 'widowed',
#    'dependants': 2},
#   'address': {'street': '195 Doyle square',
#    'city': 'Lake Adrian',
#    'postcode': 'E6 7PY'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 20870,
#    'retired': True,
#    'pension_GBP': 17442},
#   'card': {'card_num': 4770000000000,
#    'card_cvv': 990,
#    'card_iban': 'GB80TXZK70878347834265',
#    'card_start': '2020-02-01',
#    'card_exp': '2024-06-01'},
#   'vehicle': {'vehicle_make': 'BMW',
#    'vehicle_model': 'Pathfinder',
#    'vehicle_year': 2017,
#    'vehicle_type': 'Hatchback'}},
#  {'personal': {'first_name': 'Bethany',
#    'last_name': 'Newman',
#    'sex': 'Female',
#    'age': 82,
#    'marital_status': 'single',
#    'dependants': 2},
#   'address': {'street': '520 Thompson brook',
#    'city': 'Campbellburgh',
#    'postcode': 'E0W 7SA'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 51160,
#    'retired': True,
#    'pension_GBP': 30609},
#   'card': {'card_num': 3550000000000000,
#    'card_cvv': 526,
#    'card_iban': 'GB17BSSQ06507325612928',
#    'card_start': '2016-05-01',
#    'card_exp': '2030-12-01'},
#   'vehicle': {'vehicle_make': 'Dodge',
#    'vehicle_model': 'Savana 1500 Passenger',
#    'vehicle_year': 1995,
#    'vehicle_type': 'Pickup'}},
#  {'personal': {'first_name': 'Harry',
#    'last_name': 'Lambert',
#    'sex': 'Male',
#    'age': 73,
#    'marital_status': 'single',
#    'dependants': 2},
#   'address': {'street': 'Flat 6 Andrea coves',
#    'city': 'Hollietown',
#    'postcode': 'FY23 2JQ'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 27730,
#    'retired': True,
#    'pension_GBP': 29272},
#   'card': {'card_num': 343000000000000,
#    'card_cvv': 389,
#    'card_iban': 'GB82ZAIC38073848968480',
#    'card_start': '2017-06-01',
#    'card_exp': '2028-09-01'},
#   'vehicle': {'vehicle_make': 'Pontiac',
#    'vehicle_model': 'Tribeca',
#    'vehicle_year': 1996,
#    'vehicle_type': 'SUV'}},
#  {'personal': {'first_name': 'Phillip',
#    'last_name': 'Dixon',
#    'sex': 'Male',
#    'age': 89,
#    'marital_status': 'married or civil partner',
#    'dependants': 3},
#   'address': {'street': 'Studio 11F Harris light',
#    'city': 'Annashire',
#    'postcode': 'L55 9FH'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 57766,
#    'retired': True,
#    'pension_GBP': 27015},
#   'card': {'card_num': 3590000000000000,
#    'card_cvv': 1196,
#    'card_iban': 'GB67WCNR66199555478220',
#    'card_start': '2019-08-01',
#    'card_exp': '2028-09-01'},
#   'vehicle': {'vehicle_make': 'INFINITI',
#    'vehicle_model': 'GLK-Class',
#    'vehicle_year': 1994,
#    'vehicle_type': 'SUV'}},
#  {'personal': {'first_name': 'Gail',
#    'last_name': 'Walker',
#    'sex': 'Female',
#    'age': 89,
#    'marital_status': 'single',
#    'dependants': 1},
#   'address': {'street': 'Studio 12 Rebecca river',
#    'city': 'Burtonmouth',
#    'postcode': 'ME89 0FJ'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 88719,
#    'retired': True,
#    'pension_GBP': 38873},
#   'card': {'card_num': 4750000000000000,
#    'card_cvv': 320,
#    'card_iban': 'GB82MVQP12931129936673',
#    'card_start': '2006-12-01',
#    'card_exp': '2016-03-01'},
#   'vehicle': {'vehicle_make': 'Plymouth',
#    'vehicle_model': 'HR-V',
#    'vehicle_year': 2020,
#    'vehicle_type': 'Sedan'}},
#  {'personal': {'first_name': 'Philip',
#    'last_name': 'Owen',
#    'sex': 'Male',
#    'age': 67,
#    'marital_status': 'divorced',
#    'dependants': 1},
#   'address': {'street': '090 Ford roads',
#    'city': 'East Bryan',
#    'postcode': 'L3 4WR'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 95691,
#    'retired': True,
#    'pension_GBP': 33629},
#   'card': {'card_num': 4630000000000000000,
#    'card_cvv': 933,
#    'card_iban': 'GB97XNRH55329324397700',
#    'card_start': '2020-03-01',
#    'card_exp': '2028-12-01'},
#   'vehicle': {'vehicle_make': 'Subaru',
#    'vehicle_model': 'Sierra 1500 Regular Cab',
#    'vehicle_year': 2015,
#    'vehicle_type': 'Sedan'}},
#  {'personal': {'first_name': 'Sandra',
#    'last_name': 'Jones',
#    'sex': 'Female',
#    'age': 87,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': 'Flat 7 Manning rapid',
#    'city': 'Jenniferborough',
#    'postcode': 'M25 3TJ'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 83754,
#    'retired': True,
#    'pension_GBP': 18668},
#   'card': {'card_num': 2410000000000000,
#    'card_cvv': 324,
#    'card_iban': 'GB05XVTL40048654259634',
#    'card_start': '2018-07-01',
#    'card_exp': '2022-02-01'},
#   'vehicle': {'vehicle_make': 'Ford',
#    'vehicle_model': 'Impala',
#    'vehicle_year': 2004,
#    'vehicle_type': 'Coupe'}},
#  {'personal': {'first_name': 'George',
#    'last_name': 'Robinson',
#    'sex': 'Male',
#    'age': 84,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': 'Studio 58S Ahmed motorway',
#    'city': 'Johnstonmouth',
#    'postcode': 'G1E 5JS'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 60099,
#    'retired': True,
#    'pension_GBP': 14439},
#   'card': {'card_num': 30200000000000,
#    'card_cvv': 320,
#    'card_iban': 'GB30PZNQ35734131517122',
#    'card_start': '2019-06-01',
#    'card_exp': '2022-05-01'},
#   'vehicle': {'vehicle_make': 'Cadillac',
#    'vehicle_model': 'Sierra 1500 Crew Cab',
#    'vehicle_year': 2019,
#    'vehicle_type': 'Van/Minivan'}},
#  {'personal': {'first_name': 'Karl',
#    'last_name': 'Jones',
#    'sex': 'Male',
#    'age': 82,
#    'marital_status': 'married or civil partner',
#    'dependants': 3},
#   'address': {'street': '4 Clark villages',
#    'city': 'Blackport',
#    'postcode': 'L76 3HQ'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 48732,
#    'retired': True,
#    'pension_GBP': 15720},
#   'card': {'card_num': 343000000000000,
#    'card_cvv': 248,
#    'card_iban': 'GB24BEGI58730221107128',
#    'card_start': '2013-05-01',
#    'card_exp': '2019-06-01'},
#   'vehicle': {'vehicle_make': 'Cadillac',
#    'vehicle_model': 'IS',
#    'vehicle_year': 2013,
#    'vehicle_type': 'Van/Minivan'}},
#  {'personal': {'first_name': 'Hazel',
#    'last_name': 'Hayward',
#    'sex': 'Female',
#    'age': 84,
#    'marital_status': 'married or civil partner',
#    'dependants': 0},
#   'address': {'street': 'Flat 75 Russell orchard',
#    'city': 'Katiemouth',
#    'postcode': 'SL5 9RD'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 22020,
#    'retired': True,
#    'pension_GBP': 25214},
#   'card': {'card_num': 4080000000000000,
#    'card_cvv': 314,
#    'card_iban': 'GB43GWMR08993795489139',
#    'card_start': '2014-07-01',
#    'card_exp': '2014-08-01'},
#   'vehicle': {'vehicle_make': 'Mercedes-Benz',
#    'vehicle_model': 'Durango',
#    'vehicle_year': '1998',
#    'vehicle_type': 'SUV'}},
#  {'personal': {'first_name': 'Aaron',
#    'last_name': 'Mistry',
#    'sex': 'Male',
#    'age': 83,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': '71 Smith stravenue',
#    'city': 'Lesleytown',
#    'postcode': 'MK0 1HD'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 66220,
#    'retired': True,
#    'pension_GBP': 16436},
#   'card': {'card_num': 38200000000000,
#    'card_cvv': 684,
#    'card_iban': 'GB04ZDRK14974964545353',
#    'card_start': '2020-08-01',
#    'card_exp': '2021-11-01'},
#   'vehicle': {'vehicle_make': 'GMC',
#    'vehicle_model': 'Venture Cargo',
#    'vehicle_year': 2018,
#    'vehicle_type': 'SUV'}},
#  {'personal': {'first_name': 'Kieran',
#    'last_name': 'Thomas',
#    'sex': 'Male',
#    'age': 90,
#    'marital_status': 'married or civil partner',
#    'dependants': 1},
#   'address': {'street': 'Studio 51 Scott summit',
#    'city': 'East Shane',
#    'postcode': 'N2 8WH'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 26654,
#    'retired': True,
#    'pension_GBP': 25776},
#   'card': {'card_num': 2710000000000000,
#    'card_cvv': 863,
#    'card_iban': 'GB32QNPA26143392126454',
#    'card_start': '2010-12-01',
#    'card_exp': '2018-01-01'},
#   'vehicle': {'vehicle_make': 'Kia',
#    'vehicle_model': '3 Series',
#    'vehicle_year': 2003,
#    'vehicle_type': 'Coupe, Convertible'}},
#  {'personal': {'first_name': 'Trevor',
#    'last_name': 'Goddard',
#    'sex': 'Male',
#    'age': 76,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': 'Studio 6 Leslie keys',
#    'city': 'Andreastad',
#    'postcode': 'KA4X 1QR'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 48597,
#    'retired': True,
#    'pension_GBP': 28990},
#   'card': {'card_num': 676000000000,
#    'card_cvv': 909,
#    'card_iban': 'GB27KLPB12136922168928',
#    'card_start': '2017-10-01',
#    'card_exp': '2028-12-01'},
#   'vehicle': {'vehicle_make': 'Scion',
#    'vehicle_model': 'Vibe',
#    'vehicle_year': 2005,
#    'vehicle_type': 'Wagon'}},
#  {'personal': {'first_name': 'Joel',
#    'last_name': 'Sykes',
#    'sex': 'Male',
#    'age': 90,
#    'marital_status': 'single',
#    'dependants': 3},
#   'address': {'street': 'Flat 35h Kathleen extensions',
#    'city': 'Lake Owenmouth',
#    'postcode': 'G3 8PL'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 49928,
#    'retired': True,
#    'pension_GBP': 15650},
#   'card': {'card_num': 213000000000000,
#    'card_cvv': 911,
#    'card_iban': 'GB60TSJL96687346319661',
#    'card_start': '2015-06-01',
#    'card_exp': '2026-07-01'},
#   'vehicle': {'vehicle_make': 'Nissan',
#    'vehicle_model': 'Prizm',
#    'vehicle_year': 1994,
#    'vehicle_type': 'Van/Minivan'}},
#  {'personal': {'first_name': 'Sheila',
#    'last_name': 'Russell',
#    'sex': 'Female',
#    'age': 80,
#    'marital_status': 'single',
#    'dependants': 1},
#   'address': {'street': 'Flat 9 Mohamed route',
#    'city': 'West Glen',
#    'postcode': 'LL3M 4WS'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 25788,
#    'retired': True,
#    'pension_GBP': 22869},
#   'card': {'card_num': 180000000000000,
#    'card_cvv': 903,
#    'card_iban': 'GB45ORXV49380519147072',
#    'card_start': '2014-12-01',
#    'card_exp': '2016-01-01'},
#   'vehicle': {'vehicle_make': 'Geo',
#    'vehicle_model': 'S7',
#    'vehicle_year': 1993,
#    'vehicle_type': 'Van/Minivan'}}]

# %%
employed_customers
# Out:
# [{'personal': {'first_name': 'Jonathan',
#    'last_name': 'Thomas',
#    'sex': 'Male',
#    'age': 46,
#    'marital_status': 'married or civil partner',
#    'dependants': 1},
#   'address': {'street': '00 Wheeler wells',
#    'city': 'Chapmanton',
#    'postcode': 'L2 7BT'},
#   'work': {'employer': 'Begum-Williams',
#    'commute': 13.72,
#    'salary_GBP': 54016,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4530000000000000,
#    'card_cvv': 583,
#    'card_iban': 'GB37UMCO54540228728019',
#    'card_start': '2008-12-01',
#    'card_exp': '2026-11-01'},
#   'vehicle': {'vehicle_make': 'Nissan',
#    'vehicle_model': 'ATS',
#    'vehicle_year': 1996,
#    'vehicle_type': 'Coupe'}},
#  {'personal': {'first_name': 'Antony',
#    'last_name': 'Jones',
#    'sex': 'Male',
#    'age': 22,
#    'marital_status': 'married or civil partner',
#    'dependants': 1},
#   'address': {'street': 'Studio 33K Joel walk',
#    'city': 'Randallborough',
#    'postcode': 'ME3N 1GH'},
#   'work': {'employer': 'Hill-Wright',
#    'commute': 16.02,
#    'salary_GBP': 68049,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4090000000000000000,
#    'card_cvv': 422,
#    'card_iban': 'GB40CVUE84011545859591',
#    'card_start': '2019-11-01',
#    'card_exp': '2027-07-01'},
#   'vehicle': {'vehicle_make': 'GMC',
#    'vehicle_model': 'Achieva',
#    'vehicle_year': 2015,
#    'vehicle_type': 'Convertible, Coupe'}},
#  {'personal': {'first_name': 'Henry',
#    'last_name': 'Shaw',
#    'sex': 'Male',
#    'age': 56,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': 'Studio 46S Bethany lights',
#    'city': 'East Reece',
#    'postcode': 'E10 9RJ'},
#   'work': {'employer': 'Green LLC',
#    'commute': 19.35,
#    'salary_GBP': 91337,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4670000000000000000,
#    'card_cvv': 669,
#    'card_iban': 'GB40YPKK71613332239280',
#    'card_start': '2017-10-01',
#    'card_exp': '2018-04-01'},
#   'vehicle': {'vehicle_make': 'Scion',
#    'vehicle_model': 'F150 SuperCrew Cab',
#    'vehicle_year': 1994,
#    'vehicle_type': 'Pickup'}},
#  {'personal': {'first_name': 'Jodie',
#    'last_name': "O'Brien",
#    'sex': 'Female',
#    'age': 57,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': 'Flat 3 Christine views',
#    'city': 'Fletcherstad',
#    'postcode': 'WS2 9SN'},
#   'work': {'employer': 'Hill, Evans and Harrison',
#    'commute': 5.94,
#    'salary_GBP': 18446,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 2250000000000000,
#    'card_cvv': 659,
#    'card_iban': 'GB95WAYW31715898077181',
#    'card_start': '2019-04-01',
#    'card_exp': '2027-11-01'},
#   'vehicle': {'vehicle_make': 'Buick',
#    'vehicle_model': 'Outback',
#    'vehicle_year': 2020,
#    'vehicle_type': 'SUV'}},
#  {'personal': {'first_name': 'Ryan',
#    'last_name': 'Clarke',
#    'sex': 'Male',
#    'age': 23,
#    'marital_status': 'married or civil partner',
#    'dependants': 3},
#   'address': {'street': 'Studio 43M Emily rapid',
#    'city': 'West Derekborough',
#    'postcode': 'W1J 0DL'},
#   'work': {'employer': 'Gill and Sons',
#    'commute': 10.73,
#    'salary_GBP': 38100,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4490000000000000000,
#    'card_cvv': 123,
#    'card_iban': 'GB29SSDY05529526374313',
#    'card_start': '2015-03-01',
#    'card_exp': '2015-05-01'},
#   'vehicle': {'vehicle_make': 'Lexus',
#    'vehicle_model': 'Paceman',
#    'vehicle_year': 2004,
#    'vehicle_type': 'Van/Minivan'}},
#  {'personal': {'first_name': 'Julian',
#    'last_name': 'Potter',
#    'sex': 'Male',
#    'age': 43,
#    'marital_status': 'single',
#    'dependants': 3},
#   'address': {'street': '24 Heather locks',
#    'city': 'New Mathew',
#    'postcode': 'WD10 1LX'},
#   'work': {'employer': 'Clark Group',
#    'commute': 20.05,
#    'salary_GBP': 96645,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 37000000000000,
#    'card_cvv': 622,
#    'card_iban': 'GB92PWOB18937027850061',
#    'card_start': '2007-12-01',
#    'card_exp': '2029-03-01'},
#   'vehicle': {'vehicle_make': 'Lexus',
#    'vehicle_model': 'S-Series',
#    'vehicle_year': 1998,
#    'vehicle_type': 'Van/Minivan'}},
#  {'personal': {'first_name': 'Joan',
#    'last_name': 'Stanley',
#    'sex': 'Female',
#    'age': 33,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': '798 Yates crescent',
#    'city': 'Port Lisa',
#    'postcode': 'LS0M 7UU'},
#   'work': {'employer': 'Richardson and Sons',
#    'commute': 15.29,
#    'salary_GBP': 63433,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 30200000000000,
#    'card_cvv': 849,
#    'card_iban': 'GB80GFKU97154647098789',
#    'card_start': '2013-05-01',
#    'card_exp': '2020-08-01'},
#   'vehicle': {'vehicle_make': 'Volkswagen',
#    'vehicle_model': 'Town & Country',
#    'vehicle_year': 2010,
#    'vehicle_type': 'Sedan, Coupe, Hatchback'}},
#  {'personal': {'first_name': 'Kimberley',
#    'last_name': 'Turner',
#    'sex': 'Female',
#    'age': 64,
#    'marital_status': 'married or civil partner',
#    'dependants': 3},
#   'address': {'street': '2 Robert squares',
#    'city': 'North Martyn',
#    'postcode': 'LN2 4JH'},
#   'work': {'employer': 'Gray-James',
#    'commute': 11.11,
#    'salary_GBP': 39983,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4710000000000000,
#    'card_cvv': 843,
#    'card_iban': 'GB95JQAU66555098753975',
#    'card_start': '2019-05-01',
#    'card_exp': '2029-03-01'},
#   'vehicle': {'vehicle_make': 'Volvo',
#    'vehicle_model': 'Tundra Double Cab',
#    'vehicle_year': 2011,
#    'vehicle_type': 'Sedan'}},
#  {'personal': {'first_name': 'Stuart',
#    'last_name': 'Page',
#    'sex': 'Male',
#    'age': 68,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': '6 Frances flats',
#    'city': 'Lake Amberchester',
#    'postcode': 'NE5E 5AD'},
#   'work': {'employer': 'Mitchell-Brown',
#    'commute': 7.5,
#    'salary_GBP': 24062,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4030000000000,
#    'card_cvv': 404,
#    'card_iban': 'GB52JKQX17539370637650',
#    'card_start': '2018-06-01',
#    'card_exp': '2022-12-01'},
#   'vehicle': {'vehicle_make': 'Volkswagen',
#    'vehicle_model': 'Stratus',
#    'vehicle_year': 2012,
#    'vehicle_type': 'SUV'}},
#  {'personal': {'first_name': 'Hollie',
#    'last_name': 'Gray',
#    'sex': 'Female',
#    'age': 45,
#    'marital_status': 'single',
#    'dependants': 3},
#   'address': {'street': 'Flat 29 Liam greens',
#    'city': 'West Liamview',
#    'postcode': 'S78 9WZ'},
#   'work': {'employer': 'Bailey, Gibson and Wallace',
#    'commute': 20.21,
#    'salary_GBP': 97948,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 375000000000000,
#    'card_cvv': 237,
#    'card_iban': 'GB32JFUZ85486983593277',
#    'card_start': '2019-03-01',
#    'card_exp': '2023-02-01'},
#   'vehicle': {'vehicle_make': 'Ford',
#    'vehicle_model': '1500 Regular Cab',
#    'vehicle_year': 2008,
#    'vehicle_type': 'Convertible'}},
#  {'personal': {'first_name': 'Lawrence',
#    'last_name': 'Smith',
#    'sex': 'Male',
#    'age': 56,
#    'marital_status': 'married or civil partner',
#    'dependants': 3},
#   'address': {'street': 'Studio 75 Matthew tunnel',
#    'city': 'Patelville',
#    'postcode': 'L85 4LT'},
#   'work': {'employer': 'Jones Inc',
#    'commute': 9.48,
#    'salary_GBP': 32281,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 3560000000000000,
#    'card_cvv': 69,
#    'card_iban': 'GB80OOIU80240902240471',
#    'card_start': '2017-04-01',
#    'card_exp': '2020-12-01'},
#   'vehicle': {'vehicle_make': 'Lincoln',
#    'vehicle_model': 'Sierra 2500 HD Crew Cab',
#    'vehicle_year': 2016,
#    'vehicle_type': 'Pickup'}},
#  {'personal': {'first_name': 'Ronald',
#    'last_name': 'Pearce',
#    'sex': 'Male',
#    'age': 55,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': '8 Lesley estates',
#    'city': 'South Albertmouth',
#    'postcode': 'L1D 2GY'},
#   'work': {'employer': 'Butler PLC',
#    'commute': 17.53,
#    'salary_GBP': 78214,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4040000000000,
#    'card_cvv': 885,
#    'card_iban': 'GB63SWMR56023428926868',
#    'card_start': '2014-06-01',
#    'card_exp': '2029-04-01'},
#   'vehicle': {'vehicle_make': 'Acura',
#    'vehicle_model': 'S10 Regular Cab',
#    'vehicle_year': 1999,
#    'vehicle_type': 'Pickup'}},
#  {'personal': {'first_name': 'Josephine',
#    'last_name': 'Saunders',
#    'sex': 'Female',
#    'age': 40,
#    'marital_status': 'married or civil partner',
#    'dependants': 3},
#   'address': {'street': '6 Karl path',
#    'city': 'Lake Kateborough',
#    'postcode': 'L2 1YW'},
#   'work': {'employer': 'White PLC',
#    'commute': 18.76,
#    'salary_GBP': 86961,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 3580000000000000,
#    'card_cvv': 388,
#    'card_iban': 'GB95JPHC00666850049083',
#    'card_start': '2014-07-01',
#    'card_exp': '2017-02-01'},
#   'vehicle': {'vehicle_make': 'Hyundai',
#    'vehicle_model': 'Colorado Extended Cab',
#    'vehicle_year': 2017,
#    'vehicle_type': 'Sedan'}},
#  {'personal': {'first_name': 'Tina',
#    'last_name': 'Thornton',
#    'sex': 'Female',
#    'age': 28,
#    'marital_status': 'single',
#    'dependants': 2},
#   'address': {'street': 'Studio 9 Joan tunnel',
#    'city': 'Birdview',
#    'postcode': 'LS3 9ZL'},
#   'work': {'employer': 'McCarthy and Sons',
#    'commute': 6.65,
#    'salary_GBP': 20918,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 6010000000000000,
#    'card_cvv': 588,
#    'card_iban': 'GB02YMXX98886109551024',
#    'card_start': '2014-03-01',
#    'card_exp': '2023-06-01'},
#   'vehicle': {'vehicle_make': 'Mercedes-Benz',
#    'vehicle_model': 'RX',
#    'vehicle_year': 1992,
#    'vehicle_type': 'Hatchback, Convertible'}},
#  {'personal': {'first_name': 'Lauren',
#    'last_name': 'Smith',
#    'sex': 'Female',
#    'age': 64,
#    'marital_status': 'married or civil partner',
#    'dependants': 3},
#   'address': {'street': 'Studio 24F Cartwright mission',
#    'city': 'Lake Cheryl',
#    'postcode': 'EX5 7QJ'},
#   'work': {'employer': 'Dickinson LLC',
#    'commute': 11.2,
#    'salary_GBP': 40432,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4520000000000000,
#    'card_cvv': 592,
#    'card_iban': 'GB13NXGK90881253380683',
#    'card_start': '2013-09-01',
#    'card_exp': '2016-04-01'},
#   'vehicle': {'vehicle_make': 'Nissan',
#    'vehicle_model': 'Ram 3500 Quad Cab',
#    'vehicle_year': 2019,
#    'vehicle_type': 'Wagon, Sedan'}},
#  {'personal': {'first_name': 'Tracy',
#    'last_name': 'White',
#    'sex': 'Female',
#    'age': 61,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': '409 Julie cliff',
#    'city': 'North Benjamin',
#    'postcode': 'SK1 8EA'},
#   'work': {'employer': 'Pugh-Ahmed',
#    'commute': 15.12,
#    'salary_GBP': 62377,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4350000000000000000,
#    'card_cvv': 981,
#    'card_iban': 'GB46TBUI88094503861317',
#    'card_start': '2012-11-01',
#    'card_exp': '2019-08-01'},
#   'vehicle': {'vehicle_make': 'Chevrolet',
#    'vehicle_model': 'Navigator',
#    'vehicle_year': 2008,
#    'vehicle_type': 'Van/Minivan'}},
#  {'personal': {'first_name': 'Lynne',
#    'last_name': 'Smith',
#    'sex': 'Female',
#    'age': 61,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': 'Studio 98v Watson manors',
#    'city': 'Parkershire',
#    'postcode': 'E58 7QE'},
#   'work': {'employer': 'Wall Inc',
#    'commute': 18.23,
#    'salary_GBP': 83114,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4200000000000,
#    'card_cvv': 215,
#    'card_iban': 'GB95OJRW46308657171586',
#    'card_start': '2018-07-01',
#    'card_exp': '2020-06-01'},
#   'vehicle': {'vehicle_make': 'Ford',
#    'vehicle_model': 'Sierra 2500 HD Regular Cab',
#    'vehicle_year': 2009,
#    'vehicle_type': 'Wagon'}},
#  {'personal': {'first_name': 'Sian',
#    'last_name': 'Marshall',
#    'sex': 'Female',
#    'age': 40,
#    'marital_status': 'married or civil partner',
#    'dependants': 0},
#   'address': {'street': '9 Hargreaves loaf',
#    'city': 'New Keith',
#    'postcode': 'OX85 1NN'},
#   'work': {'employer': 'Frost-Howard',
#    'commute': 11.98,
#    'salary_GBP': 44434,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 3580000000000000,
#    'card_cvv': 426,
#    'card_iban': 'GB24RDII19341179851384',
#    'card_start': '2018-09-01',
#    'card_exp': '2023-02-01'},
#   'vehicle': {'vehicle_make': 'MAZDA',
#    'vehicle_model': 'Tundra Regular Cab',
#    'vehicle_year': '2001',
#    'vehicle_type': 'Sedan'}},
#  {'personal': {'first_name': 'Lindsey',
#    'last_name': 'Williams',
#    'sex': 'Female',
#    'age': 75,
#    'marital_status': 'single',
#    'dependants': 1},
#   'address': {'street': 'Studio 5 Morgan shore',
#    'city': 'Murrayshire',
#    'postcode': 'N2B 6BQ'},
#   'work': {'employer': 'Taylor-Price',
#    'commute': 17.76,
#    'salary_GBP': 79823,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 3600000000000000,
#    'card_cvv': 779,
#    'card_iban': 'GB13LRBV70338974739597',
#    'card_start': '2017-12-01',
#    'card_exp': '2025-07-01'},
#   'vehicle': {'vehicle_make': 'Toyota',
#    'vehicle_model': 'Silverado 3500 HD Crew Cab',
#    'vehicle_year': 2008,
#    'vehicle_type': 'SUV'}},
#  {'personal': {'first_name': 'Billy',
#    'last_name': 'Turner',
#    'sex': 'Male',
#    'age': 30,
#    'marital_status': 'single',
#    'dependants': 2},
#   'address': {'street': 'Flat 7 Nicholas extensions',
#    'city': 'Claireside',
#    'postcode': 'G1 8ND'},
#   'work': {'employer': 'Chapman-Roberts',
#    'commute': 17.22,
#    'salary_GBP': 76038,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4420000000000000,
#    'card_cvv': 844,
#    'card_iban': 'GB20SYOG64532798985587',
#    'card_start': '2007-12-01',
#    'card_exp': '2024-01-01'},
#   'vehicle': {'vehicle_make': 'Mitsubishi',
#    'vehicle_model': 'Optima Hybrid',
#    'vehicle_year': 2002,
#    'vehicle_type': 'Sedan'}},
#  {'personal': {'first_name': 'Elliot',
#    'last_name': 'Iqbal',
#    'sex': 'Male',
#    'age': 52,
#    'marital_status': 'widowed',
#    'dependants': 2},
#   'address': {'street': 'Studio 3 Duncan spurs',
#    'city': 'Briggsside',
#    'postcode': 'E0T 1XP'},
#   'work': {'employer': 'Hall, Chambers and Hussain',
#    'commute': 17.57,
#    'salary_GBP': 78499,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 341000000000000,
#    'card_cvv': 653,
#    'card_iban': 'GB33EXFR41119491231301',
#    'card_start': '2020-09-01',
#    'card_exp': '2021-05-01'},
#   'vehicle': {'vehicle_make': 'Chrysler',
#    'vehicle_model': 'Camry',
#    'vehicle_year': 2000,
#    'vehicle_type': 'Coupe'}},
#  {'personal': {'first_name': 'Jessica',
#    'last_name': 'Carr',
#    'sex': 'Female',
#    'age': 58,
#    'marital_status': 'married or civil partner',
#    'dependants': 1},
#   'address': {'street': '4 Mitchell ranch',
#    'city': 'Lake Josephinechester',
#    'postcode': 'N5S 7YJ'},
#   'work': {'employer': 'Hall-Bishop',
#    'commute': 10.68,
#    'salary_GBP': 37866,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 3540000000000000,
#    'card_cvv': 555,
#    'card_iban': 'GB34JTYZ40582231795531',
#    'card_start': '2020-09-01',
#    'card_exp': '2028-02-01'},
#   'vehicle': {'vehicle_make': 'Dodge',
#    'vehicle_model': 'Talon',
#    'vehicle_year': 2014,
#    'vehicle_type': 'Coupe, Convertible'}},
#  {'personal': {'first_name': 'Caroline',
#    'last_name': 'Clarke',
#    'sex': 'Female',
#    'age': 32,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': '235 Smith path',
#    'city': 'Singhmouth',
#    'postcode': 'WN71 7XD'},
#   'work': {'employer': 'Rogers, Richards and Thomas',
#    'commute': 16.42,
#    'salary_GBP': 70655,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 6010000000000000,
#    'card_cvv': 190,
#    'card_iban': 'GB02HCXE02205190652485',
#    'card_start': '2015-05-01',
#    'card_exp': '2024-04-01'},
#   'vehicle': {'vehicle_make': 'Hyundai',
#    'vehicle_model': 'Monte Carlo',
#    'vehicle_year': 2011,
#    'vehicle_type': 'Sedan, Wagon'}},
#  {'personal': {'first_name': 'Jack',
#    'last_name': 'Porter',
#    'sex': 'Male',
#    'age': 36,
#    'marital_status': 'single',
#    'dependants': 3},
#   'address': {'street': 'Studio 76l Carr mill',
#    'city': 'South Francesborough',
#    'postcode': 'W7 1DR'},
#   'work': {'employer': 'Henry, Gibson and French',
#    'commute': 17.64,
#    'salary_GBP': 78955,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 582000000000,
#    'card_cvv': 7258,
#    'card_iban': 'GB64SWHN93102765498771',
#    'card_start': '2009-12-01',
#    'card_exp': '2017-04-01'},
#   'vehicle': {'vehicle_make': 'Kia',
#    'vehicle_model': 'X3',
#    'vehicle_year': 2018,
#    'vehicle_type': 'Pickup'}},
#  {'personal': {'first_name': 'Gavin',
#    'last_name': 'Chapman',
#    'sex': 'Male',
#    'age': 18,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': '385 Ward rue',
#    'city': 'Abigailport',
#    'postcode': 'AL0 4BW'},
#   'work': {'employer': 'Barnett, Jones and Jones',
#    'commute': 19.49,
#    'salary_GBP': 92384,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 2720000000000000,
#    'card_cvv': 5547,
#    'card_iban': 'GB15JSIN49600511879663',
#    'card_start': '2013-02-01',
#    'card_exp': '2014-03-01'},
#   'vehicle': {'vehicle_make': 'Nissan',
#    'vehicle_model': 'Canyon Extended Cab',
#    'vehicle_year': 2014,
#    'vehicle_type': 'Coupe'}},
#  {'personal': {'first_name': 'Dennis',
#    'last_name': 'Johnson',
#    'sex': 'Male',
#    'age': 80,
#    'marital_status': 'married or civil partner',
#    'dependants': 1},
#   'address': {'street': 'Flat 59T Barry loop',
#    'city': 'Lindaton',
#    'postcode': 'B60 3LJ'},
#   'work': {'employer': 'Clark, Evans and Lloyd',
#    'commute': 19.67,
#    'salary_GBP': 93744,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4880000000000,
#    'card_cvv': 20,
#    'card_iban': 'GB67BTBB81025265475465',
#    'card_start': '2018-05-01',
#    'card_exp': '2027-01-01'},
#   'vehicle': {'vehicle_make': 'Nissan',
#    'vehicle_model': 'Spirit',
#    'vehicle_year': 2006,
#    'vehicle_type': 'Pickup'}},
#  {'personal': {'first_name': 'Rhys',
#    'last_name': 'George',
#    'sex': 'Male',
#    'age': 55,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': '4 Patel curve',
#    'city': 'Robertstad',
#    'postcode': 'DT33 1UL'},
#   'work': {'employer': 'May, Bennett and Wood',
#    'commute': 14.53,
#    'salary_GBP': 58770,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 3550000000000000,
#    'card_cvv': 106,
#    'card_iban': 'GB96MSSE31514251878599',
#    'card_start': '2007-12-01',
#    'card_exp': '2024-03-01'},
#   'vehicle': {'vehicle_make': 'Aston Martin',
#    'vehicle_model': 'Sierra 1500 Crew Cab',
#    'vehicle_year': 1993,
#    'vehicle_type': 'Hatchback'}},
#  {'personal': {'first_name': 'Denis',
#    'last_name': 'Brown',
#    'sex': 'Male',
#    'age': 65,
#    'marital_status': 'married or civil partner',
#    'dependants': 1},
#   'address': {'street': '949 Kirsty walk',
#    'city': 'Rickymouth',
#    'postcode': 'N77 4DX'},
#   'work': {'employer': 'Warren, Burton and Spencer',
#    'commute': 7.21,
#    'salary_GBP': 22959,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 3530000000000000,
#    'card_cvv': 570,
#    'card_iban': 'GB61PVEV06020291833305',
#    'card_start': '2008-12-01',
#    'card_exp': '2017-04-01'},
#   'vehicle': {'vehicle_make': 'Ford',
#    'vehicle_model': 'Yukon XL 1500',
#    'vehicle_year': 2007,
#    'vehicle_type': 'Wagon, Sedan, Coupe'}},
#  {'personal': {'first_name': 'Jeffrey',
#    'last_name': 'Humphreys',
#    'sex': 'Male',
#    'age': 39,
#    'marital_status': 'divorced',
#    'dependants': 2},
#   'address': {'street': '004 Julian estates',
#    'city': 'Colinhaven',
#    'postcode': 'KT54 9TR'},
#   'work': {'employer': 'Kay, Chapman and Wilson',
#    'commute': 18.81,
#    'salary_GBP': 87308,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4100000000000000,
#    'card_cvv': 615,
#    'card_iban': 'GB34LHKJ06609001114424',
#    'card_start': '2016-01-01',
#    'card_exp': '2025-08-01'},
#   'vehicle': {'vehicle_make': 'Saab',
#    'vehicle_model': 'Transit Connect Cargo',
#    'vehicle_year': 2005,
#    'vehicle_type': 'SUV'}},
#  {'personal': {'first_name': 'Joyce',
#    'last_name': 'Brown',
#    'sex': 'Female',
#    'age': 42,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': 'Studio 63 Rachel underpass',
#    'city': 'Gallaghermouth',
#    'postcode': 'G99 3GH'},
#   'work': {'employer': 'Stevenson Group',
#    'commute': 12.44,
#    'salary_GBP': 46864,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4610000000000,
#    'card_cvv': 926,
#    'card_iban': 'GB09RXOP90874575465239',
#    'card_start': '2013-07-01',
#    'card_exp': '2013-08-01'},
#   'vehicle': {'vehicle_make': 'Mercedes-Benz',
#    'vehicle_model': 'Veloster',
#    'vehicle_year': 2011,
#    'vehicle_type': 'Convertible'}},
#  {'personal': {'first_name': 'Dawn',
#    'last_name': 'Young',
#    'sex': 'Female',
#    'age': 35,
#    'marital_status': 'married or civil partner',
#    'dependants': 4},
#   'address': {'street': '75 Gordon courts',
#    'city': 'Lorraineberg',
#    'postcode': 'L56 2JA'},
#   'work': {'employer': 'Wright and Sons',
#    'commute': 15.36,
#    'salary_GBP': 63857,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 6010000000000000,
#    'card_cvv': 660,
#    'card_iban': 'GB86CXKN23940068226539',
#    'card_start': '2019-10-01',
#    'card_exp': '2021-07-01'},
#   'vehicle': {'vehicle_make': 'Chevrolet',
#    'vehicle_model': 'S2000',
#    'vehicle_year': 2002,
#    'vehicle_type': 'SUV'}},
#  {'personal': {'first_name': 'Darren',
#    'last_name': 'Nicholls',
#    'sex': 'Male',
#    'age': 54,
#    'marital_status': 'married or civil partner',
#    'dependants': 1},
#   'address': {'street': 'Studio 09F Allen road',
#    'city': 'Port Rachel',
#    'postcode': 'TS9 1TL'},
#   'work': {'employer': 'Thomson, Kirby and Barker',
#    'commute': 9.85,
#    'salary_GBP': 33987,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 3580000000000000,
#    'card_cvv': 113,
#    'card_iban': 'GB12URYF32648832649281',
#    'card_start': '2019-05-01',
#    'card_exp': '2023-08-01'},
#   'vehicle': {'vehicle_make': 'Volkswagen',
#    'vehicle_model': '300',
#    'vehicle_year': 2015,
#    'vehicle_type': 'Sedan'}},
#  {'personal': {'first_name': 'Lauren',
#    'last_name': 'Martin',
#    'sex': 'Female',
#    'age': 20,
#    'marital_status': 'widowed',
#    'dependants': 2},
#   'address': {'street': 'Studio 7 Jemma cliff',
#    'city': 'Turnerbury',
#    'postcode': 'B98 1HT'},
#   'work': {'employer': 'Smith-Smith',
#    'commute': 7.65,
#    'salary_GBP': 24652,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4930000000000000,
#    'card_cvv': 373,
#    'card_iban': 'GB41AMAJ35865980015154',
#    'card_start': '2004-12-01',
#    'card_exp': '2024-01-01'},
#   'vehicle': {'vehicle_make': 'GMC',
#    'vehicle_model': 'Phaeton',
#    'vehicle_year': 2008,
#    'vehicle_type': 'SUV'}},
#  {'personal': {'first_name': 'Melanie',
#    'last_name': "O'Brien",
#    'sex': 'Female',
#    'age': 51,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': 'Flat 08d Ward squares',
#    'city': 'Phillipside',
#    'postcode': 'BB3A 9PE'},
#   'work': {'employer': 'Clarke Inc',
#    'commute': 6.45,
#    'salary_GBP': 20206,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 213000000000000,
#    'card_cvv': 542,
#    'card_iban': 'GB14FFMB81152248185033',
#    'card_start': '2001-12-01',
#    'card_exp': '2023-09-01'},
#   'vehicle': {'vehicle_make': 'Pontiac',
#    'vehicle_model': '2500 Regular Cab',
#    'vehicle_year': 1997,
#    'vehicle_type': 'Sedan'}},
#  {'personal': {'first_name': 'Vanessa',
#    'last_name': 'Hussain',
#    'sex': 'Female',
#    'age': 42,
#    'marital_status': 'single',
#    'dependants': 2},
#   'address': {'street': '28 Oliver fort',
#    'city': 'Melissaport',
#    'postcode': 'DY95 0UG'},
#   'work': {'employer': 'Smith PLC',
#    'commute': 20.08,
#    'salary_GBP': 96882,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4030000000000000,
#    'card_cvv': 326,
#    'card_iban': 'GB50MQKE98379126728837',
#    'card_start': '2013-12-01',
#    'card_exp': '2014-11-01'},
#   'vehicle': {'vehicle_make': 'Lexus',
#    'vehicle_model': 'TrailBlazer',
#    'vehicle_year': 2001,
#    'vehicle_type': 'Van/Minivan'}},
#  {'personal': {'first_name': 'Chelsea',
#    'last_name': 'Thorpe',
#    'sex': 'Female',
#    'age': 43,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': 'Flat 39 Shaun dam',
#    'city': 'Martinbury',
#    'postcode': 'N9W 3EN'},
#   'work': {'employer': 'Sutton LLC',
#    'commute': 17.96,
#    'salary_GBP': 81215,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 2240000000000000,
#    'card_cvv': 751,
#    'card_iban': 'GB23IKFU36409120028603',
#    'card_start': '2016-06-01',
#    'card_exp': '2017-01-01'},
#   'vehicle': {'vehicle_make': 'Nissan',
#    'vehicle_model': 'Tundra Regular Cab',
#    'vehicle_year': 2013,
#    'vehicle_type': 'Van/Minivan'}},
#  {'personal': {'first_name': 'Sarah',
#    'last_name': 'Robinson',
#    'sex': 'Female',
#    'age': 38,
#    'marital_status': 'single',
#    'dependants': 2},
#   'address': {'street': 'Studio 77T Emily path',
#    'city': 'West Connor',
#    'postcode': 'NW7B 5ZR'},
#   'work': {'employer': 'Dickinson, Nolan and Smith',
#    'commute': 6.35,
#    'salary_GBP': 19863,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4420000000000000000,
#    'card_cvv': 800,
#    'card_iban': 'GB72SOVW84817129799960',
#    'card_start': '2018-09-01',
#    'card_exp': '2026-02-01'},
#   'vehicle': {'vehicle_make': 'INFINITI',
#    'vehicle_model': 'Sportvan G20',
#    'vehicle_year': 2020,
#    'vehicle_type': 'SUV'}},
#  {'personal': {'first_name': 'Zoe',
#    'last_name': 'Williams',
#    'sex': 'Female',
#    'age': 59,
#    'marital_status': 'widowed',
#    'dependants': 1},
#   'address': {'street': 'Flat 66f Anderson fords',
#    'city': 'Aaronburgh',
#    'postcode': 'E33 3NW'},
#   'work': {'employer': 'Blake-Johnson',
#    'commute': 15.52,
#    'salary_GBP': 64885,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4860000000000000000,
#    'card_cvv': 854,
#    'card_iban': 'GB73OAWO74482506912387',
#    'card_start': '2020-04-01',
#    'card_exp': '2026-02-01'},
#   'vehicle': {'vehicle_make': 'Cadillac',
#    'vehicle_model': 'Tacoma Double Cab',
#    'vehicle_year': 2016,
#    'vehicle_type': 'Coupe, Sedan'}},
#  {'personal': {'first_name': 'Dorothy',
#    'last_name': 'Leonard',
#    'sex': 'Female',
#    'age': 72,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': 'Studio 30X Clive hills',
#    'city': 'East Katemouth',
#    'postcode': 'SN5V 1JD'},
#   'work': {'employer': 'Archer-Dean',
#    'commute': 9.28,
#    'salary_GBP': 31412,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 38700000000000,
#    'card_cvv': 510,
#    'card_iban': 'GB53SWXB45203854278672',
#    'card_start': '2015-05-01',
#    'card_exp': '2018-10-01'},
#   'vehicle': {'vehicle_make': 'Dodge',
#    'vehicle_model': 'B-Series Regular Cab',
#    'vehicle_year': 2017,
#    'vehicle_type': 'Sedan'}},
#  {'personal': {'first_name': 'Ashley',
#    'last_name': 'Sullivan',
#    'sex': 'Male',
#    'age': 50,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': '34 Amanda trace',
#    'city': 'North Juliamouth',
#    'postcode': 'HU28 3AR'},
#   'work': {'employer': 'Williams-Jones',
#    'commute': 5.81,
#    'salary_GBP': 18005,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 379000000000000,
#    'card_cvv': 586,
#    'card_iban': 'GB22OTJE53991614349608',
#    'card_start': '2006-12-01',
#    'card_exp': '2017-07-01'},
#   'vehicle': {'vehicle_make': 'Mercedes-Benz',
#    'vehicle_model': 'Sprinter 2500 Crew',
#    'vehicle_year': 2014,
#    'vehicle_type': 'Pickup'}},
#  {'personal': {'first_name': 'Lindsey',
#    'last_name': 'Perry',
#    'sex': 'Female',
#    'age': 22,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': 'Studio 39L Fisher junction',
#    'city': 'Lukeport',
#    'postcode': 'B5 6HB'},
#   'work': {'employer': 'Phillips-Nixon',
#    'commute': 19.12,
#    'salary_GBP': 89661,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4660000000000,
#    'card_cvv': 643,
#    'card_iban': 'GB04OJXZ36629513168495',
#    'card_start': '2018-01-01',
#    'card_exp': '2027-06-01'},
#   'vehicle': {'vehicle_make': 'Toyota',
#    'vehicle_model': 'Civic',
#    'vehicle_year': 2018,
#    'vehicle_type': 'Coupe, Convertible'}},
#  {'personal': {'first_name': 'Grace',
#    'last_name': 'Davies',
#    'sex': 'Female',
#    'age': 57,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': 'Studio 88 Collins fords',
#    'city': 'Lake Howard',
#    'postcode': 'W4 0AA'},
#   'work': {'employer': 'Collins Group',
#    'commute': 18.78,
#    'salary_GBP': 87098,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4570000000000000000,
#    'card_cvv': 132,
#    'card_iban': 'GB51LSRK16179476021409',
#    'card_start': '2019-04-01',
#    'card_exp': '2025-10-01'},
#   'vehicle': {'vehicle_make': 'Chrysler',
#    'vehicle_model': 'Sierra 3500 HD Crew Cab',
#    'vehicle_year': 2006,
#    'vehicle_type': 'Sedan'}},
#  {'personal': {'first_name': 'Albert',
#    'last_name': 'Steele',
#    'sex': 'Male',
#    'age': 60,
#    'marital_status': 'married or civil partner',
#    'dependants': 3},
#   'address': {'street': '82 Paige bridge',
#    'city': 'Port Elaine',
#    'postcode': 'B5 3BF'},
#   'work': {'employer': 'Webb Group',
#    'commute': 7.57,
#    'salary_GBP': 24329,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 2720000000000000,
#    'card_cvv': 899,
#    'card_iban': 'GB61YUTS59935062271665',
#    'card_start': '2014-02-01',
#    'card_exp': '2026-07-01'},
#   'vehicle': {'vehicle_make': 'Ford',
#    'vehicle_model': 'Prelude',
#    'vehicle_year': 2012,
#    'vehicle_type': 'SUV'}},
#  {'personal': {'first_name': 'Peter',
#    'last_name': 'Burton',
#    'sex': 'Male',
#    'age': 63,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': 'Studio 38 James throughway',
#    'city': 'Leighton',
#    'postcode': 'M8E 7HJ'},
#   'work': {'employer': 'Graham, Watts and Hall',
#    'commute': 5.58,
#    'salary_GBP': 17245,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4060000000000,
#    'card_cvv': 458,
#    'card_iban': 'GB30EGRJ34862965423758',
#    'card_start': '2011-12-01',
#    'card_exp': '2022-07-01'},
#   'vehicle': {'vehicle_make': 'Dodge',
#    'vehicle_model': 'Sorento',
#    'vehicle_year': 2016,
#    'vehicle_type': 'Sedan, Coupe, Hatchback'}},
#  {'personal': {'first_name': 'Christopher',
#    'last_name': 'Jackson',
#    'sex': 'Male',
#    'age': 33,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': 'Flat 05 Hope prairie',
#    'city': 'Lake Grace',
#    'postcode': 'NG0R 7SG'},
#   'work': {'employer': 'Jones Ltd',
#    'commute': 11.51,
#    'salary_GBP': 41981,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 3600000000000000,
#    'card_cvv': 927,
#    'card_iban': 'GB30EKXF93283283335493',
#    'card_start': '2013-09-01',
#    'card_exp': '2026-05-01'},
#   'vehicle': {'vehicle_make': 'Cadillac',
#    'vehicle_model': 'V90',
#    'vehicle_year': 1996,
#    'vehicle_type': 'Van/Minivan'}},
#  {'personal': {'first_name': 'Gavin',
#    'last_name': 'Holland',
#    'sex': 'Male',
#    'age': 46,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': '83 Jemma estates',
#    'city': 'Patelchester',
#    'postcode': 'KA1N 5UP'},
#   'work': {'employer': 'Bailey-George',
#    'commute': 17.08,
#    'salary_GBP': 75117,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 60416002073,
#    'card_cvv': 61,
#    'card_iban': 'GB05MUJX37298335273577',
#    'card_start': '2018-03-01',
#    'card_exp': '2029-05-01'},
#   'vehicle': {'vehicle_make': 'Ford',
#    'vehicle_model': '3000GT',
#    'vehicle_year': 2003,
#    'vehicle_type': 'Van/Minivan'}},
#  {'personal': {'first_name': 'Christian',
#    'last_name': 'Rogers',
#    'sex': 'Male',
#    'age': 66,
#    'marital_status': 'single',
#    'dependants': 4},
#   'address': {'street': 'Studio 15 Cooper forges',
#    'city': 'Port Joel',
#    'postcode': 'B2 9AL'},
#   'work': {'employer': 'Patel-Singh',
#    'commute': 14.39,
#    'salary_GBP': 57934,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 60467338848,
#    'card_cvv': 552,
#    'card_iban': 'GB97UEAX89313220430163',
#    'card_start': '2020-08-01',
#    'card_exp': '2024-10-01'},
#   'vehicle': {'vehicle_make': 'Toyota',
#    'vehicle_model': 'Tiburon',
#    'vehicle_year': 1998,
#    'vehicle_type': 'Sedan'}},
#  {'personal': {'first_name': 'Kenneth',
#    'last_name': 'Lewis',
#    'sex': 'Male',
#    'age': 42,
#    'marital_status': 'divorced',
#    'dependants': 4},
#   'address': {'street': 'Flat 76j Carter junctions',
#    'city': 'Stanleyton',
#    'postcode': 'L9B 0AL'},
#   'work': {'employer': 'Pritchard PLC',
#    'commute': 14.02,
#    'salary_GBP': 55758,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 3520000000000000,
#    'card_cvv': 168,
#    'card_iban': 'GB98HIIZ00956490663842',
#    'card_start': '2019-09-01',
#    'card_exp': '2024-04-01'},
#   'vehicle': {'vehicle_make': 'Isuzu',
#    'vehicle_model': '929',
#    'vehicle_year': 2003,
#    'vehicle_type': 'SUV'}},
#  {'personal': {'first_name': 'Steven',
#    'last_name': 'Stanley',
#    'sex': 'Male',
#    'age': 42,
#    'marital_status': 'widowed',
#    'dependants': 1},
#   'address': {'street': 'Flat 59 Joel pass',
#    'city': 'Murphystad',
#    'postcode': 'B4 6PT'},
#   'work': {'employer': 'Fletcher LLC',
#    'commute': 17.34,
#    'salary_GBP': 76921,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4250000000000000000,
#    'card_cvv': 177,
#    'card_iban': 'GB60ABVW08545614890191',
#    'card_start': '2017-09-01',
#    'card_exp': '2018-03-01'},
#   'vehicle': {'vehicle_make': 'Chrysler',
#    'vehicle_model': 'Savana 2500 Cargo',
#    'vehicle_year': 2000,
#    'vehicle_type': 'Coupe'}},
#  {'personal': {'first_name': 'Carly',
#    'last_name': 'Wright',
#    'sex': 'Female',
#    'age': 32,
#    'marital_status': 'married or civil partner',
#    'dependants': 5},
#   'address': {'street': 'Studio 20 Lisa shores',
#    'city': 'Malcolmstad',
#    'postcode': 'SE7B 0WY'},
#   'work': {'employer': 'Edwards, Clarke and Palmer',
#    'commute': 15.91,
#    'salary_GBP': 67367,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 2700000000000000,
#    'card_cvv': 864,
#    'card_iban': 'GB36ZZMR85340990776081',
#    'card_start': '2013-06-01',
#    'card_exp': '2027-05-01'},
#   'vehicle': {'vehicle_make': 'Nissan',
#    'vehicle_model': 'Excel',
#    'vehicle_year': 2000,
#    'vehicle_type': 'SUV'}},
#  {'personal': {'first_name': 'Lorraine',
#    'last_name': 'Duncan',
#    'sex': 'Female',
#    'age': 33,
#    'marital_status': 'single',
#    'dependants': 4},
#   'address': {'street': '487 Gordon village',
#    'city': 'Hicksstad',
#    'postcode': 'E8E 8BN'},
#   'work': {'employer': 'Williams PLC',
#    'commute': 11.95,
#    'salary_GBP': 44279,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 36100000000000,
#    'card_cvv': 308,
#    'card_iban': 'GB49DVCP36360318826870',
#    'card_start': '2016-05-01',
#    'card_exp': '2024-12-01'},
#   'vehicle': {'vehicle_make': 'Plymouth',
#    'vehicle_model': 'F150 SuperCrew Cab',
#    'vehicle_year': 2001,
#    'vehicle_type': 'Van/Minivan'}},
#  {'personal': {'first_name': 'Jasmine',
#    'last_name': 'Khan',
#    'sex': 'Female',
#    'age': 54,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': 'Studio 24X Saunders plain',
#    'city': 'Cartwrightton',
#    'postcode': 'HX36 6ZR'},
#   'work': {'employer': 'Carter, Ward and Smith',
#    'commute': 11.01,
#    'salary_GBP': 39466,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 213000000000000,
#    'card_cvv': 386,
#    'card_iban': 'GB54URZU46329075531104',
#    'card_start': '2013-05-01',
#    'card_exp': '2020-06-01'},
#   'vehicle': {'vehicle_make': 'Toyota',
#    'vehicle_model': 'NV3500 HD Passenger',
#    'vehicle_year': 1994,
#    'vehicle_type': 'Convertible'}},
#  {'personal': {'first_name': 'Darren',
#    'last_name': 'Davies',
#    'sex': 'Male',
#    'age': 48,
#    'marital_status': 'single',
#    'dependants': 2},
#   'address': {'street': '010 Eric street',
#    'city': 'New Reecefurt',
#    'postcode': 'SS7A 4EP'},
#   'work': {'employer': 'Day-Thomas',
#    'commute': 19.13,
#    'salary_GBP': 89697,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4130000000000,
#    'card_cvv': 911,
#    'card_iban': 'GB94ENEM74278534672022',
#    'card_start': '2017-01-01',
#    'card_exp': '2019-01-01'},
#   'vehicle': {'vehicle_make': 'Mercedes-Benz',
#    'vehicle_model': 'DTS',
#    'vehicle_year': 1992,
#    'vehicle_type': 'Sedan'}},
#  {'personal': {'first_name': 'Paula',
#    'last_name': 'Roberts',
#    'sex': 'Female',
#    'age': 37,
#    'marital_status': 'single',
#    'dependants': 2},
#   'address': {'street': 'Flat 23D Nicola isle',
#    'city': 'South Garethmouth',
#    'postcode': 'RG3 2AG'},
#   'work': {'employer': 'Lambert, Parker and Brown',
#    'commute': 11.99,
#    'salary_GBP': 44472,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 6540000000000000,
#    'card_cvv': 77,
#    'card_iban': 'GB87FHXK16979131324991',
#    'card_start': '2019-05-01',
#    'card_exp': '2022-09-01'},
#   'vehicle': {'vehicle_make': 'Jeep',
#    'vehicle_model': 'SX4',
#    'vehicle_year': 2013,
#    'vehicle_type': 'SUV'}},
#  {'personal': {'first_name': 'Carolyn',
#    'last_name': 'Roberts',
#    'sex': 'Female',
#    'age': 67,
#    'marital_status': 'married or civil partner',
#    'dependants': 3},
#   'address': {'street': 'Flat 53 Hollie motorway',
#    'city': 'East Raymond',
#    'postcode': 'JE18 7AJ'},
#   'work': {'employer': 'Richardson-Watts',
#    'commute': 19.27,
#    'salary_GBP': 90740,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4490000000000000000,
#    'card_cvv': 161,
#    'card_iban': 'GB76HNHE42862201326025',
#    'card_start': '2003-12-01',
#    'card_exp': '2015-04-01'},
#   'vehicle': {'vehicle_make': 'Cadillac',
#    'vehicle_model': 'Sienna',
#    'vehicle_year': 2002,
#    'vehicle_type': 'Sedan'}},
#  {'personal': {'first_name': 'Jill',
#    'last_name': 'Bolton',
#    'sex': 'Female',
#    'age': 43,
#    'marital_status': 'single',
#    'dependants': 2},
#   'address': {'street': '7 Damien islands',
#    'city': 'Port Gerald',
#    'postcode': 'DL1X 6LX'},
#   'work': {'employer': 'James, Whitehouse and Mellor',
#    'commute': 17.74,
#    'salary_GBP': 79692,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 38700000000000,
#    'card_cvv': 627,
#    'card_iban': 'GB27ZJWQ46159728183894',
#    'card_start': '2019-02-01',
#    'card_exp': '2023-07-01'},
#   'vehicle': {'vehicle_make': 'Ford',
#    'vehicle_model': 'Capri',
#    'vehicle_year': 2002,
#    'vehicle_type': 'SUV'}},
#  {'personal': {'first_name': 'Ashleigh',
#    'last_name': 'Gray',
#    'sex': 'Female',
#    'age': 29,
#    'marital_status': 'married or civil partner',
#    'dependants': 5},
#   'address': {'street': 'Flat 40m Zoe prairie',
#    'city': 'West Alexanderstad',
#    'postcode': 'OL3 4ZL'},
#   'work': {'employer': 'Morley-Murphy',
#    'commute': 14.97,
#    'salary_GBP': 61470,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 30500000000000,
#    'card_cvv': 828,
#    'card_iban': 'GB21JLVB79701886585201',
#    'card_start': '2016-07-01',
#    'card_exp': '2025-08-01'},
#   'vehicle': {'vehicle_make': 'GMC',
#    'vehicle_model': 'Elantra',
#    'vehicle_year': 1993,
#    'vehicle_type': 'Van/Minivan'}},
#  {'personal': {'first_name': 'Adrian',
#    'last_name': 'Saunders',
#    'sex': 'Male',
#    'age': 26,
#    'marital_status': 'single',
#    'dependants': 2},
#   'address': {'street': 'Flat 50T White mountain',
#    'city': 'New Dennis',
#    'postcode': 'SY7 5DE'},
#   'work': {'employer': 'Baldwin Inc',
#    'commute': 13.28,
#    'salary_GBP': 51461,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4570000000000,
#    'card_cvv': 456,
#    'card_iban': 'GB67ACGW20850632829786',
#    'card_start': '2016-10-01',
#    'card_exp': '2028-08-01'},
#   'vehicle': {'vehicle_make': 'Buick',
#    'vehicle_model': 'Safari Passenger',
#    'vehicle_year': 1999,
#    'vehicle_type': 'Sedan'}},
#  {'personal': {'first_name': 'Beverley',
#    'last_name': 'Marsden',
#    'sex': 'Female',
#    'age': 63,
#    'marital_status': 'married or civil partner',
#    'dependants': 1},
#   'address': {'street': '8 Thompson trace',
#    'city': 'Liamside',
#    'postcode': 'PA38 9ZB'},
#   'work': {'employer': 'Jackson-Crawford',
#    'commute': 15.55,
#    'salary_GBP': 65036,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4430000000000,
#    'card_cvv': 9897,
#    'card_iban': 'GB54LORL45412135355270',
#    'card_start': '2016-06-01',
#    'card_exp': '2019-01-01'},
#   'vehicle': {'vehicle_make': 'Dodge',
#    'vehicle_model': 'F150 Regular Cab',
#    'vehicle_year': 2019,
#    'vehicle_type': 'Van/Minivan'}},
#  {'personal': {'first_name': 'Justin',
#    'last_name': 'Frost',
#    'sex': 'Male',
#    'age': 50,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': '7 Brown keys',
#    'city': 'Warrenberg',
#    'postcode': 'S3K 4HD'},
#   'work': {'employer': 'Johnston PLC',
#    'commute': 18.33,
#    'salary_GBP': 83864,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 375000000000000,
#    'card_cvv': 596,
#    'card_iban': 'GB04FHAM30531487708212',
#    'card_start': '2015-01-01',
#    'card_exp': '2027-04-01'},
#   'vehicle': {'vehicle_make': 'GMC',
#    'vehicle_model': 'Spectra',
#    'vehicle_year': 1999,
#    'vehicle_type': 'Sedan'}},
#  {'personal': {'first_name': 'Chelsea',
#    'last_name': 'Byrne',
#    'sex': 'Female',
#    'age': 73,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': '1 James meadow',
#    'city': 'Gracetown',
#    'postcode': 'L1 6GY'},
#   'work': {'employer': 'White, Bray and Iqbal',
#    'commute': 18.08,
#    'salary_GBP': 82084,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4050000000000,
#    'card_cvv': 635,
#    'card_iban': 'GB97WUTP26823806991952',
#    'card_start': '2015-12-01',
#    'card_exp': '2029-02-01'},
#   'vehicle': {'vehicle_make': 'GMC',
#    'vehicle_model': 'Amigo',
#    'vehicle_year': 1998,
#    'vehicle_type': 'Sedan'}},
#  {'personal': {'first_name': 'Mandy',
#    'last_name': 'Harvey',
#    'sex': 'Female',
#    'age': 54,
#    'marital_status': 'married or civil partner',
#    'dependants': 3},
#   'address': {'street': 'Flat 8 Barry mountain',
#    'city': 'Susanfurt',
#    'postcode': 'IG38 5WD'},
#   'work': {'employer': 'Foster-Carr',
#    'commute': 12.54,
#    'salary_GBP': 47383,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 341000000000000,
#    'card_cvv': 842,
#    'card_iban': 'GB62UTEV49492892867739',
#    'card_start': '2013-04-01',
#    'card_exp': '2022-05-01'},
#   'vehicle': {'vehicle_make': 'Toyota',
#    'vehicle_model': 'X3',
#    'vehicle_year': 2002,
#    'vehicle_type': 'Sedan, Wagon'}},
#  {'personal': {'first_name': 'Henry',
#    'last_name': 'Scott',
#    'sex': 'Male',
#    'age': 72,
#    'marital_status': 'married or civil partner',
#    'dependants': 5},
#   'address': {'street': 'Flat 02U Poole plaza',
#    'city': 'West Callum',
#    'postcode': 'SM8W 0UN'},
#   'work': {'employer': 'Hunt, Rees and Owen',
#    'commute': 11.69,
#    'salary_GBP': 42914,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4020000000000000,
#    'card_cvv': 538,
#    'card_iban': 'GB91OFLB36087357895482',
#    'card_start': '2014-01-01',
#    'card_exp': '2018-05-01'},
#   'vehicle': {'vehicle_make': 'Toyota',
#    'vehicle_model': 'Blazer',
#    'vehicle_year': 2014,
#    'vehicle_type': 'SUV'}},
#  {'personal': {'first_name': 'Lewis',
#    'last_name': 'Lewis',
#    'sex': 'Male',
#    'age': 22,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': 'Studio 5 Barbara rue',
#    'city': 'East Ellie',
#    'postcode': 'W18 8BH'},
#   'work': {'employer': 'Myers PLC',
#    'commute': 8.49,
#    'salary_GBP': 28041,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 3570000000000000,
#    'card_cvv': 498,
#    'card_iban': 'GB63IXPQ33410220621933',
#    'card_start': '2015-01-01',
#    'card_exp': '2026-07-01'},
#   'vehicle': {'vehicle_make': 'Chevrolet',
#    'vehicle_model': 'V40',
#    'vehicle_year': 2008,
#    'vehicle_type': 'Sedan, Wagon'}},
#  {'personal': {'first_name': 'Wendy',
#    'last_name': 'Jones',
#    'sex': 'Female',
#    'age': 28,
#    'marital_status': 'married or civil partner',
#    'dependants': 1},
#   'address': {'street': '541 Quinn mountains',
#    'city': 'Townsendhaven',
#    'postcode': 'TW45 2NG'},
#   'work': {'employer': 'Rose, George and Elliott',
#    'commute': 12.27,
#    'salary_GBP': 45941,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 30200000000000,
#    'card_cvv': 860,
#    'card_iban': 'GB62IEDD44714585832090',
#    'card_start': '2020-04-01',
#    'card_exp': '2026-09-01'},
#   'vehicle': {'vehicle_make': 'Porsche',
#    'vehicle_model': '3500 Mega Cab',
#    'vehicle_year': 2016,
#    'vehicle_type': 'Sedan'}},
#  {'personal': {'first_name': 'Cheryl',
#    'last_name': 'Campbell',
#    'sex': 'Female',
#    'age': 40,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': '67 Brady mountains',
#    'city': 'Carlstad',
#    'postcode': 'M7B 2YX'},
#   'work': {'employer': 'Taylor-Brown',
#    'commute': 20.26,
#    'salary_GBP': 98275,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 3560000000000000,
#    'card_cvv': 393,
#    'card_iban': 'GB44NMNL77554612240878',
#    'card_start': '2020-08-01',
#    'card_exp': '2027-04-01'},
#   'vehicle': {'vehicle_make': 'Hyundai',
#    'vehicle_model': 'Fit',
#    'vehicle_year': 2000,
#    'vehicle_type': 'Coupe, Convertible'}},
#  {'personal': {'first_name': 'Rosemary',
#    'last_name': 'Mills',
#    'sex': 'Female',
#    'age': 60,
#    'marital_status': 'single',
#    'dependants': 2},
#   'address': {'street': '160 Thompson isle',
#    'city': "O'Brienland",
#    'postcode': 'N48 3ZN'},
#   'work': {'employer': 'Jordan, Stevenson and Kerr',
#    'commute': 8.35,
#    'salary_GBP': 27443,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4800000000000000,
#    'card_cvv': 569,
#    'card_iban': 'GB11KDOZ31590635418004',
#    'card_start': '2011-11-01',
#    'card_exp': '2028-08-01'},
#   'vehicle': {'vehicle_make': 'Dodge',
#    'vehicle_model': '5 Series',
#    'vehicle_year': 2005,
#    'vehicle_type': 'Sedan'}},
#  {'personal': {'first_name': 'Reece',
#    'last_name': 'Howells',
#    'sex': 'Male',
#    'age': 42,
#    'marital_status': 'widowed',
#    'dependants': 2},
#   'address': {'street': '9 Danny green',
#    'city': 'Bullstad',
#    'postcode': 'TF14 9AP'},
#   'work': {'employer': 'Taylor, Gould and Gould',
#    'commute': 14.15,
#    'salary_GBP': 56505,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4790000000000000,
#    'card_cvv': 591,
#    'card_iban': 'GB47XGZY81262962304948',
#    'card_start': '2016-04-01',
#    'card_exp': '2029-10-01'},
#   'vehicle': {'vehicle_make': 'Mercury',
#    'vehicle_model': 'Camry',
#    'vehicle_year': 2008,
#    'vehicle_type': 'SUV'}},
#  {'personal': {'first_name': 'Owen',
#    'last_name': 'Mason',
#    'sex': 'Male',
#    'age': 32,
#    'marital_status': 'single',
#    'dependants': 2},
#   'address': {'street': '0 Powell dale',
#    'city': 'West Alexanderland',
#    'postcode': 'E21 8ZZ'},
#   'work': {'employer': 'Taylor, Patel and Lord',
#    'commute': 19.92,
#    'salary_GBP': 95658,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 2280000000000000,
#    'card_cvv': 698,
#    'card_iban': 'GB59ZHIM75072154744976',
#    'card_start': '2014-10-01',
#    'card_exp': '2029-01-01'},
#   'vehicle': {'vehicle_make': 'Chevrolet',
#    'vehicle_model': 'Accord Hybrid',
#    'vehicle_year': 1999,
#    'vehicle_type': 'Van/Minivan'}},
#  {'personal': {'first_name': 'Melissa',
#    'last_name': 'Clayton',
#    'sex': 'Female',
#    'age': 38,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': 'Studio 8 Nicholas club',
#    'city': 'South Lesley',
#    'postcode': 'W6 1XA'},
#   'work': {'employer': 'Davies Group',
# ...
#    'card_start': '2014-03-01',
#    'card_exp': '2017-06-01'},
#   'vehicle': {'vehicle_make': 'Toyota',
#    'vehicle_model': 'Astra',
#    'vehicle_year': 2012,
#    'vehicle_type': 'SUV'}},
#  {'personal': {'first_name': 'Richard',
#    'last_name': 'Greenwood',
#    'sex': 'Male',
#    'age': 20,
#    'marital_status': 'single',
#    'dependants': 2},
#   'address': {'street': 'Flat 13s Lowe club',
#    'city': 'East Jake',
#    'postcode': 'SK7P 2TR'},
#   'work': {'employer': 'Buckley-Collins',
#    'commute': 9.88,
#    'salary_GBP': 34103,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 3570000000000000,
#    'card_cvv': 290,
#    'card_iban': 'GB88ZUHZ89008937806619',
#    'card_start': '2016-02-01',
#    'card_exp': '2020-12-01'},
#   'vehicle': {'vehicle_make': 'Pontiac',
#    'vehicle_model': '3 Series',
#    'vehicle_year': 1995,
#    'vehicle_type': 'Wagon, Sedan'}},
#  {'personal': {'first_name': 'Jill',
#    'last_name': 'Smith',
#    'sex': 'Female',
#    'age': 56,
#    'marital_status': 'single',
#    'dependants': 2},
#   'address': {'street': '1 Scott dale',
#    'city': 'Port Juliahaven',
#    'postcode': 'E4 1HH'},
#   'work': {'employer': 'James, Moore and Griffiths',
#    'commute': 12.88,
#    'salary_GBP': 49274,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4560000000000000,
#    'card_cvv': 805,
#    'card_iban': 'GB41HEAW33422386257035',
#    'card_start': '2011-12-01',
#    'card_exp': '2013-07-01'},
#   'vehicle': {'vehicle_make': 'Nissan',
#    'vehicle_model': 'XT5',
#    'vehicle_year': 1998,
#    'vehicle_type': 'Wagon'}},
#  {'personal': {'first_name': 'Derek',
#    'last_name': 'Willis',
#    'sex': 'Male',
#    'age': 42,
#    'marital_status': 'widowed',
#    'dependants': 4},
#   'address': {'street': 'Studio 13 June plaza',
#    'city': 'Fraserfort',
#    'postcode': 'MK6 8TF'},
#   'work': {'employer': 'Robinson, Smith and Rhodes',
#    'commute': 8.43,
#    'salary_GBP': 27779,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 2490000000000000,
#    'card_cvv': 810,
#    'card_iban': 'GB85BYZH33004165095166',
#    'card_start': '2019-01-01',
#    'card_exp': '2022-04-01'},
#   'vehicle': {'vehicle_make': 'Jaguar',
#    'vehicle_model': 'Civic',
#    'vehicle_year': 2012,
#    'vehicle_type': 'SUV'}},
#  {'personal': {'first_name': 'Molly',
#    'last_name': 'Jackson',
#    'sex': 'Female',
#    'age': 51,
#    'marital_status': 'married or civil partner',
#    'dependants': 3},
#   'address': {'street': 'Flat 56 King light',
#    'city': 'North Brianmouth',
#    'postcode': 'M0 6BL'},
#   'work': {'employer': 'Williams-Owen',
#    'commute': 17.8,
#    'salary_GBP': 80081,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 3600000000000000,
#    'card_cvv': 884,
#    'card_iban': 'GB44HFGK01536480769158',
#    'card_start': '2020-08-01',
#    'card_exp': '2029-09-01'},
#   'vehicle': {'vehicle_make': 'Ford',
#    'vehicle_model': 'Equinox',
#    'vehicle_year': 2018,
#    'vehicle_type': 'Sedan, Wagon'}},
#  {'personal': {'first_name': 'Vincent',
#    'last_name': 'Tomlinson',
#    'sex': 'Male',
#    'age': 68,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': '05 Amelia coves',
#    'city': 'Paigebury',
#    'postcode': 'NE9 0TH'},
#   'work': {'employer': 'Marshall Group',
#    'commute': 17.84,
#    'salary_GBP': 80386,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 2710000000000000,
#    'card_cvv': 442,
#    'card_iban': 'GB20EBXM99989526790238',
#    'card_start': '2017-02-01',
#    'card_exp': '2017-08-01'},
#   'vehicle': {'vehicle_make': 'Lexus',
#    'vehicle_model': 'Transit 150 Van',
#    'vehicle_year': 2006,
#    'vehicle_type': 'Hatchback'}},
#  {'personal': {'first_name': 'Peter',
#    'last_name': 'Sharp',
#    'sex': 'Male',
#    'age': 37,
#    'marital_status': 'single',
#    'dependants': 1},
#   'address': {'street': '777 Aaron valleys',
#    'city': 'Johnmouth',
#    'postcode': 'B07 5ZZ'},
#   'work': {'employer': 'Pearson, Collins and Marsh',
#    'commute': 15.48,
#    'salary_GBP': 64609,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 30500000000000,
#    'card_cvv': 8503,
#    'card_iban': 'GB22LYFJ95732218003692',
#    'card_start': '2020-05-01',
#    'card_exp': '2026-01-01'},
#   'vehicle': {'vehicle_make': 'BMW',
#    'vehicle_model': 'LR3',
#    'vehicle_year': 2010,
#    'vehicle_type': 'Coupe'}},
#  {'personal': {'first_name': 'Vincent',
#    'last_name': 'Swift',
#    'sex': 'Male',
#    'age': 50,
#    'marital_status': 'divorced',
#    'dependants': 1},
#   'address': {'street': 'Flat 22 Mandy squares',
#    'city': 'Shanehaven',
#    'postcode': 'SR18 1EZ'},
#   'work': {'employer': 'Davies, Pearce and Williams',
#    'commute': 16.12,
#    'salary_GBP': 68728,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 30500000000000,
#    'card_cvv': 799,
#    'card_iban': 'GB30EGOC73092573029419',
#    'card_start': '2020-09-01',
#    'card_exp': '2022-04-01'},
#   'vehicle': {'vehicle_make': 'GMC',
#    'vehicle_model': 'Mercedes-AMG GLC Coupe',
#    'vehicle_year': 2012,
#    'vehicle_type': 'Sedan'}},
#  {'personal': {'first_name': 'Lydia',
#    'last_name': 'Reed',
#    'sex': 'Female',
#    'age': 26,
#    'marital_status': 'single',
#    'dependants': 2},
#   'address': {'street': 'Flat 08d Taylor path',
#    'city': 'Smartside',
#    'postcode': 'HU4N 6YX'},
#   'work': {'employer': 'Fisher-Hill',
#    'commute': 8.8,
#    'salary_GBP': 29320,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4640000000000,
#    'card_cvv': 691,
#    'card_iban': 'GB52OFTT26226743199049',
#    'card_start': '2016-09-01',
#    'card_exp': '2027-01-01'},
#   'vehicle': {'vehicle_make': 'FIAT',
#    'vehicle_model': 'Odyssey',
#    'vehicle_year': 2010,
#    'vehicle_type': 'Sedan'}},
#  {'personal': {'first_name': 'Marc',
#    'last_name': 'Payne',
#    'sex': 'Male',
#    'age': 43,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': 'Studio 99 Curtis rest',
#    'city': 'Port Laurenmouth',
#    'postcode': 'BH8P 0UX'},
#   'work': {'employer': 'Morton-Collins',
#    'commute': 16.19,
#    'salary_GBP': 69182,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 3510000000000000,
#    'card_cvv': 349,
#    'card_iban': 'GB55TNII01672776605843',
#    'card_start': '2014-12-01',
#    'card_exp': '2026-06-01'},
#   'vehicle': {'vehicle_make': 'Land Rover',
#    'vehicle_model': 'Avalon',
#    'vehicle_year': 2005,
#    'vehicle_type': 'Hatchback'}},
#  {'personal': {'first_name': 'Ellie',
#    'last_name': 'Wright',
#    'sex': 'Female',
#    'age': 30,
#    'marital_status': 'single',
#    'dependants': 2},
#   'address': {'street': '20 Dean lakes',
#    'city': 'Meganland',
#    'postcode': 'N4E 6XQ'},
#   'work': {'employer': 'Rahman-Parker',
#    'commute': 17.11,
#    'salary_GBP': 75305,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4830000000000,
#    'card_cvv': 349,
#    'card_iban': 'GB97KQVY80253351403949',
#    'card_start': '2018-12-01',
#    'card_exp': '2020-01-01'},
#   'vehicle': {'vehicle_make': 'Chevrolet',
#    'vehicle_model': 'Tracer',
#    'vehicle_year': 2002,
#    'vehicle_type': 'Coupe'}},
#  {'personal': {'first_name': 'Simon',
#    'last_name': 'Murphy',
#    'sex': 'Male',
#    'age': 53,
#    'marital_status': 'single',
#    'dependants': 2},
#   'address': {'street': '12 Potter squares',
#    'city': 'Dominicside',
#    'postcode': 'WC5R 4ES'},
#   'work': {'employer': 'Jennings LLC',
#    'commute': 12.44,
#    'salary_GBP': 46840,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 213000000000000,
#    'card_cvv': 677,
#    'card_iban': 'GB14PIHK07386954050456',
#    'card_start': '2015-06-01',
#    'card_exp': '2018-05-01'},
#   'vehicle': {'vehicle_make': 'Honda',
#    'vehicle_model': 'Silverado 2500 Regular Cab',
#    'vehicle_year': 2017,
#    'vehicle_type': 'Sedan, Hatchback'}},
#  {'personal': {'first_name': 'Catherine',
#    'last_name': 'Lowe',
#    'sex': 'Female',
#    'age': 38,
#    'marital_status': 'married or civil partner',
#    'dependants': 3},
#   'address': {'street': 'Studio 6 McCarthy forest',
#    'city': 'New Damian',
#    'postcode': 'IV7X 8SY'},
#   'work': {'employer': 'Ball, Hughes and Robinson',
#    'commute': 12.18,
#    'salary_GBP': 45491,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 3580000000000000,
#    'card_cvv': 451,
#    'card_iban': 'GB48DASS31162887870344',
#    'card_start': '2018-02-01',
#    'card_exp': '2028-01-01'},
#   'vehicle': {'vehicle_make': 'Dodge',
#    'vehicle_model': 'Thunderbird',
#    'vehicle_year': 1996,
#    'vehicle_type': 'Sedan'}},
#  {'personal': {'first_name': 'Lorraine',
#    'last_name': 'Mistry',
#    'sex': 'Female',
#    'age': 54,
#    'marital_status': 'divorced',
#    'dependants': 4},
#   'address': {'street': '34 Mary locks',
#    'city': 'Tonymouth',
#    'postcode': 'L2 1RH'},
#   'work': {'employer': 'Marshall LLC',
#    'commute': 12.1,
#    'salary_GBP': 45051,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4720000000000000000,
#    'card_cvv': 314,
#    'card_iban': 'GB19NWSV06173347245700',
#    'card_start': '2014-08-01',
#    'card_exp': '2028-07-01'},
#   'vehicle': {'vehicle_make': 'Nissan',
#    'vehicle_model': 'RS 7',
#    'vehicle_year': 1997,
#    'vehicle_type': 'Wagon'}},
#  {'personal': {'first_name': 'Rachel',
#    'last_name': 'Smart',
#    'sex': 'Female',
#    'age': 29,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': '64 Patterson centers',
#    'city': 'Cliffordburgh',
#    'postcode': 'B24 8EJ'},
#   'work': {'employer': "O'Sullivan, Taylor and Cox",
#    'commute': 18.81,
#    'salary_GBP': 87344,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4840000000000,
#    'card_cvv': 133,
#    'card_iban': 'GB62ONWU62915681538019',
#    'card_start': '2018-10-01',
#    'card_exp': '2029-07-01'},
#   'vehicle': {'vehicle_make': 'Volkswagen',
#    'vehicle_model': 'Sprinter 3500 Cargo',
#    'vehicle_year': 1994,
#    'vehicle_type': 'Pickup'}},
#  {'personal': {'first_name': 'Katy',
#    'last_name': 'Knight',
#    'sex': 'Female',
#    'age': 33,
#    'marital_status': 'married or civil partner',
#    'dependants': 1},
#   'address': {'street': '133 Jacob spur',
#    'city': 'East Mathew',
#    'postcode': 'M0S 0GJ'},
#   'work': {'employer': 'Archer Ltd',
#    'commute': 7.77,
#    'salary_GBP': 25115,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 180000000000000,
#    'card_cvv': 292,
#    'card_iban': 'GB78HGUW98653392316629',
#    'card_start': '2015-12-01',
#    'card_exp': '2020-07-01'},
#   'vehicle': {'vehicle_make': 'Suzuki',
#    'vehicle_model': 'Silverado 2500 HD Extended Cab',
#    'vehicle_year': 2012,
#    'vehicle_type': 'Pickup'}},
#  {'personal': {'first_name': 'Bradley',
#    'last_name': 'Thompson',
#    'sex': 'Male',
#    'age': 30,
#    'marital_status': 'married or civil partner',
#    'dependants': 1},
#   'address': {'street': 'Studio 58D Hill dam',
#    'city': 'West Owenview',
#    'postcode': 'B48 1FB'},
#   'work': {'employer': 'Ashton, Tucker and Davies',
#    'commute': 11.68,
#    'salary_GBP': 42838,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4550000000000000,
#    'card_cvv': 401,
#    'card_iban': 'GB44HFCB98336374626479',
#    'card_start': '2014-08-01',
#    'card_exp': '2032-04-01'},
#   'vehicle': {'vehicle_make': 'Freightliner',
#    'vehicle_model': 'Nautilus',
#    'vehicle_year': 2011,
#    'vehicle_type': 'Wagon, Convertible'}},
#  {'personal': {'first_name': 'Antony',
#    'last_name': 'Edwards',
#    'sex': 'Male',
#    'age': 39,
#    'marital_status': 'married or civil partner',
#    'dependants': 1},
#   'address': {'street': '54 Josephine point',
#    'city': 'South William',
#    'postcode': 'WN6B 7PF'},
#   'work': {'employer': 'Roberts, Thompson and Thomas',
#    'commute': 8.85,
#    'salary_GBP': 29557,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4620000000000000,
#    'card_cvv': 295,
#    'card_iban': 'GB43NXOW18067474519071',
#    'card_start': '2019-12-01',
#    'card_exp': '2023-11-01'},
#   'vehicle': {'vehicle_make': 'Volkswagen',
#    'vehicle_model': 'Eclipse',
#    'vehicle_year': 1997,
#    'vehicle_type': 'SUV'}},
#  {'personal': {'first_name': 'Simon',
#    'last_name': 'Pollard',
#    'sex': 'Male',
#    'age': 39,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': 'Studio 19 Booth freeway',
#    'city': 'West Louisehaven',
#    'postcode': 'GU8 4EX'},
#   'work': {'employer': 'Kennedy LLC',
#    'commute': 19.84,
#    'salary_GBP': 95080,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4890000000000000,
#    'card_cvv': 578,
#    'card_iban': 'GB02UMII22298941128830',
#    'card_start': '2014-08-01',
#    'card_exp': '2019-12-01'},
#   'vehicle': {'vehicle_make': 'Jaguar',
#    'vehicle_model': 'Mystique',
#    'vehicle_year': 2017,
#    'vehicle_type': 'Coupe'}},
#  {'personal': {'first_name': 'Amelia',
#    'last_name': 'Cooper',
#    'sex': 'Female',
#    'age': 69,
#    'marital_status': 'single',
#    'dependants': 2},
#   'address': {'street': '66 Hutchinson run',
#    'city': 'New Joanneton',
#    'postcode': 'B3G 0RL'},
#   'work': {'employer': 'Jones, Simmons and Wyatt',
#    'commute': 15.49,
#    'salary_GBP': 64712,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4150000000000000,
#    'card_cvv': 18,
#    'card_iban': 'GB09KABU79666494796792',
#    'card_start': '2015-10-01',
#    'card_exp': '2024-12-01'},
#   'vehicle': {'vehicle_make': 'Mercedes-Benz',
#    'vehicle_model': 'M6',
#    'vehicle_year': 2014,
#    'vehicle_type': 'Sedan'}},
#  {'personal': {'first_name': 'Leonard',
#    'last_name': 'Clark',
#    'sex': 'Male',
#    'age': 48,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': 'Studio 6 Heather prairie',
#    'city': 'North Amelia',
#    'postcode': 'E9 0HB'},
#   'work': {'employer': 'Phillips-Pope',
#    'commute': 18.44,
#    'salary_GBP': 84645,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 3560000000000000,
#    'card_cvv': 908,
#    'card_iban': 'GB45UVZH05043505193524',
#    'card_start': '2019-04-01',
#    'card_exp': '2026-08-01'},
#   'vehicle': {'vehicle_make': 'Saturn',
#    'vehicle_model': 'Convertible',
#    'vehicle_year': 2015,
#    'vehicle_type': 'Van/Minivan'}},
#  {'personal': {'first_name': 'Jemma',
#    'last_name': 'Jones',
#    'sex': 'Female',
#    'age': 22,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': 'Flat 3 Davies run',
#    'city': 'Greenshire',
#    'postcode': 'E7 4UJ'},
#   'work': {'employer': 'Hughes LLC',
#    'commute': 19.61,
#    'salary_GBP': 93314,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 3590000000000000,
#    'card_cvv': 675,
#    'card_iban': 'GB88EGZV32518465934497',
#    'card_start': '2005-12-01',
#    'card_exp': '2028-07-01'},
#   'vehicle': {'vehicle_make': 'Toyota',
#    'vehicle_model': 'Yukon',
#    'vehicle_year': 2015,
#    'vehicle_type': 'Van/Minivan'}},
#  {'personal': {'first_name': 'Nicola',
#    'last_name': 'Walker',
#    'sex': 'Female',
#    'age': 38,
#    'marital_status': 'single',
#    'dependants': 1},
#   'address': {'street': 'Flat 7 Barber motorway',
#    'city': 'Burrowsshire',
#    'postcode': 'L62 8TA'},
#   'work': {'employer': 'Bailey Group',
#    'commute': 6.66,
#    'salary_GBP': 20940,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 3580000000000000,
#    'card_cvv': 679,
#    'card_iban': 'GB81SVHK17718594367943',
#    'card_start': '2013-01-01',
#    'card_exp': '2029-05-01'},
#   'vehicle': {'vehicle_make': 'Ford',
#    'vehicle_model': 'S6',
#    'vehicle_year': 2020,
#    'vehicle_type': 'Sedan'}},
#  {'personal': {'first_name': 'Paul',
#    'last_name': 'Thomson',
#    'sex': 'Male',
#    'age': 45,
#    'marital_status': 'married or civil partner',
#    'dependants': 3},
#   'address': {'street': '00 Tony forks',
#    'city': 'Abbiebury',
#    'postcode': 'NP4 1JL'},
#   'work': {'employer': 'Foster-Price',
#    'commute': 18.13,
#    'salary_GBP': 82412,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4090000000000000,
#    'card_cvv': 775,
#    'card_iban': 'GB14LLBD59118062249339',
#    'card_start': '2019-04-01',
#    'card_exp': '2023-05-01'},
#   'vehicle': {'vehicle_make': 'Scion',
#    'vehicle_model': 'Ram 1500 Quad Cab',
#    'vehicle_year': 2015,
#    'vehicle_type': 'Pickup'}}]

# %% [markdown]
# ### Task 6: there may be some issues with credit card entries. Any customers that have more than 10 years between their start and end date need writing to a separate file, called remove_ccard.json, in the JSON data format. The client will manually deal with these later based on your output. They request that you write a function to help perform this, which accepts a single row from the CSV data.

# %%
#first, a function is create which accepts a row
#the string dates converted earlier are converted back to datetime.date using the datetime function
#after this timedelta is applied to show the number of days that make up 10 years

def card_issues(row):
    flagged = False
    
    #the card rows
    cc_start = row['card']['card_start']
    cc_exp = row['card']['card_exp']
    
    #converting the string dates back to time
    cc_start_dt = datetime.strptime(cc_start, '%Y-%m-%d').date()
    cc_exp_dt = datetime.strptime(cc_exp, '%Y-%m-%d').date()
    
    #creating an object
    #this is the difference of card expiry - card start date
    #due to the datetime applied, results are returned in days
    
    diff_days = cc_exp_dt - cc_start_dt
    
    #the conditional statement to enforce the results for the function
    if diff_days > timedelta(days=3652):
        return True
    else:
        return flagged

# %% [markdown]
# __After the function is created, testing is done below to see if it indeeds picks up the correct rows. The first 10 rows has been checked below and results were compared with a check done manually__

# %%
(card_issues(all_customers[0]), 
 card_issues(all_customers[1]),
 card_issues(all_customers[2]), 
 card_issues(all_customers[3]), 
 card_issues(all_customers[4]),
 card_issues(all_customers[5]), 
 card_issues(all_customers[6]),
 card_issues(all_customers[7]), 
 card_issues(all_customers[8]),
 card_issues(all_customers[9]))
# Out:
# (False, True, False, False, False, False, True, True, False, False)

# %% [markdown]
# __Lastly, a list is created and a json file is created from this list to store this data__

# %%
#creating the list comprehension to hold the remove_ccard data
#iterating through the all_customers list, then applying the card_issues function to get the rows
#these rows are then appended to the list comprehension

remove_ccard = []
for row in all_customers:
    if card_issues(row) == True:
        remove_ccard.append(row)

#the function for creating json files created earlier is applied again
#the object for the file name is created as well
remove_ccard_json = 'remove_ccard.json'
create_json(remove_ccard,remove_ccard_json)
print ('The number of customers where the difference between card start and expiry dates is more than 3652 days :',len(remove_ccard))
# Out:
# The number of customers where the difference between card start and expiry dates is more than 3652 days : 283

# %% [markdown]
# ### Task 7: You have been tasked with calculating some additional metrics which will be used for ranking customers. You should create a new data attribute for our customers called “Salary-Commute”. Reading in from processed.json:
# 1. __Add, and calculate appropriately, this new attribute. It should represent the Salary that a customer earns, per mile of their commute.__
#   <br>- Note: If a person travels 1 or fewer commute miles, then their salarycommute would be just their salary.
# 2. __Sort these records by that new metric, in ascending order.__
# 3. __Store the output file out as a JSON format, for a commute.json file.__

# %%
#creating a function whose input is the filename to be processed

def salary_commute(json_file):
    salary_per_commute = []
    
    try:
        with open(json_file, mode='r') as processed_file:
            new_metric = json.load(processed_file)
            for row in new_metric:
                if (row['work']['commute'] <= 1):
                    row['salary_commute'] = row['work']['salary_GBP']
            
                else:
                    row['salary_commute'] = row['work']['salary_GBP'] / row['work']['commute']
                salary_per_commute.append(row)
        
    except Exception as err:
        print('There is an error')
    
    sorted_salary_commute = sorted(salary_per_commute, key=lambda d: d['salary_commute']) 
    return (sorted_salary_commute)

#calling the function
salary_commute_obj = salary_commute('processed.json')

#again using the function created earlier to convert to json
#creating the object for the json filename
commute_json = 'commute.json'
create_json(salary_commute_obj,commute_json)

salary_commute_obj
# Out:
# [{'personal': {'first_name': 'Graeme',
#    'last_name': 'Jackson',
#    'sex': 'Male',
#    'age': 52,
#    'marital_status': 'single',
#    'dependants': 2},
#   'address': {'street': 'Studio 9 Reid lights',
#    'city': 'South Ryan',
#    'postcode': 'E27 9GY'},
#   'work': {'employer': 'Smith, Birch and Burke',
#    'commute': 5.52,
#    'salary_GBP': 17046,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4710000000000000,
#    'card_cvv': 3053,
#    'card_iban': 'GB09ELJH35362236053720',
#    'card_start': '2014-06-01',
#    'card_exp': '2029-04-01'},
#   'vehicle': {'vehicle_make': 'Chevrolet',
#    'vehicle_model': 'Rally Wagon 1500',
#    'vehicle_year': 2011,
#    'vehicle_type': 'SUV'},
#   'salary_commute': 3088.04347826087},
#  {'personal': {'first_name': 'Janet',
#    'last_name': 'Quinn',
#    'sex': 'Female',
#    'age': 30,
#    'marital_status': 'married or civil partner',
#    'dependants': 1},
#   'address': {'street': 'Studio 34r Wilkinson camp',
#    'city': 'Louisland',
#    'postcode': 'G7H 8FA'},
#   'work': {'employer': 'Wood-Davies',
#    'commute': 5.64,
#    'salary_GBP': 17428,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 180000000000000,
#    'card_cvv': 392,
#    'card_iban': 'GB47KCJL06712308674300',
#    'card_start': '2002-12-01',
#    'card_exp': '2025-02-01'},
#   'vehicle': {'vehicle_make': 'Audi',
#    'vehicle_model': 'Land Cruiser',
#    'vehicle_year': 2000,
#    'vehicle_type': 'SUV'},
#   'salary_commute': 3090.070921985816},
#  {'personal': {'first_name': 'Peter',
#    'last_name': 'Burton',
#    'sex': 'Male',
#    'age': 63,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': 'Studio 38 James throughway',
#    'city': 'Leighton',
#    'postcode': 'M8E 7HJ'},
#   'work': {'employer': 'Graham, Watts and Hall',
#    'commute': 5.58,
#    'salary_GBP': 17245,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4060000000000,
#    'card_cvv': 458,
#    'card_iban': 'GB30EGRJ34862965423758',
#    'card_start': '2011-12-01',
#    'card_exp': '2022-07-01'},
#   'vehicle': {'vehicle_make': 'Dodge',
#    'vehicle_model': 'Sorento',
#    'vehicle_year': 2016,
#    'vehicle_type': 'Sedan, Coupe, Hatchback'},
#   'salary_commute': 3090.5017921146955},
#  {'personal': {'first_name': 'Paula',
#    'last_name': 'Patel',
#    'sex': 'Female',
#    'age': 54,
#    'marital_status': 'married or civil partner',
#    'dependants': 0},
#   'address': {'street': '3 Richards stravenue',
#    'city': 'West Petermouth',
#    'postcode': 'N1 8YE'},
#   'work': {'employer': 'Foster, Morgan and Jackson',
#    'commute': 5.62,
#    'salary_GBP': 17371,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 502000000000,
#    'card_cvv': 766,
#    'card_iban': 'GB29CWJF41656280619075',
#    'card_start': '2014-10-01',
#    'card_exp': '2025-05-01'},
#   'vehicle': {'vehicle_make': 'Genesis',
#    'vehicle_model': 'Suburban 1500',
#    'vehicle_year': '2018',
#    'vehicle_type': 'Coupe'},
#   'salary_commute': 3090.9252669039147},
#  {'personal': {'first_name': 'Lynda',
#    'last_name': 'Gill',
#    'sex': 'Female',
#    'age': 30,
#    'marital_status': 'single',
#    'dependants': 3},
#   'address': {'street': '0 Burton underpass',
#    'city': 'Port Arthur',
#    'postcode': 'BR50 2QH'},
#   'work': {'employer': 'Brown-Little',
#    'commute': 5.73,
#    'salary_GBP': 17729,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 30500000000000,
#    'card_cvv': 417,
#    'card_iban': 'GB56NKVI05727577080668',
#    'card_start': '2016-03-01',
#    'card_exp': '2021-09-01'},
#   'vehicle': {'vehicle_make': 'Kia',
#    'vehicle_model': 'Tundra Regular Cab',
#    'vehicle_year': 2002,
#    'vehicle_type': 'Van/Minivan'},
#   'salary_commute': 3094.0663176265266},
#  {'personal': {'first_name': 'Stacey',
#    'last_name': 'Armstrong',
#    'sex': 'Female',
#    'age': 61,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': 'Studio 0 Khan land',
#    'city': 'Lake Shirleybury',
#    'postcode': 'DA9R 6WR'},
#   'work': {'employer': 'Brown Group',
#    'commute': 5.63,
#    'salary_GBP': 17421,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 345000000000000,
#    'card_cvv': 8534,
#    'card_iban': 'GB36USRI66285047824917',
#    'card_start': '2011-12-01',
#    'card_exp': '2028-05-01'},
#   'vehicle': {'vehicle_make': 'Chevrolet',
#    'vehicle_model': 'Highlander Hybrid',
#    'vehicle_year': 2010,
#    'vehicle_type': 'Sedan'},
#   'salary_commute': 3094.316163410302},
#  {'personal': {'first_name': 'Michelle',
#    'last_name': 'Williams',
#    'sex': 'Female',
#    'age': 34,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': 'Studio 6 McCarthy center',
#    'city': 'New Ronaldside',
#    'postcode': 'N7H 8BQ'},
#   'work': {'employer': 'Green LLC',
#    'commute': 5.82,
#    'salary_GBP': 18025,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 3520000000000000,
#    'card_cvv': 893,
#    'card_iban': 'GB65FJCM17404310719954',
#    'card_start': '2014-10-01',
#    'card_exp': '2024-01-01'},
#   'vehicle': {'vehicle_make': 'Mercedes-Benz',
#    'vehicle_model': 'Colorado Crew Cab',
#    'vehicle_year': 2019,
#    'vehicle_type': 'SUV'},
#   'salary_commute': 3097.0790378006873},
#  {'personal': {'first_name': 'Elliott',
#    'last_name': 'Brown',
#    'sex': 'Male',
#    'age': 67,
#    'marital_status': 'single',
#    'dependants': 4},
#   'address': {'street': 'Flat 8 Gerald forks',
#    'city': 'West Christine',
#    'postcode': 'S1A 6TH'},
#   'work': {'employer': 'Hunt, Lowe and Marshall',
#    'commute': 5.74,
#    'salary_GBP': 17780,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4290000000000,
#    'card_cvv': 573,
#    'card_iban': 'GB52ZIII28520242353704',
#    'card_start': '2017-07-01',
#    'card_exp': '2024-04-01'},
#   'vehicle': {'vehicle_make': 'Suzuki',
#    'vehicle_model': 'E-PACE',
#    'vehicle_year': 1995,
#    'vehicle_type': 'Coupe'},
#   'salary_commute': 3097.560975609756},
#  {'personal': {'first_name': 'Charlie',
#    'last_name': 'Taylor',
#    'sex': 'Male',
#    'age': 45,
#    'marital_status': 'single',
#    'dependants': 3},
#   'address': {'street': 'Flat 57 Olivia trace',
#    'city': 'Jonesview',
#    'postcode': 'CH4R 2JZ'},
#   'work': {'employer': 'Carter Group',
#    'commute': 5.78,
#    'salary_GBP': 17906,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4190000000000000000,
#    'card_cvv': 500,
#    'card_iban': 'GB06ZROW35488708483557',
#    'card_start': '2014-08-01',
#    'card_exp': '2021-10-01'},
#   'vehicle': {'vehicle_make': 'Audi',
#    'vehicle_model': 'Express 3500 Passenger',
#    'vehicle_year': 2008,
#    'vehicle_type': 'Pickup'},
#   'salary_commute': 3097.9238754325256},
#  {'personal': {'first_name': 'Ashley',
#    'last_name': 'Sullivan',
#    'sex': 'Male',
#    'age': 50,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': '34 Amanda trace',
#    'city': 'North Juliamouth',
#    'postcode': 'HU28 3AR'},
#   'work': {'employer': 'Williams-Jones',
#    'commute': 5.81,
#    'salary_GBP': 18005,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 379000000000000,
#    'card_cvv': 586,
#    'card_iban': 'GB22OTJE53991614349608',
#    'card_start': '2006-12-01',
#    'card_exp': '2017-07-01'},
#   'vehicle': {'vehicle_make': 'Mercedes-Benz',
#    'vehicle_model': 'Sprinter 2500 Crew',
#    'vehicle_year': 2014,
#    'vehicle_type': 'Pickup'},
#   'salary_commute': 3098.9672977624787},
#  {'personal': {'first_name': 'Mohammad',
#    'last_name': 'Dawson',
#    'sex': 'Male',
#    'age': 23,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': 'Studio 7 Jayne square',
#    'city': 'Port Hayleyburgh',
#    'postcode': 'B0 4FP'},
#   'work': {'employer': 'Hammond, Ward and Kay',
#    'commute': 5.84,
#    'salary_GBP': 18099,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4760000000000000000,
#    'card_cvv': 170,
#    'card_iban': 'GB30HRHE96169675268116',
#    'card_start': '2019-04-01',
#    'card_exp': '2022-02-01'},
#   'vehicle': {'vehicle_make': 'Jaguar',
#    'vehicle_model': 'Venture Passenger',
#    'vehicle_year': 2020,
#    'vehicle_type': 'Pickup'},
#   'salary_commute': 3099.1438356164385},
#  {'personal': {'first_name': 'Shaun',
#    'last_name': 'Williams',
#    'sex': 'Male',
#    'age': 39,
#    'marital_status': 'widowed',
#    'dependants': 1},
#   'address': {'street': '33 Gary ports',
#    'city': 'West Harry',
#    'postcode': 'OL1 2YQ'},
#   'work': {'employer': 'Brown Ltd',
#    'commute': 5.84,
#    'salary_GBP': 18105,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 2710000000000000,
#    'card_cvv': 263,
#    'card_iban': 'GB73UVTC19378162783886',
#    'card_start': '2014-11-01',
#    'card_exp': '2017-04-01'},
#   'vehicle': {'vehicle_make': 'MAZDA',
#    'vehicle_model': 'Elantra',
#    'vehicle_year': 2005,
#    'vehicle_type': 'Pickup'},
#   'salary_commute': 3100.1712328767126},
#  {'personal': {'first_name': 'Irene',
#    'last_name': 'Welch',
#    'sex': 'Female',
#    'age': 28,
#    'marital_status': 'single',
#    'dependants': 1},
#   'address': {'street': 'Flat 74 Sharpe causeway',
#    'city': 'Joannemouth',
#    'postcode': 'BB64 5HJ'},
#   'work': {'employer': 'Williams-Wood',
#    'commute': 5.81,
#    'salary_GBP': 18018,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4470000000000,
#    'card_cvv': 620,
#    'card_iban': 'GB25MYAR13770026376842',
#    'card_start': '2015-11-01',
#    'card_exp': '2018-09-01'},
#   'vehicle': {'vehicle_make': 'Lincoln',
#    'vehicle_model': 'F150 Regular Cab',
#    'vehicle_year': 2012,
#    'vehicle_type': 'Convertible, Coupe'},
#   'salary_commute': 3101.2048192771085},
#  {'personal': {'first_name': 'Jodie',
#    'last_name': "O'Brien",
#    'sex': 'Female',
#    'age': 57,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': 'Flat 3 Christine views',
#    'city': 'Fletcherstad',
#    'postcode': 'WS2 9SN'},
#   'work': {'employer': 'Hill, Evans and Harrison',
#    'commute': 5.94,
#    'salary_GBP': 18446,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 2250000000000000,
#    'card_cvv': 659,
#    'card_iban': 'GB95WAYW31715898077181',
#    'card_start': '2019-04-01',
#    'card_exp': '2027-11-01'},
#   'vehicle': {'vehicle_make': 'Buick',
#    'vehicle_model': 'Outback',
#    'vehicle_year': 2020,
#    'vehicle_type': 'SUV'},
#   'salary_commute': 3105.387205387205},
#  {'personal': {'first_name': 'Bryan',
#    'last_name': 'Stevenson',
#    'sex': 'Male',
#    'age': 50,
#    'marital_status': 'divorced',
#    'dependants': 2},
#   'address': {'street': 'Studio 58 Coles causeway',
#    'city': 'East Rossland',
#    'postcode': 'SA1 0LJ'},
#   'work': {'employer': 'Collins Inc',
#    'commute': 5.92,
#    'salary_GBP': 18387,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 3530000000000000,
#    'card_cvv': 163,
#    'card_iban': 'GB33TYEE91362003724781',
#    'card_start': '2014-07-01',
#    'card_exp': '2016-10-01'},
#   'vehicle': {'vehicle_make': 'Acura',
#    'vehicle_model': 'Q40',
#    'vehicle_year': 2019,
#    'vehicle_type': 'Sedan'},
#   'salary_commute': 3105.912162162162},
#  {'personal': {'first_name': 'Yvonne',
#    'last_name': 'Moore',
#    'sex': 'Female',
#    'age': 64,
#    'marital_status': 'single',
#    'dependants': 3},
#   'address': {'street': 'Flat 24C Osborne valleys',
#    'city': 'North Aaronshire',
#    'postcode': 'PA9V 3TT'},
#   'work': {'employer': 'Blackburn Ltd',
#    'commute': 5.95,
#    'salary_GBP': 18482,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4030000000000,
#    'card_cvv': 155,
#    'card_iban': 'GB98XNCI83193229538208',
#    'card_start': '2018-02-01',
#    'card_exp': '2028-05-01'},
#   'vehicle': {'vehicle_make': 'Buick',
#    'vehicle_model': 'A3',
#    'vehicle_year': 2019,
#    'vehicle_type': 'Sedan'},
#   'salary_commute': 3106.2184873949577},
#  {'personal': {'first_name': 'Sarah',
#    'last_name': 'Crawford',
#    'sex': 'Female',
#    'age': 66,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': '75 Sian point',
#    'city': 'Lucasland',
#    'postcode': 'GU4E 9TX'},
#   'work': {'employer': 'White Ltd',
#    'commute': 6.07,
#    'salary_GBP': 18872,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 5440000000000000,
#    'card_cvv': 3995,
#    'card_iban': 'GB16MPYK68993249293405',
#    'card_start': '2020-07-01',
#    'card_exp': '2022-05-01'},
#   'vehicle': {'vehicle_make': 'Mitsubishi',
#    'vehicle_model': 'Express 2500 Passenger',
#    'vehicle_year': 2013,
#    'vehicle_type': 'SUV'},
#   'salary_commute': 3109.0609555189453},
#  {'personal': {'first_name': 'Jonathan',
#    'last_name': 'Doyle',
#    'sex': 'Male',
#    'age': 67,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': '08 Dean knolls',
#    'city': 'Terryland',
#    'postcode': 'BA47 0NA'},
#   'work': {'employer': 'Williams Group',
#    'commute': 6.08,
#    'salary_GBP': 18908,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4350000000000,
#    'card_cvv': 982,
#    'card_iban': 'GB71FKRB28802178428950',
#    'card_start': '2017-05-01',
#    'card_exp': '2025-05-01'},
#   'vehicle': {'vehicle_make': 'GMC',
#    'vehicle_model': '9-7X',
#    'vehicle_year': 2012,
#    'vehicle_type': 'Sedan, Wagon'},
#   'salary_commute': 3109.8684210526317},
#  {'personal': {'first_name': 'Frances',
#    'last_name': 'Moss',
#    'sex': 'Female',
#    'age': 61,
#    'marital_status': 'single',
#    'dependants': 2},
#   'address': {'street': '8 Hudson camp',
#    'city': 'Welchfurt',
#    'postcode': 'DE6N 9ET'},
#   'work': {'employer': 'McLean, Austin and Morris',
#    'commute': 6.14,
#    'salary_GBP': 19121,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 3580000000000000,
#    'card_cvv': 648,
#    'card_iban': 'GB13OQUF77724128234793',
#    'card_start': '2019-06-01',
#    'card_exp': '2023-05-01'},
#   'vehicle': {'vehicle_make': 'Volkswagen',
#    'vehicle_model': 'Tundra Regular Cab',
#    'vehicle_year': 1996,
#    'vehicle_type': 'Sedan'},
#   'salary_commute': 3114.169381107492},
#  {'personal': {'first_name': 'Anne',
#    'last_name': 'Peacock',
#    'sex': 'Female',
#    'age': 50,
#    'marital_status': 'single',
#    'dependants': 2},
#   'address': {'street': 'Flat 50d Carter path',
#    'city': 'Port Roy',
#    'postcode': 'S0 2PS'},
#   'work': {'employer': 'Duffy Inc',
#    'commute': 6.17,
#    'salary_GBP': 19215,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 3580000000000000,
#    'card_cvv': 312,
#    'card_iban': 'GB20MAUZ18229028843343',
#    'card_start': '2013-12-01',
#    'card_exp': '2025-07-01'},
#   'vehicle': {'vehicle_make': 'Ford',
#    'vehicle_model': 'Challenger',
#    'vehicle_year': 2013,
#    'vehicle_type': 'Sedan, Hatchback'},
#   'salary_commute': 3114.262560777958},
#  {'personal': {'first_name': 'Gary',
#    'last_name': 'Schofield',
#    'sex': 'Male',
#    'age': 66,
#    'marital_status': 'married or civil partner',
#    'dependants': 1},
#   'address': {'street': '9 Smith court',
#    'city': 'West Zoemouth',
#    'postcode': 'LU27 2UY'},
#   'work': {'employer': 'Parkinson, Schofield and Davies',
#    'commute': 6.17,
#    'salary_GBP': 19231,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 2710000000000000,
#    'card_cvv': 794,
#    'card_iban': 'GB57JVRM08306168738810',
#    'card_start': '2014-01-01',
#    'card_exp': '2014-03-01'},
#   'vehicle': {'vehicle_make': 'Dodge',
#    'vehicle_model': 'S80',
#    'vehicle_year': 2008,
#    'vehicle_type': 'Sedan'},
#   'salary_commute': 3116.8557536466774},
#  {'personal': {'first_name': 'Marian',
#    'last_name': 'Gibbons',
#    'sex': 'Female',
#    'age': 35,
#    'marital_status': 'single',
#    'dependants': 2},
#   'address': {'street': 'Flat 90T George via',
#    'city': 'New Rachelport',
#    'postcode': 'DN0E 0YH'},
#   'work': {'employer': 'Cooper-Webb',
#    'commute': 6.18,
#    'salary_GBP': 19269,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4610000000000000000,
#    'card_cvv': 2363,
#    'card_iban': 'GB10MOHR85091477884233',
#    'card_start': '2016-11-01',
#    'card_exp': '2025-05-01'},
#   'vehicle': {'vehicle_make': 'Pontiac',
#    'vehicle_model': 'Tiburon',
#    'vehicle_year': 2016,
#    'vehicle_type': 'SUV'},
#   'salary_commute': 3117.961165048544},
#  {'personal': {'first_name': 'Gerald',
#    'last_name': 'Brown',
#    'sex': 'Male',
#    'age': 33,
#    'marital_status': 'married or civil partner',
#    'dependants': 1},
#   'address': {'street': '37 Nicholas pike',
#    'city': 'East Natashaview',
#    'postcode': 'BD0H 6BZ'},
#   'work': {'employer': 'Harvey and Sons',
#    'commute': 6.24,
#    'salary_GBP': 19469,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 180000000000000,
#    'card_cvv': 978,
#    'card_iban': 'GB58YADH97240120213564',
#    'card_start': '2017-01-01',
#    'card_exp': '2024-12-01'},
#   'vehicle': {'vehicle_make': 'GMC',
#    'vehicle_model': 'Suburban 2500',
#    'vehicle_year': 1998,
#    'vehicle_type': 'Sedan, Convertible'},
#   'salary_commute': 3120.0320512820513},
#  {'personal': {'first_name': 'Rosemary',
#    'last_name': 'Jackson',
#    'sex': 'Female',
#    'age': 45,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': '469 Katherine bridge',
#    'city': 'Port Victorland',
#    'postcode': 'NW7X 4AN'},
#   'work': {'employer': 'James-Smith',
#    'commute': 6.3,
#    'salary_GBP': 19687,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 376000000000000,
#    'card_cvv': 74,
#    'card_iban': 'GB83DQDP33275288598370',
#    'card_start': '2017-11-01',
#    'card_exp': '2022-04-01'},
#   'vehicle': {'vehicle_make': 'Saab',
#    'vehicle_model': 'Ram 2500 Regular Cab',
#    'vehicle_year': 2007,
#    'vehicle_type': 'Pickup'},
#   'salary_commute': 3124.920634920635},
#  {'personal': {'first_name': 'Sarah',
#    'last_name': 'Robinson',
#    'sex': 'Female',
#    'age': 38,
#    'marital_status': 'single',
#    'dependants': 2},
#   'address': {'street': 'Studio 77T Emily path',
#    'city': 'West Connor',
#    'postcode': 'NW7B 5ZR'},
#   'work': {'employer': 'Dickinson, Nolan and Smith',
#    'commute': 6.35,
#    'salary_GBP': 19863,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4420000000000000000,
#    'card_cvv': 800,
#    'card_iban': 'GB72SOVW84817129799960',
#    'card_start': '2018-09-01',
#    'card_exp': '2026-02-01'},
#   'vehicle': {'vehicle_make': 'INFINITI',
#    'vehicle_model': 'Sportvan G20',
#    'vehicle_year': 2020,
#    'vehicle_type': 'SUV'},
#   'salary_commute': 3128.031496062992},
#  {'personal': {'first_name': 'Jay',
#    'last_name': 'Murphy',
#    'sex': 'Male',
#    'age': 22,
#    'marital_status': 'single',
#    'dependants': 1},
#   'address': {'street': '0 Bibi turnpike',
#    'city': 'Hillberg',
#    'postcode': 'TW42 5FN'},
#   'work': {'employer': 'Smith PLC',
#    'commute': 6.4,
#    'salary_GBP': 20025,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 3580000000000000,
#    'card_cvv': 960,
#    'card_iban': 'GB33CRES59264962813582',
#    'card_start': '2015-07-01',
#    'card_exp': '2025-05-01'},
#   'vehicle': {'vehicle_make': 'Kia',
#    'vehicle_model': 'Storm',
#    'vehicle_year': 1993,
#    'vehicle_type': 'Pickup'},
#   'salary_commute': 3128.90625},
#  {'personal': {'first_name': 'Hannah',
#    'last_name': 'Collins',
#    'sex': 'Female',
#    'age': 27,
#    'marital_status': 'married or civil partner',
#    'dependants': 1},
#   'address': {'street': 'Studio 2 Jeffrey points',
#    'city': 'Nicolaborough',
#    'postcode': 'G3A 2JZ'},
#   'work': {'employer': 'Hamilton-Singh',
#    'commute': 6.43,
#    'salary_GBP': 20126,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4150000000000000,
#    'card_cvv': 614,
#    'card_iban': 'GB08IRKT35717700471779',
#    'card_start': '2014-11-01',
#    'card_exp': '2015-02-01'},
#   'vehicle': {'vehicle_make': 'Toyota',
#    'vehicle_model': 'Thunderbird',
#    'vehicle_year': 1992,
#    'vehicle_type': 'Sedan, Hatchback'},
#   'salary_commute': 3130.0155520995336},
#  {'personal': {'first_name': 'Melanie',
#    'last_name': "O'Brien",
#    'sex': 'Female',
#    'age': 51,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': 'Flat 08d Ward squares',
#    'city': 'Phillipside',
#    'postcode': 'BB3A 9PE'},
#   'work': {'employer': 'Clarke Inc',
#    'commute': 6.45,
#    'salary_GBP': 20206,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 213000000000000,
#    'card_cvv': 542,
#    'card_iban': 'GB14FFMB81152248185033',
#    'card_start': '2001-12-01',
#    'card_exp': '2023-09-01'},
#   'vehicle': {'vehicle_make': 'Pontiac',
#    'vehicle_model': '2500 Regular Cab',
#    'vehicle_year': 1997,
#    'vehicle_type': 'Sedan'},
#   'salary_commute': 3132.7131782945735},
#  {'personal': {'first_name': 'Jasmine',
#    'last_name': 'Campbell',
#    'sex': 'Female',
#    'age': 58,
#    'marital_status': 'married or civil partner',
#    'dependants': 1},
#   'address': {'street': '605 Jones rapid',
#    'city': 'Stevensberg',
#    'postcode': 'B66 2FQ'},
#   'work': {'employer': 'Stevens-Humphreys',
#    'commute': 6.49,
#    'salary_GBP': 20346,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 2270000000000000,
#    'card_cvv': 3671,
#    'card_iban': 'GB54QBDY37624039010779',
#    'card_start': '2018-02-01',
#    'card_exp': '2025-08-01'},
#   'vehicle': {'vehicle_make': 'GMC',
#    'vehicle_model': 'Ram 2500 Quad Cab',
#    'vehicle_year': 2011,
#    'vehicle_type': 'Coupe'},
#   'salary_commute': 3134.9768875192603},
#  {'personal': {'first_name': 'Wayne',
#    'last_name': 'Green',
#    'sex': 'Male',
#    'age': 33,
#    'marital_status': 'single',
#    'dependants': 1},
#   'address': {'street': 'Flat 69q Abdul summit',
#    'city': 'East Deanside',
#    'postcode': 'FK5M 0WA'},
#   'work': {'employer': 'Butler, Clarke and Jackson',
#    'commute': 6.52,
#    'salary_GBP': 20448,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 502000000000,
#    'card_cvv': 148,
#    'card_iban': 'GB14MGNM26884689043140',
#    'card_start': '2020-07-01',
#    'card_exp': '2022-03-01'},
#   'vehicle': {'vehicle_make': 'Volkswagen',
#    'vehicle_model': 'Pathfinder',
#    'vehicle_year': 2015,
#    'vehicle_type': 'Van/Minivan'},
#   'salary_commute': 3136.196319018405},
#  {'personal': {'first_name': 'Lauren',
#    'last_name': 'Hughes',
#    'sex': 'Female',
#    'age': 65,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': '87 McLean trail',
#    'city': 'Normanton',
#    'postcode': 'SW98 4NA'},
#   'work': {'employer': 'Hartley-Gray',
#    'commute': 6.52,
#    'salary_GBP': 20463,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 6010000000000000,
#    'card_cvv': 30,
#    'card_iban': 'GB57OETD14594830765307',
#    'card_start': '2018-02-01',
#    'card_exp': '2021-09-01'},
#   'vehicle': {'vehicle_make': 'Chevrolet',
#    'vehicle_model': 'Express 1500 Cargo',
#    'vehicle_year': 1994,
#    'vehicle_type': 'Sedan'},
#   'salary_commute': 3138.4969325153374},
#  {'personal': {'first_name': 'Gavin',
#    'last_name': 'Stephenson',
#    'sex': 'Male',
#    'age': 18,
#    'marital_status': 'single',
#    'dependants': 2},
#   'address': {'street': 'Studio 5 Dyer isle',
#    'city': 'Rogersstad',
#    'postcode': 'TQ56 1HA'},
#   'work': {'employer': 'Cooper-Barton',
#    'commute': 6.64,
#    'salary_GBP': 20860,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 3570000000000000,
#    'card_cvv': 970,
#    'card_iban': 'GB84GPPD66922603573818',
#    'card_start': '2019-01-01',
#    'card_exp': '2027-03-01'},
#   'vehicle': {'vehicle_make': 'Oldsmobile',
#    'vehicle_model': 'Expedition',
#    'vehicle_year': 2000,
#    'vehicle_type': 'SUV'},
#   'salary_commute': 3141.566265060241},
#  {'personal': {'first_name': 'Elliott',
#    'last_name': 'Thompson',
#    'sex': 'Male',
#    'age': 70,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': 'Flat 64 Bennett orchard',
#    'city': 'Williamfurt',
#    'postcode': 'B32 7GP'},
#   'work': {'employer': 'Bradley-Adams',
#    'commute': 6.62,
#    'salary_GBP': 20798,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4950000000000000000,
#    'card_cvv': 7405,
#    'card_iban': 'GB66OWPO84433879730976',
#    'card_start': '2011-12-01',
#    'card_exp': '2016-10-01'},
#   'vehicle': {'vehicle_make': 'Porsche',
#    'vehicle_model': 'A3 Sportback e-tron',
#    'vehicle_year': 2008,
#    'vehicle_type': 'Coupe'},
#   'salary_commute': 3141.691842900302},
#  {'personal': {'first_name': 'Nicola',
#    'last_name': 'Walker',
#    'sex': 'Female',
#    'age': 38,
#    'marital_status': 'single',
#    'dependants': 1},
#   'address': {'street': 'Flat 7 Barber motorway',
#    'city': 'Burrowsshire',
#    'postcode': 'L62 8TA'},
#   'work': {'employer': 'Bailey Group',
#    'commute': 6.66,
#    'salary_GBP': 20940,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 3580000000000000,
#    'card_cvv': 679,
#    'card_iban': 'GB81SVHK17718594367943',
#    'card_start': '2013-01-01',
#    'card_exp': '2029-05-01'},
#   'vehicle': {'vehicle_make': 'Ford',
#    'vehicle_model': 'S6',
#    'vehicle_year': 2020,
#    'vehicle_type': 'Sedan'},
#   'salary_commute': 3144.144144144144},
#  {'personal': {'first_name': 'Beverley',
#    'last_name': 'Burton',
#    'sex': 'Female',
#    'age': 50,
#    'marital_status': 'widowed',
#    'dependants': 4},
#   'address': {'street': 'Flat 0 Geraldine lock',
#    'city': 'North Scottbury',
#    'postcode': 'SL9N 4JR'},
#   'work': {'employer': 'Graham, Fisher and Jones',
#    'commute': 6.64,
#    'salary_GBP': 20881,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 213000000000000,
#    'card_cvv': 542,
#    'card_iban': 'GB18MRHJ30676235636281',
#    'card_start': '2015-04-01',
#    'card_exp': '2023-11-01'},
#   'vehicle': {'vehicle_make': 'Honda',
#    'vehicle_model': 'Santa Fe',
#    'vehicle_year': 2010,
#    'vehicle_type': 'SUV'},
#   'salary_commute': 3144.7289156626507},
#  {'personal': {'first_name': 'Tina',
#    'last_name': 'Thornton',
#    'sex': 'Female',
#    'age': 28,
#    'marital_status': 'single',
#    'dependants': 2},
#   'address': {'street': 'Studio 9 Joan tunnel',
#    'city': 'Birdview',
#    'postcode': 'LS3 9ZL'},
#   'work': {'employer': 'McCarthy and Sons',
#    'commute': 6.65,
#    'salary_GBP': 20918,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 6010000000000000,
#    'card_cvv': 588,
#    'card_iban': 'GB02YMXX98886109551024',
#    'card_start': '2014-03-01',
#    'card_exp': '2023-06-01'},
#   'vehicle': {'vehicle_make': 'Mercedes-Benz',
#    'vehicle_model': 'RX',
#    'vehicle_year': 1992,
#    'vehicle_type': 'Hatchback, Convertible'},
#   'salary_commute': 3145.563909774436},
#  {'personal': {'first_name': 'Mark',
#    'last_name': 'Smith',
#    'sex': 'Male',
#    'age': 28,
#    'marital_status': 'married or civil partner',
#    'dependants': 1},
#   'address': {'street': '275 Hunt center',
#    'city': 'East Olivershire',
#    'postcode': 'L0J 3AG'},
#   'work': {'employer': 'Walker Group',
#    'commute': 6.69,
#    'salary_GBP': 21053,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4020000000000000,
#    'card_cvv': 752,
#    'card_iban': 'GB22DCLN32852428290826',
#    'card_start': '2018-05-01',
#    'card_exp': '2030-05-01'},
#   'vehicle': {'vehicle_make': 'Ford',
#    'vehicle_model': 'Matrix',
#    'vehicle_year': 2001,
#    'vehicle_type': 'Pickup'},
#   'salary_commute': 3146.9357249626305},
#  {'personal': {'first_name': 'Alexander',
#    'last_name': 'Read',
#    'sex': 'Male',
#    'age': 53,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': '058 Lewis road',
#    'city': 'North Francischester',
#    'postcode': 'SL8P 3AY'},
#   'work': {'employer': 'Stokes, Jones and Wilkinson',
#    'commute': 6.74,
#    'salary_GBP': 21222,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 370000000000000,
#    'card_cvv': 182,
#    'card_iban': 'GB29HWSY19465546861027',
#    'card_start': '2016-09-01',
#    'card_exp': '2025-10-01'},
#   'vehicle': {'vehicle_make': 'GMC',
#    'vehicle_model': 'Sentra',
#    'vehicle_year': 2009,
#    'vehicle_type': 'Pickup'},
#   'salary_commute': 3148.6646884272996},
#  {'personal': {'first_name': 'Charlie',
#    'last_name': 'Thompson',
#    'sex': 'Male',
#    'age': 21,
#    'marital_status': 'single',
#    'dependants': 2},
#   'address': {'street': '1 Haynes bypass',
#    'city': 'Port Rhys',
#    'postcode': 'DA6R 9GR'},
#   'work': {'employer': 'Edwards-Jackson',
#    'commute': 6.77,
#    'salary_GBP': 21342,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 3500000000000000,
#    'card_cvv': 497,
#    'card_iban': 'GB03FCNS17657052384698',
#    'card_start': '2016-07-01',
#    'card_exp': '2023-06-01'},
#   'vehicle': {'vehicle_make': 'Honda',
#    'vehicle_model': 'G-Class',
#    'vehicle_year': 2000,
#    'vehicle_type': 'Wagon'},
#   'salary_commute': 3152.437223042836},
#  {'personal': {'first_name': 'Sandra',
#    'last_name': 'Gill',
#    'sex': 'Female',
#    'age': 29,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': '92 Williams drive',
#    'city': 'South Georginafurt',
#    'postcode': 'BR2 2AD'},
#   'work': {'employer': 'Ingram, Williams and Flynn',
#    'commute': 6.79,
#    'salary_GBP': 21433,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4860000000000000000,
#    'card_cvv': 501,
#    'card_iban': 'GB34ONOS38919074931386',
#    'card_start': '2018-02-01',
#    'card_exp': '2025-08-01'},
#   'vehicle': {'vehicle_make': 'Land Rover',
#    'vehicle_model': 'Tundra Double Cab',
#    'vehicle_year': 1997,
#    'vehicle_type': 'Van/Minivan'},
#   'salary_commute': 3156.5537555228275},
#  {'personal': {'first_name': 'Gavin',
#    'last_name': 'Barnett',
#    'sex': 'Male',
#    'age': 33,
#    'marital_status': 'married or civil partner',
#    'dependants': 1},
#   'address': {'street': '61 Pamela underpass',
#    'city': 'Port Brett',
#    'postcode': 'PO8V 2NY'},
#   'work': {'employer': 'May, Hudson and Robertson',
#    'commute': 6.92,
#    'salary_GBP': 21875,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4790000000000000,
#    'card_cvv': 304,
#    'card_iban': 'GB65FZNW19533786149602',
#    'card_start': '2008-12-01',
#    'card_exp': '2029-09-01'},
#   'vehicle': {'vehicle_make': 'Suzuki',
#    'vehicle_model': 'G-Class',
#    'vehicle_year': 1992,
#    'vehicle_type': 'Sedan'},
#   'salary_commute': 3161.127167630058},
#  {'personal': {'first_name': 'Billy',
#    'last_name': 'Wilson',
#    'sex': 'Male',
#    'age': 56,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': 'Flat 2 Russell shores',
#    'city': 'Dennisburgh',
#    'postcode': 'E35 5BY'},
#   'work': {'employer': 'Cox-Hill',
#    'commute': 6.9,
#    'salary_GBP': 21818,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 6510000000000000,
#    'card_cvv': 389,
#    'card_iban': 'GB91VQZW86649194357794',
#    'card_start': '2015-06-01',
#    'card_exp': '2022-07-01'},
#   'vehicle': {'vehicle_make': 'Land Rover',
#    'vehicle_model': 'Yukon XL 1500',
#    'vehicle_year': 2016,
#    'vehicle_type': 'SUV'},
#   'salary_commute': 3162.028985507246},
#  {'personal': {'first_name': 'Julia',
#    'last_name': 'Wilkinson',
#    'sex': 'Female',
#    'age': 35,
#    'marital_status': 'single',
#    'dependants': 3},
#   'address': {'street': '26 Jackson canyon',
#    'city': "O'Sullivanport",
#    'postcode': 'W31 3PR'},
#   'work': {'employer': 'Khan Group',
#    'commute': 6.9,
#    'salary_GBP': 21831,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 2350000000000000,
#    'card_cvv': 31,
#    'card_iban': 'GB90FSQC41618771938390',
#    'card_start': '2019-09-01',
#    'card_exp': '2024-04-01'},
#   'vehicle': {'vehicle_make': 'Freightliner',
#    'vehicle_model': 'Transit 250 Van',
#    'vehicle_year': 2010,
#    'vehicle_type': 'Hatchback, Convertible'},
#   'salary_commute': 3163.9130434782605},
#  {'personal': {'first_name': 'Amber',
#    'last_name': 'McCarthy',
#    'sex': 'Female',
#    'age': 55,
#    'marital_status': 'single',
#    'dependants': 2},
#   'address': {'street': 'Studio 83 Douglas hollow',
#    'city': 'Oliverfort',
#    'postcode': 'S60 1RX'},
#   'work': {'employer': 'Owens-Law',
#    'commute': 6.95,
#    'salary_GBP': 22009,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 6010000000000000,
#    'card_cvv': 999,
#    'card_iban': 'GB16VPNM93629820292525',
#    'card_start': '2017-11-01',
#    'card_exp': '2028-02-01'},
#   'vehicle': {'vehicle_make': 'GMC',
#    'vehicle_model': 'Encore',
#    'vehicle_year': 2016,
#    'vehicle_type': 'Coupe'},
#   'salary_commute': 3166.7625899280574},
#  {'personal': {'first_name': 'George',
#    'last_name': 'Singh',
#    'sex': 'Male',
#    'age': 37,
#    'marital_status': 'divorced',
#    'dependants': 3},
#   'address': {'street': 'Studio 4 Harper heights',
#    'city': 'Collinsborough',
#    'postcode': 'WC12 9FX'},
#   'work': {'employer': 'Evans Inc',
#    'commute': 6.94,
#    'salary_GBP': 21978,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4910000000000000,
#    'card_cvv': 496,
#    'card_iban': 'GB53XBSV21627953089422',
#    'card_start': '2017-08-01',
#    'card_exp': '2029-02-01'},
#   'vehicle': {'vehicle_make': 'HUMMER',
#    'vehicle_model': 'Astro Passenger',
#    'vehicle_year': 1998,
#    'vehicle_type': 'Van/Minivan'},
#   'salary_commute': 3166.8587896253603},
#  {'personal': {'first_name': 'Nigel',
#    'last_name': 'John',
#    'sex': 'Male',
#    'age': 60,
#    'marital_status': 'married or civil partner',
#    'dependants': 1},
#   'address': {'street': '151 Neil garden',
#    'city': 'Port Alexburgh',
#    'postcode': 'L25 8DH'},
#   'work': {'employer': 'Hawkins Group',
#    'commute': 7.0,
#    'salary_GBP': 22171,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 213000000000000,
#    'card_cvv': 928,
#    'card_iban': 'GB15WXZG75381090347049',
#    'card_start': '2011-11-01',
#    'card_exp': '2024-08-01'},
#   'vehicle': {'vehicle_make': 'Hyundai',
#    'vehicle_model': 'Range Rover',
#    'vehicle_year': 1993,
#    'vehicle_type': 'Pickup'},
#   'salary_commute': 3167.285714285714},
#  {'personal': {'first_name': 'Julian',
#    'last_name': 'Wright',
#    'sex': 'Male',
#    'age': 48,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': '54 Gail locks',
#    'city': 'New Philip',
#    'postcode': 'S2S 8AS'},
#   'work': {'employer': 'Martin-Wong',
#    'commute': 6.98,
#    'salary_GBP': 22108,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 213000000000000,
#    'card_cvv': 3720,
#    'card_iban': 'GB95FRBH33922441872165',
#    'card_start': '2014-03-01',
#    'card_exp': '2018-03-01'},
#   'vehicle': {'vehicle_make': 'FIAT',
#    'vehicle_model': 'Express 2500 Passenger',
#    'vehicle_year': 2007,
#    'vehicle_type': 'Sedan'},
#   'salary_commute': 3167.3352435530082},
#  {'personal': {'first_name': 'Terry',
#    'last_name': 'Collins',
#    'sex': 'Male',
#    'age': 31,
#    'marital_status': 'divorced',
#    'dependants': 3},
#   'address': {'street': 'Studio 8 Megan valley',
#    'city': 'Bradystad',
#    'postcode': 'W2 3NB'},
#   'work': {'employer': 'Green Group',
#    'commute': 7.01,
#    'salary_GBP': 22227,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 6010000000000000,
#    'card_cvv': 5124,
#    'card_iban': 'GB30LARX31492330168413',
#    'card_start': '2013-12-01',
#    'card_exp': '2022-06-01'},
#   'vehicle': {'vehicle_make': 'Acura',
#    'vehicle_model': 'Accent',
#    'vehicle_year': 2011,
#    'vehicle_type': 'SUV'},
#   'salary_commute': 3170.756062767475},
#  {'personal': {'first_name': 'Joan',
#    'last_name': 'Morris',
#    'sex': 'Female',
#    'age': 61,
#    'marital_status': 'married or civil partner',
#    'dependants': 3},
#   'address': {'street': 'Flat 13e Robinson lane',
#    'city': 'Christopherville',
#    'postcode': 'EC75 1PU'},
#   'work': {'employer': 'Donnelly, Johnson and Ellis',
#    'commute': 7.04,
#    'salary_GBP': 22334,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 2720000000000000,
#    'card_cvv': 796,
#    'card_iban': 'GB35WYQE07511547192673',
#    'card_start': '2017-06-01',
#    'card_exp': '2027-06-01'},
#   'vehicle': {'vehicle_make': 'Toyota',
#    'vehicle_model': 'Prelude',
#    'vehicle_year': 1996,
#    'vehicle_type': 'Pickup'},
#   'salary_commute': 3172.443181818182},
#  {'personal': {'first_name': 'Joseph',
#    'last_name': 'Richardson',
#    'sex': 'Male',
#    'age': 28,
#    'marital_status': 'single',
#    'dependants': 3},
#   'address': {'street': '737 Iain alley',
#    'city': 'Turnbullport',
#    'postcode': 'W24 2ZF'},
#   'work': {'employer': "Williams, Gray and O'Brien",
#    'commute': 7.06,
#    'salary_GBP': 22407,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 180000000000000,
#    'card_cvv': 928,
#    'card_iban': 'GB04RLWP86942505651919',
#    'card_start': '2015-07-01',
#    'card_exp': '2016-01-01'},
#   'vehicle': {'vehicle_make': 'Audi',
#    'vehicle_model': 'Breeze',
#    'vehicle_year': 1998,
#    'vehicle_type': 'Sedan'},
#   'salary_commute': 3173.7960339943343},
#  {'personal': {'first_name': 'Abigail',
#    'last_name': 'Francis',
#    'sex': 'Female',
#    'age': 20,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': 'Flat 28D Dorothy lodge',
#    'city': 'South John',
#    'postcode': 'G67 6TX'},
#   'work': {'employer': 'Parry, Brown and Palmer',
#    'commute': 7.07,
#    'salary_GBP': 22442,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 180000000000000,
#    'card_cvv': 839,
#    'card_iban': 'GB96VWPH42116737926749',
#    'card_start': '2015-12-01',
#    'card_exp': '2016-07-01'},
#   'vehicle': {'vehicle_make': 'Mercedes-Benz',
#    'vehicle_model': 'IS',
#    'vehicle_year': 1992,
#    'vehicle_type': 'Pickup'},
#   'salary_commute': 3174.257425742574},
#  {'personal': {'first_name': 'Ian',
#    'last_name': 'Kaur',
#    'sex': 'Male',
#    'age': 36,
#    'marital_status': 'single',
#    'dependants': 2},
#   'address': {'street': 'Flat 16 Miller field',
#    'city': 'Tomtown',
#    'postcode': 'S39 3YR'},
#   'work': {'employer': "Dean, Griffiths and O'Sullivan",
#    'commute': 7.08,
#    'salary_GBP': 22482,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 180000000000000,
#    'card_cvv': 51,
#    'card_iban': 'GB68DFVY83693611094286',
#    'card_start': '2013-06-01',
#    'card_exp': '2021-09-01'},
#   'vehicle': {'vehicle_make': 'Nissan',
#    'vehicle_model': 'DeVille',
#    'vehicle_year': 2015,
#    'vehicle_type': 'Coupe, Sedan, Convertible'},
#   'salary_commute': 3175.423728813559},
#  {'personal': {'first_name': 'Ronald',
#    'last_name': 'Atkinson',
#    'sex': 'Male',
#    'age': 42,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': '034 Amelia place',
#    'city': 'Sharpton',
#    'postcode': 'RG67 4BW'},
#   'work': {'employer': 'Thomas and Sons',
#    'commute': 7.11,
#    'salary_GBP': 22590,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4030000000000,
#    'card_cvv': 182,
#    'card_iban': 'GB98CZTE90384847970589',
#    'card_start': '2017-11-01',
#    'card_exp': '2024-11-01'},
#   'vehicle': {'vehicle_make': 'Chevrolet',
#    'vehicle_model': 'R-Class',
#    'vehicle_year': 2018,
#    'vehicle_type': 'Sedan'},
#   'salary_commute': 3177.215189873418},
#  {'personal': {'first_name': 'Denis',
#    'last_name': 'Brown',
#    'sex': 'Male',
#    'age': 65,
#    'marital_status': 'married or civil partner',
#    'dependants': 1},
#   'address': {'street': '949 Kirsty walk',
#    'city': 'Rickymouth',
#    'postcode': 'N77 4DX'},
#   'work': {'employer': 'Warren, Burton and Spencer',
#    'commute': 7.21,
#    'salary_GBP': 22959,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 3530000000000000,
#    'card_cvv': 570,
#    'card_iban': 'GB61PVEV06020291833305',
#    'card_start': '2008-12-01',
#    'card_exp': '2017-04-01'},
#   'vehicle': {'vehicle_make': 'Ford',
#    'vehicle_model': 'Yukon XL 1500',
#    'vehicle_year': 2007,
#    'vehicle_type': 'Wagon, Sedan, Coupe'},
#   'salary_commute': 3184.3273231622748},
#  {'personal': {'first_name': 'Shane',
#    'last_name': 'Dale',
#    'sex': 'Male',
#    'age': 81,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': '2 Marc isle',
#    'city': 'Jasonburgh',
#    'postcode': 'E5 9AE'},
#   'work': {'employer': 'Page, Bond and Middleton',
#    'commute': 7.24,
#    'salary_GBP': 23086,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 3550000000000000,
#    'card_cvv': 551,
#    'card_iban': 'GB93KXDR64585503376228',
#    'card_start': '2015-08-01',
#    'card_exp': '2024-09-01'},
#   'vehicle': {'vehicle_make': 'Acura',
#    'vehicle_model': 'Regal',
#    'vehicle_year': 2001,
#    'vehicle_type': 'Sedan, Wagon'},
#   'salary_commute': 3188.674033149171},
#  {'personal': {'first_name': 'Jordan',
#    'last_name': 'Moore',
#    'sex': 'Male',
#    'age': 49,
#    'marital_status': 'married or civil partner',
#    'dependants': 1},
#   'address': {'street': '342 Arthur inlet',
#    'city': 'South Marianview',
#    'postcode': 'G0G 7XX'},
#   'work': {'employer': 'Collier, Jennings and Watkins',
#    'commute': 7.28,
#    'salary_GBP': 23229,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4900000000000000,
#    'card_cvv': 876,
#    'card_iban': 'GB20IOVC74910494057625',
#    'card_start': '2017-08-01',
#    'card_exp': '2025-04-01'},
#   'vehicle': {'vehicle_make': 'Dodge',
#    'vehicle_model': '3500 Crew Cab',
#    'vehicle_year': 2003,
#    'vehicle_type': 'SUV'},
#   'salary_commute': 3190.796703296703},
#  {'personal': {'first_name': 'Edward',
#    'last_name': 'Evans',
#    'sex': 'Male',
#    'age': 22,
#    'marital_status': 'divorced',
#    'dependants': 2},
#   'address': {'street': '565 Hussain ramp',
#    'city': 'Belltown',
#    'postcode': 'E8 0DA'},
#   'work': {'employer': 'Evans Inc',
#    'commute': 7.28,
#    'salary_GBP': 23230,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 378000000000000,
#    'card_cvv': 268,
#    'card_iban': 'GB39TXBI28708609660766',
#    'card_start': '2019-11-01',
#    'card_exp': '2026-12-01'},
#   'vehicle': {'vehicle_make': 'Toyota',
#    'vehicle_model': 'Huracan',
#    'vehicle_year': 2009,
#    'vehicle_type': 'Wagon'},
#   'salary_commute': 3190.934065934066},
#  {'personal': {'first_name': 'Diane',
#    'last_name': 'Jackson',
#    'sex': 'Female',
#    'age': 29,
#    'marital_status': 'married or civil partner',
#    'dependants': 1},
#   'address': {'street': 'Studio 02 Samantha ford',
#    'city': 'Lake Adam',
#    'postcode': 'N28 2WW'},
#   'work': {'employer': 'Smart-Douglas',
#    'commute': 7.26,
#    'salary_GBP': 23171,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4180000000000000,
#    'card_cvv': 758,
#    'card_iban': 'GB51HEVW37846678280777',
#    'card_start': '2001-12-01',
#    'card_exp': '2021-02-01'},
#   'vehicle': {'vehicle_make': 'Jaguar',
#    'vehicle_model': 'Eldorado',
#    'vehicle_year': 1995,
#    'vehicle_type': 'Pickup'},
#   'salary_commute': 3191.597796143251},
#  {'personal': {'first_name': 'Ann',
#    'last_name': 'Sharp',
#    'sex': 'Female',
#    'age': 59,
#    'marital_status': 'married or civil partner',
#    'dependants': 1},
#   'address': {'street': '06 Patel mission',
#    'city': 'Bruceview',
#    'postcode': 'CO93 2TY'},
#   'work': {'employer': 'Webb Ltd',
#    'commute': 7.28,
#    'salary_GBP': 23246,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 6010000000000000,
#    'card_cvv': 870,
#    'card_iban': 'GB98DJOI99007942226987',
#    'card_start': '2020-05-01',
#    'card_exp': '2020-07-01'},
#   'vehicle': {'vehicle_make': 'Chevrolet',
#    'vehicle_model': 'Sonic',
#    'vehicle_year': 2009,
#    'vehicle_type': 'Coupe, Convertible'},
#   'salary_commute': 3193.131868131868},
#  {'personal': {'first_name': 'Chloe',
#    'last_name': 'Clarke',
#    'sex': 'Female',
#    'age': 59,
#    'marital_status': 'single',
#    'dependants': 2},
#   'address': {'street': '43 Kerr mountains',
#    'city': 'Owenston',
#    'postcode': 'DH4Y 9PN'},
#   'work': {'employer': 'Wright LLC',
#    'commute': 7.3,
#    'salary_GBP': 23326,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 6520000000000000,
#    'card_cvv': 271,
#    'card_iban': 'GB12AMDV26523116046186',
#    'card_start': '2017-04-01',
#    'card_exp': '2023-09-01'},
#   'vehicle': {'vehicle_make': 'MINI',
#    'vehicle_model': 'xB',
#    'vehicle_year': 2010,
#    'vehicle_type': 'Sedan'},
#   'salary_commute': 3195.3424657534247},
#  {'personal': {'first_name': 'Rachael',
#    'last_name': 'Harris',
#    'sex': 'Female',
#    'age': 71,
#    'marital_status': 'married or civil partner',
#    'dependants': 1},
#   'address': {'street': '4 Clarke spring',
#    'city': 'Jaynetown',
#    'postcode': 'HS76 6ZB'},
#   'work': {'employer': 'Barnes-Baker',
#    'commute': 7.34,
#    'salary_GBP': 23476,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 36700000000000,
#    'card_cvv': 9960,
#    'card_iban': 'GB96MVRG32298140349356',
#    'card_start': '2020-05-01',
#    'card_exp': '2024-05-01'},
#   'vehicle': {'vehicle_make': 'Ford',
#    'vehicle_model': 'Ghost',
#    'vehicle_year': 1997,
#    'vehicle_type': 'Pickup'},
#   'salary_commute': 3198.365122615804},
#  {'personal': {'first_name': 'Jasmine',
#    'last_name': 'Wallis',
#    'sex': 'Female',
#    'age': 47,
#    'marital_status': 'married or civil partner',
#    'dependants': 1},
#   'address': {'street': 'Studio 17 Francesca trace',
#    'city': 'Bensonside',
#    'postcode': 'E2 5NW'},
#   'work': {'employer': 'Baxter, Lucas and Evans',
#    'commute': 7.43,
#    'salary_GBP': 23793,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4050000000000,
#    'card_cvv': 559,
#    'card_iban': 'GB33IWJU24164146729176',
#    'card_start': '2018-10-01',
#    'card_exp': '2028-03-01'},
#   'vehicle': {'vehicle_make': 'Ford',
#    'vehicle_model': 'SLR McLaren',
#    'vehicle_year': 2013,
#    'vehicle_type': 'Van/Minivan'},
#   'salary_commute': 3202.2880215343203},
#  {'personal': {'first_name': 'Julie',
#    'last_name': 'Collins',
#    'sex': 'Female',
#    'age': 22,
#    'marital_status': 'single',
#    'dependants': 3},
#   'address': {'street': '96 Thompson courts',
#    'city': 'Smithmouth',
#    'postcode': 'LE9A 6TP'},
#   'work': {'employer': 'Chambers Group',
#    'commute': 7.49,
#    'salary_GBP': 24016,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 373000000000000,
#    'card_cvv': 487,
#    'card_iban': 'GB63EZMZ80369156365090',
#    'card_start': '2012-12-01',
#    'card_exp': '2024-02-01'},
#   'vehicle': {'vehicle_make': 'Mercury',
#    'vehicle_model': 'LeSabre',
#    'vehicle_year': 2016,
#    'vehicle_type': 'Convertible'},
#   'salary_commute': 3206.4085447263014},
#  {'personal': {'first_name': 'Martin',
#    'last_name': 'Phillips',
#    'sex': 'Male',
#    'age': 37,
#    'marital_status': 'married or civil partner',
#    'dependants': 3},
#   'address': {'street': 'Flat 90e Kennedy point',
#    'city': 'Port Derek',
#    'postcode': 'E68 6DU'},
#   'work': {'employer': 'Herbert, Williams and Wright',
#    'commute': 7.48,
#    'salary_GBP': 23995,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4670000000000000,
#    'card_cvv': 903,
#    'card_iban': 'GB27NWGE18328186627664',
#    'card_start': '2015-05-01',
#    'card_exp': '2018-05-01'},
#   'vehicle': {'vehicle_make': 'Lexus',
#    'vehicle_model': 'i3',
#    'vehicle_year': 2006,
#    'vehicle_type': 'Sedan'},
#   'salary_commute': 3207.887700534759},
#  {'personal': {'first_name': 'Stuart',
#    'last_name': 'Page',
#    'sex': 'Male',
#    'age': 68,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': '6 Frances flats',
#    'city': 'Lake Amberchester',
#    'postcode': 'NE5E 5AD'},
#   'work': {'employer': 'Mitchell-Brown',
#    'commute': 7.5,
#    'salary_GBP': 24062,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 4030000000000,
#    'card_cvv': 404,
#    'card_iban': 'GB52JKQX17539370637650',
#    'card_start': '2018-06-01',
#    'card_exp': '2022-12-01'},
#   'vehicle': {'vehicle_make': 'Volkswagen',
#    'vehicle_model': 'Stratus',
#    'vehicle_year': 2012,
#    'vehicle_type': 'SUV'},
#   'salary_commute': 3208.266666666667},
#  {'personal': {'first_name': 'Elaine',
#    'last_name': 'Cox',
#    'sex': 'Female',
#    'age': 37,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': '7 Gough glen',
#    'city': 'Leefurt',
#    'postcode': 'CH7E 3FQ'},
#   'work': {'employer': 'King, Moore and Birch',
#    'commute': 7.5,
#    'salary_GBP': 24079,
#    'retired': False,
#    'pension_GBP': 0},
#   'card': {'card_num': 30400000000000,
#    'card_cvv': 7800,
#    'card_iban': 'GB20NHNE74002663180515',
#    'card_start': '2014-11-01',
#    'card_exp': '2023-11-01'},
#   'vehicle': {'vehicle_make': 'Ford',
#    'vehicle_model': 'QX70',
#    'vehicle_year': 2018,
#    'vehicle_type': 'Coupe'},
#   'salary_commute': 3210.5333333333333},
# ...
#    'sex': 'Female',
#    'age': 82,
#    'marital_status': 'single',
#    'dependants': 1},
#   'address': {'street': 'Studio 31I Grace extensions',
#    'city': 'Kevinmouth',
#    'postcode': 'ME64 0ZQ'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 92994,
#    'retired': True,
#    'pension_GBP': 29849},
#   'card': {'card_num': 30600000000000,
#    'card_cvv': 863,
#    'card_iban': 'GB05QMAA51612301802017',
#    'card_start': '2015-11-01',
#    'card_exp': '2028-10-01'},
#   'vehicle': {'vehicle_make': 'Ford',
#    'vehicle_model': 'Yukon XL 2500',
#    'vehicle_year': 2009,
#    'vehicle_type': 'Wagon'},
#   'salary_commute': 92994},
#  {'personal': {'first_name': 'Beverley',
#    'last_name': 'Clements',
#    'sex': 'Female',
#    'age': 81,
#    'marital_status': 'single',
#    'dependants': 3},
#   'address': {'street': '4 Griffiths lane',
#    'city': 'Robinhaven',
#    'postcode': 'W2K 7FU'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 93179,
#    'retired': True,
#    'pension_GBP': 33323},
#   'card': {'card_num': 4400000000000,
#    'card_cvv': 127,
#    'card_iban': 'GB23KSDI18325875892927',
#    'card_start': '2017-07-01',
#    'card_exp': '2024-10-01'},
#   'vehicle': {'vehicle_make': 'Lexus',
#    'vehicle_model': 'Sportage',
#    'vehicle_year': 1996,
#    'vehicle_type': 'Convertible'},
#   'salary_commute': 93179},
#  {'personal': {'first_name': 'Owen',
#    'last_name': 'Clarke',
#    'sex': 'Male',
#    'age': 77,
#    'marital_status': 'single',
#    'dependants': 2},
#   'address': {'street': '451 Fry forges',
#    'city': 'New Yvonnefurt',
#    'postcode': 'B56 9JR'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 93472,
#    'retired': True,
#    'pension_GBP': 25180},
#   'card': {'card_num': 4210000000000000000,
#    'card_cvv': 665,
#    'card_iban': 'GB52NDLB99095695780485',
#    'card_start': '2014-07-01',
#    'card_exp': '2016-10-01'},
#   'vehicle': {'vehicle_make': 'Ford',
#    'vehicle_model': 'Escalade',
#    'vehicle_year': 2017,
#    'vehicle_type': 'Sedan'},
#   'salary_commute': 93472},
#  {'personal': {'first_name': 'Judith',
#    'last_name': 'Lane',
#    'sex': 'Female',
#    'age': 91,
#    'marital_status': 'single',
#    'dependants': 2},
#   'address': {'street': '42 Alex burgs',
#    'city': 'West Nicole',
#    'postcode': 'G8S 4JD'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 93485,
#    'retired': True,
#    'pension_GBP': 39930},
#   'card': {'card_num': 3550000000000000,
#    'card_cvv': 228,
#    'card_iban': 'GB32BLVW12286806144217',
#    'card_start': '2015-06-01',
#    'card_exp': '2020-05-01'},
#   'vehicle': {'vehicle_make': 'Lexus',
#    'vehicle_model': 'Samurai',
#    'vehicle_year': 2011,
#    'vehicle_type': 'Pickup'},
#   'salary_commute': 93485},
#  {'personal': {'first_name': 'Connor',
#    'last_name': 'Lawrence',
#    'sex': 'Male',
#    'age': 87,
#    'marital_status': 'married or civil partner',
#    'dependants': 3},
#   'address': {'street': '08 McDonald dam',
#    'city': 'South Albert',
#    'postcode': 'PA5X 6YL'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 93624,
#    'retired': True,
#    'pension_GBP': 20541},
#   'card': {'card_num': 4510000000000,
#    'card_cvv': 671,
#    'card_iban': 'GB04QDRF92440956751546',
#    'card_start': '2015-04-01',
#    'card_exp': '2018-05-01'},
#   'vehicle': {'vehicle_make': 'Chrysler',
#    'vehicle_model': 'Sentra',
#    'vehicle_year': 1999,
#    'vehicle_type': 'Sedan'},
#   'salary_commute': 93624},
#  {'personal': {'first_name': 'Adam',
#    'last_name': 'Marsden',
#    'sex': 'Male',
#    'age': 88,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': '28 Graham court',
#    'city': 'West Annemouth',
#    'postcode': 'TW52 3JL'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 94218,
#    'retired': True,
#    'pension_GBP': 26520},
#   'card': {'card_num': 4620000000000000,
#    'card_cvv': 1963,
#    'card_iban': 'GB10DKPR07147792146764',
#    'card_start': '2017-06-01',
#    'card_exp': '2028-02-01'},
#   'vehicle': {'vehicle_make': 'Cadillac',
#    'vehicle_model': 'Silverado 1500 Crew Cab',
#    'vehicle_year': 2000,
#    'vehicle_type': 'Sedan'},
#   'salary_commute': 94218},
#  {'personal': {'first_name': 'Derek',
#    'last_name': 'White',
#    'sex': 'Male',
#    'age': 76,
#    'marital_status': 'single',
#    'dependants': 4},
#   'address': {'street': '9 Jones views',
#    'city': 'Greenhaven',
#    'postcode': 'G6E 9FR'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 94320,
#    'retired': True,
#    'pension_GBP': 10716},
#   'card': {'card_num': 4680000000000000000,
#    'card_cvv': 716,
#    'card_iban': 'GB62KAZA24905289473044',
#    'card_start': '2016-11-01',
#    'card_exp': '2028-10-01'},
#   'vehicle': {'vehicle_make': 'Honda',
#    'vehicle_model': 'F250 Super Duty Crew Cab',
#    'vehicle_year': 2015,
#    'vehicle_type': 'Sedan'},
#   'salary_commute': 94320},
#  {'personal': {'first_name': 'Sophie',
#    'last_name': 'Young',
#    'sex': 'Female',
#    'age': 91,
#    'marital_status': 'single',
#    'dependants': 1},
#   'address': {'street': 'Flat 36 Beverley shoal',
#    'city': 'East Shirleyton',
#    'postcode': 'L5W 7LH'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 94434,
#    'retired': True,
#    'pension_GBP': 23168},
#   'card': {'card_num': 4140000000000000000,
#    'card_cvv': 491,
#    'card_iban': 'GB21FHUG93387386912829',
#    'card_start': '2016-09-01',
#    'card_exp': '2019-11-01'},
#   'vehicle': {'vehicle_make': 'GMC',
#    'vehicle_model': 'Grand Cherokee',
#    'vehicle_year': 2014,
#    'vehicle_type': 'SUV'},
#   'salary_commute': 94434},
#  {'personal': {'first_name': 'Lorraine',
#    'last_name': 'Boyle',
#    'sex': 'Female',
#    'age': 86,
#    'marital_status': 'widowed',
#    'dependants': 2},
#   'address': {'street': '84 Sam shoal',
#    'city': 'Jeremyshire',
#    'postcode': 'CV8A 0RA'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 94590,
#    'retired': True,
#    'pension_GBP': 27727},
#   'card': {'card_num': 345000000000000,
#    'card_cvv': 777,
#    'card_iban': 'GB55PDYT71418244128116',
#    'card_start': '2013-02-01',
#    'card_exp': '2020-04-01'},
#   'vehicle': {'vehicle_make': 'Dodge',
#    'vehicle_model': 'Eclipse',
#    'vehicle_year': 2012,
#    'vehicle_type': 'Sedan'},
#   'salary_commute': 94590},
#  {'personal': {'first_name': 'Charles',
#    'last_name': 'Williams',
#    'sex': 'Male',
#    'age': 85,
#    'marital_status': 'married or civil partner',
#    'dependants': 4},
#   'address': {'street': 'Flat 91r White loop',
#    'city': 'South Lynne',
#    'postcode': 'L33 1HX'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 94891,
#    'retired': True,
#    'pension_GBP': 19041},
#   'card': {'card_num': 4680000000000000,
#    'card_cvv': 2487,
#    'card_iban': 'GB57RPFB59729369989813',
#    'card_start': '2015-07-01',
#    'card_exp': '2023-03-01'},
#   'vehicle': {'vehicle_make': 'Maserati',
#    'vehicle_model': '88',
#    'vehicle_year': 2002,
#    'vehicle_type': 'Pickup'},
#   'salary_commute': 94891},
#  {'personal': {'first_name': 'Philip',
#    'last_name': 'Owen',
#    'sex': 'Male',
#    'age': 67,
#    'marital_status': 'divorced',
#    'dependants': 1},
#   'address': {'street': '090 Ford roads',
#    'city': 'East Bryan',
#    'postcode': 'L3 4WR'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 95691,
#    'retired': True,
#    'pension_GBP': 33629},
#   'card': {'card_num': 4630000000000000000,
#    'card_cvv': 933,
#    'card_iban': 'GB97XNRH55329324397700',
#    'card_start': '2020-03-01',
#    'card_exp': '2028-12-01'},
#   'vehicle': {'vehicle_make': 'Subaru',
#    'vehicle_model': 'Sierra 1500 Regular Cab',
#    'vehicle_year': 2015,
#    'vehicle_type': 'Sedan'},
#   'salary_commute': 95691},
#  {'personal': {'first_name': 'Rosie',
#    'last_name': 'Wright',
#    'sex': 'Female',
#    'age': 83,
#    'marital_status': 'single',
#    'dependants': 1},
#   'address': {'street': '18 Graham park',
#    'city': 'Port Frances',
#    'postcode': 'BL28 8EN'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 95893,
#    'retired': True,
#    'pension_GBP': 27294},
#   'card': {'card_num': 4100000000000000,
#    'card_cvv': 241,
#    'card_iban': 'GB98MDVT41434421678958',
#    'card_start': '2018-06-01',
#    'card_exp': '2023-03-01'},
#   'vehicle': {'vehicle_make': 'Toyota',
#    'vehicle_model': 'NSX',
#    'vehicle_year': 2015,
#    'vehicle_type': 'Sedan'},
#   'salary_commute': 95893},
#  {'personal': {'first_name': 'Hazel',
#    'last_name': 'Day',
#    'sex': 'Female',
#    'age': 81,
#    'marital_status': 'divorced',
#    'dependants': 2},
#   'address': {'street': '2 Butler knolls',
#    'city': 'East Deanstad',
#    'postcode': 'GU4 1BG'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 95983,
#    'retired': True,
#    'pension_GBP': 14866},
#   'card': {'card_num': 4260000000000000,
#    'card_cvv': 151,
#    'card_iban': 'GB95LVFQ39001308964809',
#    'card_start': '2017-11-01',
#    'card_exp': '2029-08-01'},
#   'vehicle': {'vehicle_make': 'Audi',
#    'vehicle_model': 'Frontier Crew Cab',
#    'vehicle_year': 2016,
#    'vehicle_type': 'Van/Minivan'},
#   'salary_commute': 95983},
#  {'personal': {'first_name': 'Bryan',
#    'last_name': 'Ali',
#    'sex': 'Male',
#    'age': 73,
#    'marital_status': 'single',
#    'dependants': 2},
#   'address': {'street': 'Flat 40U Jonathan rapids',
#    'city': 'Hollieland',
#    'postcode': 'CW3Y 3RB'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 96519,
#    'retired': True,
#    'pension_GBP': 16340},
#   'card': {'card_num': 571000000000,
#    'card_cvv': 25,
#    'card_iban': 'GB53IRCM16821809654584',
#    'card_start': '2015-07-01',
#    'card_exp': '2017-05-01'},
#   'vehicle': {'vehicle_make': 'Ford',
#    'vehicle_model': 'Titan Crew Cab',
#    'vehicle_year': 2006,
#    'vehicle_type': 'Sedan'},
#   'salary_commute': 96519},
#  {'personal': {'first_name': 'Leigh',
#    'last_name': 'Fraser',
#    'sex': 'Male',
#    'age': 65,
#    'marital_status': 'married or civil partner',
#    'dependants': 1},
#   'address': {'street': '181 Wayne flats',
#    'city': 'West Jasonmouth',
#    'postcode': 'G2D 3RY'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 96593,
#    'retired': True,
#    'pension_GBP': 13351},
#   'card': {'card_num': 572000000000,
#    'card_cvv': 73,
#    'card_iban': 'GB86JMLO66506258656415',
#    'card_start': '2016-09-01',
#    'card_exp': '2021-02-01'},
#   'vehicle': {'vehicle_make': 'GMC',
#    'vehicle_model': 'Sierra 3500 HD Crew Cab',
#    'vehicle_year': 2013,
#    'vehicle_type': 'SUV'},
#   'salary_commute': 96593},
#  {'personal': {'first_name': 'Lee',
#    'last_name': 'Gray',
#    'sex': 'Male',
#    'age': 88,
#    'marital_status': 'single',
#    'dependants': 1},
#   'address': {'street': 'Flat 5 Stephanie forges',
#    'city': 'South Ashleytown',
#    'postcode': 'L6 5LP'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 96727,
#    'retired': True,
#    'pension_GBP': 22157},
#   'card': {'card_num': 502000000000,
#    'card_cvv': 9431,
#    'card_iban': 'GB97PVJD86143312270100',
#    'card_start': '2017-09-01',
#    'card_exp': '2026-12-01'},
#   'vehicle': {'vehicle_make': 'Porsche',
#    'vehicle_model': '5 Series',
#    'vehicle_year': 2003,
#    'vehicle_type': 'Convertible, Coupe'},
#   'salary_commute': 96727},
#  {'personal': {'first_name': 'Paul',
#    'last_name': 'Scott',
#    'sex': 'Male',
#    'age': 83,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': 'Flat 2 Simpson ridges',
#    'city': 'Port Craigborough',
#    'postcode': 'G25 3UX'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 97039,
#    'retired': True,
#    'pension_GBP': 33800},
#   'card': {'card_num': 2230000000000000,
#    'card_cvv': 351,
#    'card_iban': 'GB28BCRO81221173922772',
#    'card_start': '2017-12-01',
#    'card_exp': '2022-08-01'},
#   'vehicle': {'vehicle_make': 'Lincoln',
#    'vehicle_model': 'Ram Wagon 2500',
#    'vehicle_year': 2017,
#    'vehicle_type': 'Pickup'},
#   'salary_commute': 97039},
#  {'personal': {'first_name': 'Christian',
#    'last_name': 'Wright',
#    'sex': 'Male',
#    'age': 61,
#    'marital_status': 'single',
#    'dependants': 2},
#   'address': {'street': 'Flat 63 Gillian lodge',
#    'city': 'South Mark',
#    'postcode': 'LD2 5GQ'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 97299,
#    'retired': True,
#    'pension_GBP': 16507},
#   'card': {'card_num': 213000000000000,
#    'card_cvv': 32,
#    'card_iban': 'GB70XJZN91308561160062',
#    'card_start': '2017-06-01',
#    'card_exp': '2029-09-01'},
#   'vehicle': {'vehicle_make': 'BMW',
#    'vehicle_model': 'Aviator',
#    'vehicle_year': 2004,
#    'vehicle_type': 'Coupe'},
#   'salary_commute': 97299},
#  {'personal': {'first_name': 'Keith',
#    'last_name': 'Williamson',
#    'sex': 'Male',
#    'age': 86,
#    'marital_status': 'married or civil partner',
#    'dependants': 1},
#   'address': {'street': '18 King isle',
#    'city': 'East Caroline',
#    'postcode': 'SE25 0EH'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 97308,
#    'retired': True,
#    'pension_GBP': 17419},
#   'card': {'card_num': 4210000000000000,
#    'card_cvv': 533,
#    'card_iban': 'GB04PRCL86743699392708',
#    'card_start': '2018-09-01',
#    'card_exp': '2027-05-01'},
#   'vehicle': {'vehicle_make': 'Nissan',
#    'vehicle_model': 'X-Type',
#    'vehicle_year': 2013,
#    'vehicle_type': 'Pickup'},
#   'salary_commute': 97308},
#  {'personal': {'first_name': 'Geoffrey',
#    'last_name': 'Ward',
#    'sex': 'Male',
#    'age': 72,
#    'marital_status': 'single',
#    'dependants': 1},
#   'address': {'street': '9 Randall center',
#    'city': 'Donaldmouth',
#    'postcode': 'S5 3GT'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 97406,
#    'retired': True,
#    'pension_GBP': 21838},
#   'card': {'card_num': 377000000000000,
#    'card_cvv': 434,
#    'card_iban': 'GB54ZXCM95740026097623',
#    'card_start': '2014-03-01',
#    'card_exp': '2024-08-01'},
#   'vehicle': {'vehicle_make': 'Lincoln',
#    'vehicle_model': 'Silverado 3500 HD Regular Cab',
#    'vehicle_year': 2015,
#    'vehicle_type': 'Van/Minivan'},
#   'salary_commute': 97406},
#  {'personal': {'first_name': 'Lee',
#    'last_name': 'Davis',
#    'sex': 'Male',
#    'age': 73,
#    'marital_status': 'single',
#    'dependants': 4},
#   'address': {'street': 'Studio 63 Hilary lodge',
#    'city': 'South Glennberg',
#    'postcode': 'S0K 1HX'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 97592,
#    'retired': True,
#    'pension_GBP': 27056},
#   'card': {'card_num': 30100000000000,
#    'card_cvv': 163,
#    'card_iban': 'GB48WWAA89798937138684',
#    'card_start': '2016-09-01',
#    'card_exp': '2029-07-01'},
#   'vehicle': {'vehicle_make': 'Nissan',
#    'vehicle_model': 'Equator Crew Cab',
#    'vehicle_year': 2006,
#    'vehicle_type': 'Pickup'},
#   'salary_commute': 97592},
#  {'personal': {'first_name': 'Sian',
#    'last_name': 'Hayes',
#    'sex': 'Female',
#    'age': 89,
#    'marital_status': 'single',
#    'dependants': 2},
#   'address': {'street': '840 Webb forge',
#    'city': 'Port Francescatown',
#    'postcode': 'E2 2QX'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 97886,
#    'retired': True,
#    'pension_GBP': 10639},
#   'card': {'card_num': 30200000000000,
#    'card_cvv': 77,
#    'card_iban': 'GB21GYGM93489361164428',
#    'card_start': '2018-10-01',
#    'card_exp': '2019-10-01'},
#   'vehicle': {'vehicle_make': 'Acura',
#    'vehicle_model': 'Mercedes-AMG S-Class',
#    'vehicle_year': 2011,
#    'vehicle_type': 'Sedan'},
#   'salary_commute': 97886},
#  {'personal': {'first_name': 'Stephanie',
#    'last_name': 'Butler',
#    'sex': 'Female',
#    'age': 87,
#    'marital_status': 'married or civil partner',
#    'dependants': 2},
#   'address': {'street': 'Flat 10 Slater port',
#    'city': 'Lake Arthur',
#    'postcode': 'W5 4RU'},
#   'work': {'employer': 'N/A',
#    'commute': 0.0,
#    'salary_GBP': 98596,
#    'retired': True,
#    'pension_GBP': 46117},
#   'card': {'card_num': 213000000000000,
#    'card_cvv': 661,
#    'card_iban': 'GB06BBVM35013832455205',
#    'card_start': '2013-05-01',
#    'card_exp': '2020-02-01'},
#   'vehicle': {'vehicle_make': 'Mercedes-Benz',
#    'vehicle_model': 'Express 3500 Cargo',
#    'vehicle_year': 2002,
#    'vehicle_type': 'Coupe'},
#   'salary_commute': 98596}]
